# %% [markdown]
# ### PyTorch官方參考範例
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %%
import os
import glob
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import torchvision
import time
from PIL import Image

def CCSN_images(dataset_dir):
    classfolder = glob.glob(os.path.join(dataset_dir,"*"),recursive=True)
    class_name  = [f.split(os.path.sep)[-1] for f in classfolder]
    img_labels  = []
    img_list    = []

    for class_id, f in enumerate(classfolder):
        files = glob.glob(os.path.join(f,"*.jpg"),recursive=True)
        img_labels.extend([class_id]*len(files))
        img_list.extend(files)

    img_labels = np.array(img_labels)
    img_list   = np.array(img_list,dtype=object)

    return img_list.reshape((-1,1)), img_labels, class_name

# %% [markdown]
# ### 定義Dataset

# %%
class CCSNImageDataset(torch.utils.data.Dataset):
    def __init__(self, img_list, img_labels, transform=None, target_transform=None):
        self.transform        = transform
        self.target_transform = target_transform
        self.img_list         = img_list
        self.img_labels       = img_labels

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = self.img_list[idx,0]
        image    = Image.open(img_path)
        label    = self.img_labels[idx]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %% [markdown]
# ### 設定CCSN資料集路徑
# 例如:
# ![image.png](attachment:image.png)

# %%
CCSNDataset_Path = "CCSN_v2"
img_list, img_labels, label_names = CCSN_images(CCSNDataset_Path)

CCSNDataset = CCSNImageDataset(img_list,img_labels)

# %% [markdown]
# ### 範例:透過Dataset載入並顯示部分資料集

# %%
N = len(CCSNDataset)

plt.figure(figsize=(16,8))

for i in range(16):
    plt.subplot(4,8,i+1)
    image, label = CCSNDataset[np.random.randint(0,N)]
    plt.imshow(image)
    plt.title(label_names[label])
    plt.axis(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 使用預訓練模型
# 列出torchvision.models裡內建預訓練模型。

# %%
import torchvision
dir(torchvision.models)
# Out:
# ['AlexNet',
#  'AlexNet_Weights',
#  'ConvNeXt',
#  'ConvNeXt_Base_Weights',
#  'ConvNeXt_Large_Weights',
#  'ConvNeXt_Small_Weights',
#  'ConvNeXt_Tiny_Weights',
#  'DenseNet',
#  'DenseNet121_Weights',
#  'DenseNet161_Weights',
#  'DenseNet169_Weights',
#  'DenseNet201_Weights',
#  'EfficientNet',
#  'EfficientNet_B0_Weights',
#  'EfficientNet_B1_Weights',
#  'EfficientNet_B2_Weights',
#  'EfficientNet_B3_Weights',
#  'EfficientNet_B4_Weights',
#  'EfficientNet_B5_Weights',
#  'EfficientNet_B6_Weights',
#  'EfficientNet_B7_Weights',
#  'EfficientNet_V2_L_Weights',
#  'EfficientNet_V2_M_Weights',
#  'EfficientNet_V2_S_Weights',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'GoogLeNet_Weights',
#  'Inception3',
#  'InceptionOutputs',
#  'Inception_V3_Weights',
#  'MNASNet',
#  'MNASNet0_5_Weights',
#  'MNASNet0_75_Weights',
#  'MNASNet1_0_Weights',
#  'MNASNet1_3_Weights',
#  'MaxVit',
#  'MaxVit_T_Weights',
#  'MobileNetV2',
#  'MobileNetV3',
#  'MobileNet_V2_Weights',
#  'MobileNet_V3_Large_Weights',
#  'MobileNet_V3_Small_Weights',
#  'RegNet',
#  'RegNet_X_16GF_Weights',
#  'RegNet_X_1_6GF_Weights',
#  'RegNet_X_32GF_Weights',
#  'RegNet_X_3_2GF_Weights',
#  'RegNet_X_400MF_Weights',
#  'RegNet_X_800MF_Weights',
#  'RegNet_X_8GF_Weights',
#  'RegNet_Y_128GF_Weights',
#  'RegNet_Y_16GF_Weights',
#  'RegNet_Y_1_6GF_Weights',
#  'RegNet_Y_32GF_Weights',
#  'RegNet_Y_3_2GF_Weights',
#  'RegNet_Y_400MF_Weights',
#  'RegNet_Y_800MF_Weights',
#  'RegNet_Y_8GF_Weights',
#  'ResNeXt101_32X8D_Weights',
#  'ResNeXt101_64X4D_Weights',
#  'ResNeXt50_32X4D_Weights',
#  'ResNet',
#  'ResNet101_Weights',
#  'ResNet152_Weights',
#  'ResNet18_Weights',
#  'ResNet34_Weights',
#  'ResNet50_Weights',
#  'ShuffleNetV2',
#  'ShuffleNet_V2_X0_5_Weights',
#  'ShuffleNet_V2_X1_0_Weights',
#  'ShuffleNet_V2_X1_5_Weights',
#  'ShuffleNet_V2_X2_0_Weights',
#  'SqueezeNet',
#  'SqueezeNet1_0_Weights',
#  'SqueezeNet1_1_Weights',
#  'SwinTransformer',
#  'Swin_B_Weights',
#  'Swin_S_Weights',
#  'Swin_T_Weights',
#  'Swin_V2_B_Weights',
#  'Swin_V2_S_Weights',
#  'Swin_V2_T_Weights',
#  'VGG',
#  'VGG11_BN_Weights',
#  'VGG11_Weights',
#  'VGG13_BN_Weights',
#  'VGG13_Weights',
#  'VGG16_BN_Weights',
#  'VGG16_Weights',
#  'VGG19_BN_Weights',
#  'VGG19_Weights',
#  'ViT_B_16_Weights',
#  'ViT_B_32_Weights',
#  'ViT_H_14_Weights',
#  'ViT_L_16_Weights',
#  'ViT_L_32_Weights',
#  'VisionTransformer',
#  'Weights',
#  'WeightsEnum',
#  'Wide_ResNet101_2_Weights',
#  'Wide_ResNet50_2_Weights',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_api',
#  '_meta',
#  '_utils',
#  'alexnet',
#  'convnext',
#  'convnext_base',
#  'convnext_large',
#  'convnext_small',
#  'convnext_tiny',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'efficientnet',
#  'efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b2',
#  'efficientnet_b3',
#  'efficientnet_b4',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'efficientnet_v2_l',
#  'efficientnet_v2_m',
#  'efficientnet_v2_s',
#  'get_model',
#  'get_model_builder',
#  'get_model_weights',
#  'get_weight',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'list_models',
#  'maxvit',
#  'maxvit_t',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
#  'mobilenet_v3_small',
#  'mobilenetv2',
#  'mobilenetv3',
#  'optical_flow',
#  'quantization',
#  'regnet',
#  'regnet_x_16gf',
#  'regnet_x_1_6gf',
#  'regnet_x_32gf',
#  'regnet_x_3_2gf',
#  'regnet_x_400mf',
#  'regnet_x_800mf',
#  'regnet_x_8gf',
#  'regnet_y_128gf',
#  'regnet_y_16gf',
#  'regnet_y_1_6gf',
#  'regnet_y_32gf',
#  'regnet_y_3_2gf',
#  'regnet_y_400mf',
#  'regnet_y_800mf',
#  'regnet_y_8gf',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext101_64x4d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'shufflenetv2',
#  'squeezenet',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'swin_b',
#  'swin_s',
#  'swin_t',
#  'swin_transformer',
#  'swin_v2_b',
#  'swin_v2_s',
#  'swin_v2_t',
#  'vgg',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'video',
#  'vision_transformer',
#  'vit_b_16',
#  'vit_b_32',
#  'vit_h_14',
#  'vit_l_16',
#  'vit_l_32',
#  'wide_resnet101_2',
#  'wide_resnet50_2']

# %%
from tempfile import TemporaryDirectory

def train_model(model, criterion, optimizer, dataloaders, dataset_sizes, num_epochs=25, patience = 0,scheduler = None):

    device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model = model.to(device)

    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_loss = None
        best_acc  = 0
        history = {'loss':[],'accuracy':[],'val_loss':[],'val_accuracy':[]}
        patience_c = 0
        for epoch in range(num_epochs):
            print(f'Epoch {epoch:3d}/{num_epochs - 1}',end=' ')

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                if phase == 'train' and scheduler:
                    scheduler.step(epoch_loss)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}',end=' ' if phase=='train' else '\n')
                if phase == 'train':
                    history['loss'].append(epoch_loss)
                    history['accuracy'].append(epoch_acc.cpu().numpy())

                # deep copy the model
                if phase == 'val':
                    history['val_loss'].append(epoch_loss)
                    history['val_accuracy'].append(epoch_acc.cpu().numpy())
                    if best_acc < epoch_acc.cpu().numpy():
                        best_acc = epoch_acc.cpu().numpy()
                    if epoch == 0 or epoch_loss < best_loss:
                        best_loss = epoch_loss
                        patience_c= 0
                        torch.save(model.state_dict(), best_model_params_path)
                    else:
                        patience_c += 1

            if patience_c > patience:
                break

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model, history

def evaluate(model, dataloader):

    device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model.eval()   # Set model to evaluate mode

    running_loss = 0.0
    running_corrects = 0
    dataset_size     = 0
        # Iterate over data.
    for inputs, labels in dataloader:

        dataset_size += inputs.size(0)

        inputs = inputs.to(device)
        labels = labels.to(device)

        # forward
        # track history if only in train
        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        # statistics
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / dataset_size
    epoch_acc = running_corrects.double() / dataset_size

    print(f'test Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return epoch_loss, epoch_acc.cpu().numpy()

# %% [markdown]
# ### MyClassifierModel

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        # The arguments for commonly used modules:
        # torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        # torch.nn.MaxPool2d(kernel_size, stride, padding)
        
        self.cnn_layers = nn.Sequential(
            # 3 * 224 * 224 -> 64 * 111 * 111
            nn.Conv2d(3, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            nn.Conv2d(32, 64, 3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            # 64 * 111 * 111 -> 128 * 54 * 54
            nn.Conv2d(64, 128, 3),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            # 128 * 54 * 54 -> 256 * 26 * 26
            nn.Conv2d(128, 256, 3),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )
        
        #self-attention layer
        self.self_attn = nn.MultiheadAttention(embed_dim=256, num_heads=8, batch_first=True)

        self.fc_layers = nn.Sequential(
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),
            nn.Linear(256, 11),
        )

    def forward(self, x):
        # input (x): [batch_size, 3, 128, 128]
        # output: [batch_size, 11]

        # Extract features by convolutional layers.
        x = self.cnn_layers(x)

        # output -> [batch_size, 256 ,26 ,26] -> [batch_size, 512, 26*26] -> [batch_size, 26*26, 512]
        x = x.view(x.size(0), 256, -1).permute(0, 2, 1)  

        # output -> [batch_size, 26*26, 256]
        x, _ = self.self_attn(x, x, x)

        # global average pooling,output -> [batch_size, 256]
        x = x.mean(dim=1)  

        # The features are transformed by fully-connected layers to obtain the final logits.
        x = self.fc_layers(x)
        return x

# %%
from sklearn.model_selection import StratifiedKFold

device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

if torch.cuda.is_available():
    print('gpu is available')
else:
    print('cpu only')

data_transforms = {
    'train': torchvision.transforms.Compose([
        torchvision.transforms.RandomRotation(40),
        torchvision.transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        torchvision.transforms.RandomResizedCrop(224),
        torchvision.transforms.RandomHorizontalFlip(),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.CenterCrop(224),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

skf        = StratifiedKFold(n_splits=5, shuffle=True, random_state=0) # 80 % for training and validation sets, 20 % for the test set

batch_size = 64
epochs     = 100
patience   = epochs//5

test_accuracy = []
test_loss     = []
histories     = []

criterion = nn.CrossEntropyLoss()

for i, (train_idx, test_idx) in enumerate(skf.split(img_list,img_labels)):

    print('-'*50)

    X_train, X_valid, y_train, y_valid = sklearn.model_selection.train_test_split(img_list[train_idx],img_labels[train_idx],test_size=0.2,random_state=i)

    testloader = torch.utils.data.DataLoader(CCSNImageDataset(img_list[test_idx],img_labels[test_idx],data_transforms['train'],lambda x : torch.tensor(x,dtype=torch.long)),batch_size=1,shuffle=True,num_workers=8)
    trainloader= torch.utils.data.DataLoader(CCSNImageDataset(X_train,y_train,data_transforms['train'],lambda x : torch.tensor(x,dtype=torch.long)),batch_size=batch_size,shuffle=True,num_workers=8)
    validloader= torch.utils.data.DataLoader(CCSNImageDataset(X_valid,y_valid,data_transforms['val'],lambda x : torch.tensor(x,dtype=torch.long)),batch_size=batch_size,shuffle=True,num_workers=8)

    classifier = Classifier()
    classifier = classifier.to(device)
    # Observe that all parameters are being optimized
    optimizer_ft = optim.Adam(classifier.parameters())

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_ft, mode='min', factor=0.5, patience=3)

    trained_model, history = train_model(classifier, criterion, optimizer_ft,
                                         dataloaders={'train':trainloader,'val':validloader},
                                         dataset_sizes={'train':X_train.shape[0],'val':X_valid.shape[0]},
                                         patience=patience,
                                         num_epochs=epochs,
                                         scheduler = scheduler)

    histories.append(history)
    print(f'Fold {i+1:2d}',end=' ')
    loss, acc = evaluate(trained_model, testloader)

    test_loss.append(loss)
    test_accuracy.append(acc)
# Out:
# gpu is available
# --------------------------------------------------
# Epoch   0/99 train Loss: 2.4228 Acc: 0.1592 val Loss: 2.1883 Acc: 0.2015
# Epoch   1/99 train Loss: 2.2671 Acc: 0.2059 val Loss: 2.2927 Acc: 0.2334
# Epoch   2/99 train Loss: 2.2410 Acc: 0.2182 val Loss: 2.1039 Acc: 0.2678
# Epoch   3/99 train Loss: 2.2269 Acc: 0.2151 val Loss: 2.1206 Acc: 0.2850
# Epoch   4/99 train Loss: 2.1748 Acc: 0.2243 val Loss: 2.1327 Acc: 0.2482
# Epoch   5/99 train Loss: 2.1333 Acc: 0.2606 val Loss: 2.0409 Acc: 0.2850
# Epoch   6/99 train Loss: 2.1475 Acc: 0.2495 val Loss: 2.0195 Acc: 0.2998
# Epoch   7/99 train Loss: 2.1314 Acc: 0.2551 val Loss: 2.0103 Acc: 0.3170
# Epoch   8/99 train Loss: 2.0908 Acc: 0.2729 val Loss: 2.9319 Acc: 0.2506
# Epoch   9/99 train Loss: 2.1035 Acc: 0.2680 val Loss: 2.1059 Acc: 0.2727
# Epoch  10/99 train Loss: 2.0651 Acc: 0.2846 val Loss: 2.0221 Acc: 0.3194
# Epoch  11/99 train Loss: 2.0138 Acc: 0.2919 val Loss: 1.9627 Acc: 0.3292
# Epoch  12/99 train Loss: 2.0089 Acc: 0.3184 val Loss: 1.9246 Acc: 0.3243
# Epoch  13/99 train Loss: 2.0148 Acc: 0.3030 val Loss: 1.9483 Acc: 0.3268
# Epoch  14/99 train Loss: 1.9911 Acc: 0.2981 val Loss: 1.9028 Acc: 0.3292
# Epoch  15/99 train Loss: 1.9987 Acc: 0.3024 val Loss: 1.9003 Acc: 0.3563
# Epoch  16/99 train Loss: 1.9918 Acc: 0.3319 val Loss: 1.9528 Acc: 0.3292
# Epoch  17/99 train Loss: 1.9775 Acc: 0.3196 val Loss: 1.9621 Acc: 0.3243
# Epoch  18/99 train Loss: 2.0592 Acc: 0.2975 val Loss: 2.3005 Acc: 0.2113
# Epoch  19/99 train Loss: 2.1053 Acc: 0.2440 val Loss: 2.0505 Acc: 0.2604
# Epoch  20/99 train Loss: 2.0573 Acc: 0.2698 val Loss: 2.0241 Acc: 0.2678
# Epoch  21/99 train Loss: 2.0451 Acc: 0.2815 val Loss: 2.0079 Acc: 0.2727
# Epoch  22/99 train Loss: 1.9841 Acc: 0.3012 val Loss: 1.9136 Acc: 0.3342
# Epoch  23/99 train Loss: 1.9649 Acc: 0.3049 val Loss: 1.9084 Acc: 0.3317
# Epoch  24/99 train Loss: 1.9125 Acc: 0.3245 val Loss: 1.8453 Acc: 0.3735
# Epoch  25/99 train Loss: 1.9113 Acc: 0.3264 val Loss: 1.8508 Acc: 0.3759
# Epoch  26/99 train Loss: 1.9397 Acc: 0.3190 val Loss: 1.8667 Acc: 0.3440
# Epoch  27/99 train Loss: 1.9100 Acc: 0.3405 val Loss: 1.8073 Acc: 0.3808
# Epoch  28/99 train Loss: 1.8942 Acc: 0.3417 val Loss: 1.8353 Acc: 0.3661
# Epoch  29/99 train Loss: 1.8834 Acc: 0.3430 val Loss: 1.7989 Acc: 0.3808
# Epoch  30/99 train Loss: 1.8590 Acc: 0.3540 val Loss: 1.8630 Acc: 0.3538
# Epoch  31/99 train Loss: 1.8622 Acc: 0.3442 val Loss: 1.8284 Acc: 0.3956
# Epoch  32/99 train Loss: 1.8426 Acc: 0.3565 val Loss: 1.8468 Acc: 0.4005
# Epoch  33/99 train Loss: 1.8314 Acc: 0.3540 val Loss: 1.8197 Acc: 0.3686
# Epoch  34/99 train Loss: 1.8650 Acc: 0.3565 val Loss: 1.8022 Acc: 0.3686
# Epoch  35/99 train Loss: 1.8434 Acc: 0.3454 val Loss: 1.8136 Acc: 0.3931
# Epoch  36/99 train Loss: 1.8680 Acc: 0.3380 val Loss: 1.8452 Acc: 0.3808
# Epoch  37/99 train Loss: 1.8423 Acc: 0.3516 val Loss: 1.8022 Acc: 0.3907
# Epoch  38/99 train Loss: 1.7948 Acc: 0.3719 val Loss: 1.8023 Acc: 0.3587
# Epoch  39/99 train Loss: 1.8066 Acc: 0.3725 val Loss: 1.7872 Acc: 0.3907
# Epoch  40/99 train Loss: 1.8084 Acc: 0.3688 val Loss: 1.7513 Acc: 0.4201
# Epoch  41/99 train Loss: 1.7906 Acc: 0.3749 val Loss: 1.7257 Acc: 0.4103
# Epoch  42/99 train Loss: 1.7685 Acc: 0.3792 val Loss: 1.7488 Acc: 0.4005
# Epoch  43/99 train Loss: 1.7716 Acc: 0.3780 val Loss: 1.7418 Acc: 0.3956
# Epoch  44/99 train Loss: 1.7858 Acc: 0.3835 val Loss: 1.7586 Acc: 0.4275
# Epoch  45/99 train Loss: 1.7817 Acc: 0.3866 val Loss: 1.7521 Acc: 0.3686
# Epoch  46/99 train Loss: 1.7338 Acc: 0.3964 val Loss: 1.7453 Acc: 0.3931
# Epoch  47/99 train Loss: 1.7572 Acc: 0.3792 val Loss: 1.7774 Acc: 0.4029
# Epoch  48/99 train Loss: 1.7765 Acc: 0.3805 val Loss: 1.7470 Acc: 0.3808
# Epoch  49/99 train Loss: 1.7496 Acc: 0.4001 val Loss: 1.7418 Acc: 0.3808
# Epoch  50/99 train Loss: 1.7467 Acc: 0.3964 val Loss: 1.7634 Acc: 0.4103
# Epoch  51/99 train Loss: 1.7163 Acc: 0.3977 val Loss: 1.7155 Acc: 0.3980
# Epoch  52/99 train Loss: 1.7432 Acc: 0.3921 val Loss: 1.7331 Acc: 0.4103
# Epoch  53/99 train Loss: 1.6917 Acc: 0.4124 val Loss: 1.7413 Acc: 0.3956
# Epoch  54/99 train Loss: 1.7170 Acc: 0.3952 val Loss: 1.7159 Acc: 0.3931
# Epoch  55/99 train Loss: 1.6891 Acc: 0.4106 val Loss: 1.7149 Acc: 0.4103
# Epoch  56/99 train Loss: 1.6984 Acc: 0.4069 val Loss: 1.7337 Acc: 0.3907
# Epoch  57/99 train Loss: 1.6861 Acc: 0.4136 val Loss: 1.7047 Acc: 0.4177
# Epoch  58/99 train Loss: 1.6988 Acc: 0.4093 val Loss: 1.7476 Acc: 0.4152
# Epoch  59/99 train Loss: 1.6975 Acc: 0.4026 val Loss: 1.7065 Acc: 0.4201
# Epoch  60/99 train Loss: 1.7040 Acc: 0.3940 val Loss: 1.7095 Acc: 0.4275
# Epoch  61/99 train Loss: 1.6984 Acc: 0.4130 val Loss: 1.7213 Acc: 0.4226
# Epoch  62/99 train Loss: 1.6620 Acc: 0.4321 val Loss: 1.7058 Acc: 0.4177
# Epoch  63/99 train Loss: 1.6809 Acc: 0.4118 val Loss: 1.7074 Acc: 0.4251
# Epoch  64/99 train Loss: 1.6794 Acc: 0.4247 val Loss: 1.7009 Acc: 0.4201
# Epoch  65/99 train Loss: 1.6889 Acc: 0.4069 val Loss: 1.7031 Acc: 0.4152
# Epoch  66/99 train Loss: 1.7151 Acc: 0.4204 val Loss: 1.6894 Acc: 0.4201
# Epoch  67/99 train Loss: 1.6573 Acc: 0.4216 val Loss: 1.6918 Acc: 0.4373
# Epoch  68/99 train Loss: 1.6787 Acc: 0.4124 val Loss: 1.6965 Acc: 0.4079
# Epoch  69/99 train Loss: 1.6649 Acc: 0.4278 val Loss: 1.6947 Acc: 0.4251
# Epoch  70/99 train Loss: 1.6494 Acc: 0.4321 val Loss: 1.6980 Acc: 0.4201
# Epoch  71/99 train Loss: 1.6706 Acc: 0.4247 val Loss: 1.6919 Acc: 0.4251
# Epoch  72/99 train Loss: 1.6287 Acc: 0.4376 val Loss: 1.6907 Acc: 0.4152
# Epoch  73/99 train Loss: 1.6718 Acc: 0.4198 val Loss: 1.6974 Acc: 0.4324
# Epoch  74/99 train Loss: 1.6822 Acc: 0.4167 val Loss: 1.6881 Acc: 0.4324
# Epoch  75/99 train Loss: 1.6653 Acc: 0.4216 val Loss: 1.6857 Acc: 0.4177
# Epoch  76/99 train Loss: 1.6583 Acc: 0.4395 val Loss: 1.6943 Acc: 0.4226
# Epoch  77/99 train Loss: 1.6529 Acc: 0.4321 val Loss: 1.6950 Acc: 0.4349
# Epoch  78/99 train Loss: 1.6420 Acc: 0.4333 val Loss: 1.6923 Acc: 0.4275
# Epoch  79/99 train Loss: 1.6922 Acc: 0.4143 val Loss: 1.6891 Acc: 0.4226
# Epoch  80/99 train Loss: 1.6449 Acc: 0.4272 val Loss: 1.6951 Acc: 0.4226
# Epoch  81/99 train Loss: 1.6656 Acc: 0.4364 val Loss: 1.6953 Acc: 0.4226
# Epoch  82/99 train Loss: 1.6520 Acc: 0.4395 val Loss: 1.6969 Acc: 0.4201
# Epoch  83/99 train Loss: 1.6581 Acc: 0.4272 val Loss: 1.6931 Acc: 0.4201
# Epoch  84/99 train Loss: 1.6556 Acc: 0.4173 val Loss: 1.6887 Acc: 0.4226
# Epoch  85/99 train Loss: 1.6486 Acc: 0.4186 val Loss: 1.6900 Acc: 0.4275
# Epoch  86/99 train Loss: 1.6565 Acc: 0.4253 val Loss: 1.6914 Acc: 0.4251
# Epoch  87/99 train Loss: 1.6855 Acc: 0.4167 val Loss: 1.6875 Acc: 0.4300
# Epoch  88/99 train Loss: 1.6557 Acc: 0.4235 val Loss: 1.6887 Acc: 0.4251
# Epoch  89/99 train Loss: 1.6534 Acc: 0.4198 val Loss: 1.6876 Acc: 0.4226
# Epoch  90/99 train Loss: 1.6700 Acc: 0.4087 val Loss: 1.6831 Acc: 0.4300
# Epoch  91/99 train Loss: 1.6704 Acc: 0.4327 val Loss: 1.6887 Acc: 0.4201
# Epoch  92/99 train Loss: 1.6337 Acc: 0.4388 val Loss: 1.6850 Acc: 0.4251
# Epoch  93/99 train Loss: 1.6429 Acc: 0.4407 val Loss: 1.6859 Acc: 0.4226
# Epoch  94/99 train Loss: 1.6619 Acc: 0.4247 val Loss: 1.6922 Acc: 0.4275
# Epoch  95/99 train Loss: 1.6436 Acc: 0.4352 val Loss: 1.6858 Acc: 0.4201
# Epoch  96/99 train Loss: 1.6520 Acc: 0.4216 val Loss: 1.6954 Acc: 0.4226
# Epoch  97/99 train Loss: 1.6646 Acc: 0.4345 val Loss: 1.6930 Acc: 0.4275
# Epoch  98/99 train Loss: 1.6141 Acc: 0.4468 val Loss: 1.6892 Acc: 0.4300
# Epoch  99/99 train Loss: 1.6584 Acc: 0.4266 val Loss: 1.6891 Acc: 0.4226
# Training complete in 106m 20s
# Best val Acc: 0.437346
# Fold  1
# /tmp/ipykernel_264505/1696249048.py:89: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_params_path))
# test Loss: 1.8001 Acc: 0.3929
# --------------------------------------------------
# Epoch   0/99 train Loss: 2.3785 Acc: 0.1807 val Loss: 2.1662 Acc: 0.2260
# Epoch   1/99 train Loss: 2.2392 Acc: 0.2114 val Loss: 2.1015 Acc: 0.2604
# Epoch   2/99 train Loss: 2.2121 Acc: 0.2157 val Loss: 2.0810 Acc: 0.2580
# Epoch   3/99 train Loss: 2.1450 Acc: 0.2483 val Loss: 2.0141 Acc: 0.3022
# Epoch   4/99 train Loss: 2.1026 Acc: 0.2545 val Loss: 2.0258 Acc: 0.2948
# Epoch   5/99 train Loss: 2.1158 Acc: 0.2563 val Loss: 2.0778 Acc: 0.2899
# Epoch   6/99 train Loss: 2.0743 Acc: 0.2643 val Loss: 1.9589 Acc: 0.2899
# Epoch   7/99 train Loss: 2.0528 Acc: 0.2624 val Loss: 1.9810 Acc: 0.3415
# Epoch   8/99 train Loss: 2.0335 Acc: 0.3018 val Loss: 2.0175 Acc: 0.2457
# Epoch   9/99 train Loss: 2.0271 Acc: 0.2833 val Loss: 1.8988 Acc: 0.3563
# Epoch  10/99 train Loss: 1.9885 Acc: 0.2999 val Loss: 1.9033 Acc: 0.3317
# Epoch  11/99 train Loss: 1.9956 Acc: 0.3024 val Loss: 1.9363 Acc: 0.3440
# Epoch  12/99 train Loss: 1.9918 Acc: 0.3061 val Loss: 1.8891 Acc: 0.3587
# Epoch  13/99 train Loss: 1.9353 Acc: 0.3319 val Loss: 2.0107 Acc: 0.3071
# Epoch  14/99 train Loss: 1.9475 Acc: 0.3024 val Loss: 2.3223 Acc: 0.3219
# Epoch  15/99 train Loss: 1.9223 Acc: 0.3153 val Loss: 1.9329 Acc: 0.3563
# Epoch  16/99 train Loss: 1.8889 Acc: 0.3380 val Loss: 1.9070 Acc: 0.3587
# Epoch  17/99 train Loss: 1.9063 Acc: 0.3184 val Loss: 1.9774 Acc: 0.3047
# Epoch  18/99 train Loss: 1.8899 Acc: 0.3411 val Loss: 1.8393 Acc: 0.4128
# Epoch  19/99 train Loss: 1.8772 Acc: 0.3411 val Loss: 1.8408 Acc: 0.3833
# Epoch  20/99 train Loss: 1.8796 Acc: 0.3460 val Loss: 1.8353 Acc: 0.3661
# Epoch  21/99 train Loss: 1.8376 Acc: 0.3467 val Loss: 1.8102 Acc: 0.3636
# Epoch  22/99 train Loss: 1.8350 Acc: 0.3577 val Loss: 1.8412 Acc: 0.3636
# Epoch  23/99 train Loss: 1.8448 Acc: 0.3448 val Loss: 1.8285 Acc: 0.3710
# Epoch  24/99 train Loss: 1.8119 Acc: 0.3602 val Loss: 1.8014 Acc: 0.3882
# Epoch  25/99 train Loss: 1.8419 Acc: 0.3510 val Loss: 2.0413 Acc: 0.3636
# Epoch  26/99 train Loss: 1.8673 Acc: 0.3460 val Loss: 1.7835 Acc: 0.4005
# Epoch  27/99 train Loss: 1.8176 Acc: 0.3712 val Loss: 1.7472 Acc: 0.4128
# Epoch  28/99 train Loss: 1.8045 Acc: 0.3719 val Loss: 1.7698 Acc: 0.4300
# Epoch  29/99 train Loss: 1.7698 Acc: 0.3811 val Loss: 1.7769 Acc: 0.4275
# Epoch  30/99 train Loss: 1.7927 Acc: 0.3743 val Loss: 1.7689 Acc: 0.4152
# Epoch  31/99 train Loss: 1.7425 Acc: 0.3872 val Loss: 1.7807 Acc: 0.4005
# Epoch  32/99 train Loss: 1.7552 Acc: 0.3866 val Loss: 1.8725 Acc: 0.3710
# Epoch  33/99 train Loss: 1.8038 Acc: 0.3614 val Loss: 1.8278 Acc: 0.3735
# Epoch  34/99 train Loss: 1.7625 Acc: 0.3786 val Loss: 1.7934 Acc: 0.3882
# Epoch  35/99 train Loss: 1.7918 Acc: 0.3768 val Loss: 1.8406 Acc: 0.3710
# Epoch  36/99 train Loss: 1.7534 Acc: 0.3774 val Loss: 1.7186 Acc: 0.4496
# Epoch  37/99 train Loss: 1.6812 Acc: 0.4216 val Loss: 1.7257 Acc: 0.4472
# Epoch  38/99 train Loss: 1.6911 Acc: 0.4075 val Loss: 1.7343 Acc: 0.4496
# Epoch  39/99 train Loss: 1.6676 Acc: 0.4143 val Loss: 1.7484 Acc: 0.4152
# Epoch  40/99 train Loss: 1.6910 Acc: 0.4063 val Loss: 1.7718 Acc: 0.4054
# Epoch  41/99 train Loss: 1.6981 Acc: 0.4167 val Loss: 1.7110 Acc: 0.4275
# Epoch  42/99 train Loss: 1.6724 Acc: 0.4241 val Loss: 1.8657 Acc: 0.4226
# Epoch  43/99 train Loss: 1.6711 Acc: 0.4081 val Loss: 1.7185 Acc: 0.4128
# Epoch  44/99 train Loss: 1.6200 Acc: 0.4450 val Loss: 1.6992 Acc: 0.4693
# Epoch  45/99 train Loss: 1.6455 Acc: 0.4309 val Loss: 1.6946 Acc: 0.4373
# Epoch  46/99 train Loss: 1.6426 Acc: 0.4272 val Loss: 1.6727 Acc: 0.4521
# Epoch  47/99 train Loss: 1.5817 Acc: 0.4487 val Loss: 1.6883 Acc: 0.4545
# Epoch  48/99 train Loss: 1.6367 Acc: 0.4167 val Loss: 1.6834 Acc: 0.4521
# Epoch  49/99 train Loss: 1.6128 Acc: 0.4241 val Loss: 1.6809 Acc: 0.4693
# Epoch  50/99 train Loss: 1.5935 Acc: 0.4364 val Loss: 1.6759 Acc: 0.4373
# Epoch  51/99 train Loss: 1.5981 Acc: 0.4376 val Loss: 1.7046 Acc: 0.4251
# Epoch  52/99 train Loss: 1.6076 Acc: 0.4462 val Loss: 1.6632 Acc: 0.4423
# Epoch  53/99 train Loss: 1.5925 Acc: 0.4425 val Loss: 1.6802 Acc: 0.4447
# Epoch  54/99 train Loss: 1.5705 Acc: 0.4438 val Loss: 1.6636 Acc: 0.4595
# Epoch  55/99 train Loss: 1.5747 Acc: 0.4511 val Loss: 1.6745 Acc: 0.4447
# Epoch  56/99 train Loss: 1.5736 Acc: 0.4487 val Loss: 1.6671 Acc: 0.4644
# Epoch  57/99 train Loss: 1.5554 Acc: 0.4524 val Loss: 1.6637 Acc: 0.4496
# Epoch  58/99 train Loss: 1.5396 Acc: 0.4677 val Loss: 1.6756 Acc: 0.4570
# Epoch  59/99 train Loss: 1.5547 Acc: 0.4505 val Loss: 1.6706 Acc: 0.4619
# Epoch  60/99 train Loss: 1.5337 Acc: 0.4579 val Loss: 1.6624 Acc: 0.4570
# Epoch  61/99 train Loss: 1.5478 Acc: 0.4431 val Loss: 1.6516 Acc: 0.4496
# Epoch  62/99 train Loss: 1.5363 Acc: 0.4634 val Loss: 1.6684 Acc: 0.4570
# Epoch  63/99 train Loss: 1.5591 Acc: 0.4554 val Loss: 1.6783 Acc: 0.4570
# Epoch  64/99 train Loss: 1.5611 Acc: 0.4604 val Loss: 1.6666 Acc: 0.4275
# Epoch  65/99 train Loss: 1.4929 Acc: 0.4610 val Loss: 1.6521 Acc: 0.4398
# Epoch  66/99 train Loss: 1.4778 Acc: 0.4966 val Loss: 1.6516 Acc: 0.4447
# Epoch  67/99 train Loss: 1.5042 Acc: 0.4671 val Loss: 1.6503 Acc: 0.4521
# Epoch  68/99 train Loss: 1.5143 Acc: 0.4868 val Loss: 1.6636 Acc: 0.4472
# Epoch  69/99 train Loss: 1.5425 Acc: 0.4499 val Loss: 1.6503 Acc: 0.4668
# Epoch  70/99 train Loss: 1.5070 Acc: 0.4726 val Loss: 1.6529 Acc: 0.4619
# Epoch  71/99 train Loss: 1.5281 Acc: 0.4708 val Loss: 1.6616 Acc: 0.4595
# Epoch  72/99 train Loss: 1.5163 Acc: 0.4567 val Loss: 1.6645 Acc: 0.4496
# Epoch  73/99 train Loss: 1.5262 Acc: 0.4714 val Loss: 1.6706 Acc: 0.4496
# Epoch  74/99 train Loss: 1.5233 Acc: 0.4622 val Loss: 1.6633 Acc: 0.4423
# Epoch  75/99 train Loss: 1.4776 Acc: 0.4813 val Loss: 1.6634 Acc: 0.4423
# Epoch  76/99 train Loss: 1.5040 Acc: 0.4585 val Loss: 1.6654 Acc: 0.4521
# Epoch  77/99 train Loss: 1.5020 Acc: 0.4763 val Loss: 1.6729 Acc: 0.4496
# Epoch  78/99 train Loss: 1.5139 Acc: 0.4665 val Loss: 1.6724 Acc: 0.4472
# Epoch  79/99 train Loss: 1.4961 Acc: 0.4788 val Loss: 1.6642 Acc: 0.4570
# Epoch  80/99 train Loss: 1.5163 Acc: 0.4616 val Loss: 1.6666 Acc: 0.4496
# Epoch  81/99 train Loss: 1.4952 Acc: 0.4782 val Loss: 1.6686 Acc: 0.4447
# Epoch  82/99 train Loss: 1.4971 Acc: 0.4782 val Loss: 1.6608 Acc: 0.4521
# Epoch  83/99 train Loss: 1.4914 Acc: 0.4788 val Loss: 1.6655 Acc: 0.4570
# Epoch  84/99 train Loss: 1.4943 Acc: 0.4911 val Loss: 1.6649 Acc: 0.4521
# Epoch  85/99 train Loss: 1.4815 Acc: 0.4794 val Loss: 1.6631 Acc: 0.4496
# Epoch  86/99 train Loss: 1.4824 Acc: 0.4880 val Loss: 1.6607 Acc: 0.4472
# Epoch  87/99 train Loss: 1.5191 Acc: 0.4696 val Loss: 1.6672 Acc: 0.4521
# Epoch  88/99 train Loss: 1.4828 Acc: 0.4604 val Loss: 1.6688 Acc: 0.4496
# Training complete in 98m 27s
# Best val Acc: 0.469287
# Fold  2 test Loss: 1.7190 Acc: 0.4165
# --------------------------------------------------
# Epoch   0/99 train Loss: 2.3915 Acc: 0.1709 val Loss: 2.2070 Acc: 0.2260
# Epoch   1/99 train Loss: 2.2871 Acc: 0.2016 val Loss: 2.1614 Acc: 0.2260
# Epoch   2/99 train Loss: 2.2464 Acc: 0.2170 val Loss: 2.2851 Acc: 0.2113
# Epoch   3/99 train Loss: 2.1927 Acc: 0.2274 val Loss: 2.1441 Acc: 0.2457
# Epoch   4/99 train Loss: 2.1838 Acc: 0.2323 val Loss: 2.1728 Acc: 0.2432
# Epoch   5/99 train Loss: 2.1542 Acc: 0.2502 val Loss: 2.0980 Acc: 0.3071
# Epoch   6/99 train Loss: 2.1016 Acc: 0.2551 val Loss: 2.0475 Acc: 0.2826
# Epoch   7/99 train Loss: 2.0928 Acc: 0.2643 val Loss: 2.1657 Acc: 0.2580
# Epoch   8/99 train Loss: 2.0897 Acc: 0.2735 val Loss: 1.9940 Acc: 0.3071
# Epoch   9/99 train Loss: 2.0552 Acc: 0.2858 val Loss: 2.0626 Acc: 0.2998
# Epoch  10/99 train Loss: 2.0401 Acc: 0.2987 val Loss: 2.0669 Acc: 0.2826
# Epoch  11/99 train Loss: 2.0848 Acc: 0.2618 val Loss: 2.1356 Acc: 0.2629
# Epoch  12/99 train Loss: 2.0386 Acc: 0.2840 val Loss: 2.0367 Acc: 0.3071
# Epoch  13/99 train Loss: 2.0189 Acc: 0.2919 val Loss: 1.9860 Acc: 0.2948
# Epoch  14/99 train Loss: 2.0028 Acc: 0.2999 val Loss: 2.0400 Acc: 0.2801
# Epoch  15/99 train Loss: 1.9834 Acc: 0.2938 val Loss: 1.9509 Acc: 0.3391
# Epoch  16/99 train Loss: 1.9812 Acc: 0.2956 val Loss: 2.0356 Acc: 0.3268
# Epoch  17/99 train Loss: 1.9514 Acc: 0.3153 val Loss: 1.9692 Acc: 0.3096
# Epoch  18/99 train Loss: 1.9213 Acc: 0.3227 val Loss: 1.8513 Acc: 0.3686
# Epoch  19/99 train Loss: 1.9523 Acc: 0.3159 val Loss: 1.9282 Acc: 0.3440
# Epoch  20/99 train Loss: 1.9226 Acc: 0.3159 val Loss: 1.8888 Acc: 0.3538
# Epoch  21/99 train Loss: 1.8785 Acc: 0.3436 val Loss: 1.9520 Acc: 0.3391
# Epoch  22/99 train Loss: 1.9213 Acc: 0.3479 val Loss: 2.1435 Acc: 0.2850
# Epoch  23/99 train Loss: 1.9044 Acc: 0.3313 val Loss: 1.8960 Acc: 0.3292
# Epoch  24/99 train Loss: 1.9132 Acc: 0.3233 val Loss: 1.9622 Acc: 0.3022
# Epoch  25/99 train Loss: 1.8931 Acc: 0.3239 val Loss: 1.8851 Acc: 0.3661
# Epoch  26/99 train Loss: 1.8485 Acc: 0.3608 val Loss: 1.8840 Acc: 0.3661
# Epoch  27/99 train Loss: 1.8119 Acc: 0.3663 val Loss: 1.8479 Acc: 0.3833
# Epoch  28/99 train Loss: 1.7940 Acc: 0.3706 val Loss: 1.8590 Acc: 0.3808
# Epoch  29/99 train Loss: 1.7950 Acc: 0.3688 val Loss: 1.8169 Acc: 0.3735
# Epoch  30/99 train Loss: 1.7737 Acc: 0.3774 val Loss: 1.8389 Acc: 0.3980
# Epoch  31/99 train Loss: 1.7858 Acc: 0.3675 val Loss: 1.8132 Acc: 0.3833
# Epoch  32/99 train Loss: 1.7900 Acc: 0.3743 val Loss: 1.8290 Acc: 0.3759
# Epoch  33/99 train Loss: 1.7856 Acc: 0.3731 val Loss: 1.8439 Acc: 0.3661
# Epoch  34/99 train Loss: 1.8154 Acc: 0.3669 val Loss: 1.7945 Acc: 0.4079
# Epoch  35/99 train Loss: 1.7867 Acc: 0.3688 val Loss: 1.7895 Acc: 0.4275
# Epoch  36/99 train Loss: 1.7665 Acc: 0.3835 val Loss: 1.7943 Acc: 0.4029
# Epoch  37/99 train Loss: 1.7347 Acc: 0.4063 val Loss: 1.7797 Acc: 0.4054
# Epoch  38/99 train Loss: 1.7617 Acc: 0.3921 val Loss: 1.8045 Acc: 0.4128
# Epoch  39/99 train Loss: 1.7369 Acc: 0.4026 val Loss: 1.7869 Acc: 0.4226
# Epoch  40/99 train Loss: 1.7381 Acc: 0.3946 val Loss: 1.7777 Acc: 0.4251
# Epoch  41/99 train Loss: 1.7491 Acc: 0.4081 val Loss: 1.7687 Acc: 0.4275
# Epoch  42/99 train Loss: 1.7283 Acc: 0.3909 val Loss: 1.7613 Acc: 0.4079
# Epoch  43/99 train Loss: 1.7157 Acc: 0.3977 val Loss: 1.7674 Acc: 0.4300
# Epoch  44/99 train Loss: 1.7007 Acc: 0.4044 val Loss: 1.7446 Acc: 0.4324
# Epoch  45/99 train Loss: 1.6934 Acc: 0.4161 val Loss: 1.7530 Acc: 0.4275
# Epoch  46/99 train Loss: 1.7057 Acc: 0.4093 val Loss: 1.7526 Acc: 0.4324
# Epoch  47/99 train Loss: 1.7054 Acc: 0.4143 val Loss: 1.7576 Acc: 0.4128
# Epoch  48/99 train Loss: 1.6862 Acc: 0.4020 val Loss: 1.7496 Acc: 0.4275
# Epoch  49/99 train Loss: 1.6717 Acc: 0.4266 val Loss: 1.7657 Acc: 0.4275
# Epoch  50/99 train Loss: 1.6694 Acc: 0.4100 val Loss: 1.7502 Acc: 0.4226
# Epoch  51/99 train Loss: 1.6741 Acc: 0.4198 val Loss: 1.7746 Acc: 0.4079
# Epoch  52/99 train Loss: 1.6769 Acc: 0.4210 val Loss: 1.7467 Acc: 0.4349
# Epoch  53/99 train Loss: 1.6816 Acc: 0.4241 val Loss: 1.7244 Acc: 0.4054
# Epoch  54/99 train Loss: 1.6671 Acc: 0.4290 val Loss: 1.7199 Acc: 0.4251
# Epoch  55/99 train Loss: 1.6803 Acc: 0.4278 val Loss: 1.7275 Acc: 0.4275
# Epoch  56/99 train Loss: 1.6663 Acc: 0.4130 val Loss: 1.7348 Acc: 0.4152
# Epoch  57/99 train Loss: 1.6457 Acc: 0.4315 val Loss: 1.7405 Acc: 0.4128
# Epoch  58/99 train Loss: 1.6615 Acc: 0.4302 val Loss: 1.7252 Acc: 0.4349
# Epoch  59/99 train Loss: 1.6913 Acc: 0.4032 val Loss: 1.7182 Acc: 0.4373
# Epoch  60/99 train Loss: 1.6578 Acc: 0.4204 val Loss: 1.7332 Acc: 0.4226
# Epoch  61/99 train Loss: 1.6629 Acc: 0.4241 val Loss: 1.7138 Acc: 0.4275
# Epoch  62/99 train Loss: 1.6185 Acc: 0.4302 val Loss: 1.7157 Acc: 0.4324
# Epoch  63/99 train Loss: 1.5932 Acc: 0.4388 val Loss: 1.7198 Acc: 0.4300
# Epoch  64/99 train Loss: 1.6311 Acc: 0.4179 val Loss: 1.7255 Acc: 0.4324
# Epoch  65/99 train Loss: 1.6538 Acc: 0.4364 val Loss: 1.7178 Acc: 0.4275
# Epoch  66/99 train Loss: 1.6483 Acc: 0.4339 val Loss: 1.7204 Acc: 0.4226
# Epoch  67/99 train Loss: 1.6196 Acc: 0.4315 val Loss: 1.7232 Acc: 0.4349
# Epoch  68/99 train Loss: 1.6284 Acc: 0.4456 val Loss: 1.7097 Acc: 0.4423
# Epoch  69/99 train Loss: 1.6398 Acc: 0.4222 val Loss: 1.7230 Acc: 0.4373
# Epoch  70/99 train Loss: 1.6318 Acc: 0.4364 val Loss: 1.7132 Acc: 0.4324
# Epoch  71/99 train Loss: 1.6256 Acc: 0.4370 val Loss: 1.7180 Acc: 0.4423
# Epoch  72/99 train Loss: 1.6397 Acc: 0.4296 val Loss: 1.7237 Acc: 0.4300
# Epoch  73/99 train Loss: 1.6140 Acc: 0.4266 val Loss: 1.7141 Acc: 0.4373
# Epoch  74/99 train Loss: 1.6368 Acc: 0.4253 val Loss: 1.7162 Acc: 0.4275
# Epoch  75/99 train Loss: 1.5968 Acc: 0.4499 val Loss: 1.7163 Acc: 0.4496
# Epoch  76/99 train Loss: 1.6131 Acc: 0.4401 val Loss: 1.7167 Acc: 0.4349
# Epoch  77/99 train Loss: 1.6240 Acc: 0.4352 val Loss: 1.7134 Acc: 0.4201
# Epoch  78/99 train Loss: 1.6273 Acc: 0.4382 val Loss: 1.7141 Acc: 0.4324
# Epoch  79/99 train Loss: 1.6122 Acc: 0.4481 val Loss: 1.7128 Acc: 0.4373
# Epoch  80/99 train Loss: 1.6272 Acc: 0.4382 val Loss: 1.7119 Acc: 0.4373
# Epoch  81/99 train Loss: 1.6449 Acc: 0.4253 val Loss: 1.7106 Acc: 0.4398
# Epoch  82/99 train Loss: 1.6118 Acc: 0.4431 val Loss: 1.7065 Acc: 0.4349
# Epoch  83/99 train Loss: 1.6060 Acc: 0.4376 val Loss: 1.7107 Acc: 0.4324
# Epoch  84/99 train Loss: 1.6465 Acc: 0.4388 val Loss: 1.7011 Acc: 0.4324
# Epoch  85/99 train Loss: 1.6019 Acc: 0.4413 val Loss: 1.7068 Acc: 0.4324
# Epoch  86/99 train Loss: 1.5868 Acc: 0.4554 val Loss: 1.7093 Acc: 0.4324
# Epoch  87/99 train Loss: 1.6155 Acc: 0.4401 val Loss: 1.7088 Acc: 0.4472
# Epoch  88/99 train Loss: 1.6044 Acc: 0.4388 val Loss: 1.7099 Acc: 0.4300
# Epoch  89/99 train Loss: 1.6318 Acc: 0.4395 val Loss: 1.7152 Acc: 0.4275
# Epoch  90/99 train Loss: 1.6160 Acc: 0.4444 val Loss: 1.7128 Acc: 0.4300
# Epoch  91/99 train Loss: 1.6057 Acc: 0.4419 val Loss: 1.7106 Acc: 0.4349
# Epoch  92/99 train Loss: 1.6109 Acc: 0.4413 val Loss: 1.7044 Acc: 0.4373
# Epoch  93/99 train Loss: 1.6107 Acc: 0.4370 val Loss: 1.7100 Acc: 0.4300
# Epoch  94/99 train Loss: 1.5999 Acc: 0.4597 val Loss: 1.7069 Acc: 0.4349
# Epoch  95/99 train Loss: 1.5973 Acc: 0.4511 val Loss: 1.7065 Acc: 0.4373
# Epoch  96/99 train Loss: 1.6323 Acc: 0.4352 val Loss: 1.7055 Acc: 0.4324
# Epoch  97/99 train Loss: 1.6038 Acc: 0.4487 val Loss: 1.7119 Acc: 0.4275
# Epoch  98/99 train Loss: 1.6120 Acc: 0.4419 val Loss: 1.7103 Acc: 0.4398
# Epoch  99/99 train Loss: 1.6373 Acc: 0.4358 val Loss: 1.7150 Acc: 0.4472
# Training complete in 107m 51s
# Best val Acc: 0.449631
# Fold  3 test Loss: 1.7704 Acc: 0.4185
# --------------------------------------------------
# Epoch   0/99 train Loss: 2.4111 Acc: 0.1609 val Loss: 2.1890 Acc: 0.2531
# Epoch   1/99 train Loss: 2.2468 Acc: 0.2119 val Loss: 2.1471 Acc: 0.2629
# Epoch   2/99 train Loss: 2.2143 Acc: 0.2168 val Loss: 2.0635 Acc: 0.2752
# Epoch   3/99 train Loss: 2.1191 Acc: 0.2623 val Loss: 2.1191 Acc: 0.2776
# Epoch   4/99 train Loss: 2.1486 Acc: 0.2506 val Loss: 2.1011 Acc: 0.2604
# Epoch   5/99 train Loss: 2.1116 Acc: 0.2408 val Loss: 2.0532 Acc: 0.2727
# Epoch   6/99 train Loss: 2.0682 Acc: 0.2967 val Loss: 2.1020 Acc: 0.2850
# Epoch   7/99 train Loss: 2.0500 Acc: 0.2813 val Loss: 2.2624 Acc: 0.2776
# Epoch   8/99 train Loss: 2.0887 Acc: 0.2684 val Loss: 2.0638 Acc: 0.2826
# Epoch   9/99 train Loss: 2.0853 Acc: 0.2819 val Loss: 2.0677 Acc: 0.3219
# Epoch  10/99 train Loss: 2.0530 Acc: 0.2948 val Loss: 1.9663 Acc: 0.2973
# Epoch  11/99 train Loss: 2.0322 Acc: 0.2819 val Loss: 2.0798 Acc: 0.2924
# Epoch  12/99 train Loss: 2.0662 Acc: 0.2875 val Loss: 2.0114 Acc: 0.2948
# Epoch  13/99 train Loss: 2.0328 Acc: 0.2991 val Loss: 1.9806 Acc: 0.2924
# Epoch  14/99 train Loss: 1.9918 Acc: 0.2942 val Loss: 1.9713 Acc: 0.3268
# Epoch  15/99 train Loss: 1.9954 Acc: 0.2905 val Loss: 1.9301 Acc: 0.3661
# Epoch  16/99 train Loss: 1.9860 Acc: 0.2991 val Loss: 1.9990 Acc: 0.3071
# Epoch  17/99 train Loss: 1.9574 Acc: 0.3225 val Loss: 1.9102 Acc: 0.3071
# Epoch  18/99 train Loss: 1.9181 Acc: 0.3305 val Loss: 1.9025 Acc: 0.3489
# Epoch  19/99 train Loss: 1.9312 Acc: 0.3292 val Loss: 1.8409 Acc: 0.3686
# Epoch  20/99 train Loss: 1.9500 Acc: 0.3360 val Loss: 2.3723 Acc: 0.3096
# Epoch  21/99 train Loss: 1.9201 Acc: 0.3249 val Loss: 1.8784 Acc: 0.3563
# Epoch  22/99 train Loss: 1.9168 Acc: 0.3249 val Loss: 1.7887 Acc: 0.3882
# Epoch  23/99 train Loss: 1.8890 Acc: 0.3495 val Loss: 1.8303 Acc: 0.3563
# Epoch  24/99 train Loss: 1.9053 Acc: 0.3335 val Loss: 1.8600 Acc: 0.3710
# Epoch  25/99 train Loss: 1.8762 Acc: 0.3292 val Loss: 1.8929 Acc: 0.3243
# Epoch  26/99 train Loss: 1.8870 Acc: 0.3483 val Loss: 1.7908 Acc: 0.3931
# Epoch  27/99 train Loss: 1.8626 Acc: 0.3606 val Loss: 1.8210 Acc: 0.3563
# Epoch  28/99 train Loss: 1.8604 Acc: 0.3520 val Loss: 1.8832 Acc: 0.3514
# Epoch  29/99 train Loss: 1.8608 Acc: 0.3501 val Loss: 1.7868 Acc: 0.3833
# Epoch  30/99 train Loss: 1.8132 Acc: 0.3735 val Loss: 1.8637 Acc: 0.3661
# Epoch  31/99 train Loss: 1.8550 Acc: 0.3655 val Loss: 1.7778 Acc: 0.4005
# Epoch  32/99 train Loss: 1.8580 Acc: 0.3495 val Loss: 2.0787 Acc: 0.3292
# Epoch  33/99 train Loss: 1.8436 Acc: 0.3501 val Loss: 1.8642 Acc: 0.3833
# Epoch  34/99 train Loss: 1.8052 Acc: 0.3802 val Loss: 1.9313 Acc: 0.3710
# Epoch  35/99 train Loss: 1.8141 Acc: 0.3821 val Loss: 1.7879 Acc: 0.4029
# Epoch  36/99 train Loss: 1.8190 Acc: 0.3814 val Loss: 1.9824 Acc: 0.3612
# Epoch  37/99 train Loss: 1.7869 Acc: 0.3741 val Loss: 1.8079 Acc: 0.3686
# Epoch  38/99 train Loss: 1.8228 Acc: 0.3686 val Loss: 1.7711 Acc: 0.4128
# Epoch  39/99 train Loss: 1.8348 Acc: 0.3649 val Loss: 1.8955 Acc: 0.3514
# Epoch  40/99 train Loss: 1.8119 Acc: 0.3827 val Loss: 1.7660 Acc: 0.3980
# Epoch  41/99 train Loss: 1.7648 Acc: 0.3950 val Loss: 1.8414 Acc: 0.3735
# Epoch  42/99 train Loss: 1.7942 Acc: 0.3882 val Loss: 1.7962 Acc: 0.3735
# Epoch  43/99 train Loss: 1.7939 Acc: 0.3808 val Loss: 1.7272 Acc: 0.4177
# Epoch  44/99 train Loss: 1.7672 Acc: 0.3925 val Loss: 1.7471 Acc: 0.4177
# Epoch  45/99 train Loss: 1.7801 Acc: 0.4005 val Loss: 2.0057 Acc: 0.3415
# Epoch  46/99 train Loss: 1.8009 Acc: 0.3778 val Loss: 2.0599 Acc: 0.4005
# Epoch  47/99 train Loss: 1.7339 Acc: 0.3968 val Loss: 1.7159 Acc: 0.4079
# Epoch  48/99 train Loss: 1.7045 Acc: 0.4091 val Loss: 1.7372 Acc: 0.4226
# Epoch  49/99 train Loss: 1.7087 Acc: 0.4140 val Loss: 1.7427 Acc: 0.4152
# Epoch  50/99 train Loss: 1.6864 Acc: 0.4263 val Loss: 1.7289 Acc: 0.4251
# Epoch  51/99 train Loss: 1.6537 Acc: 0.4134 val Loss: 1.6999 Acc: 0.4128
# Epoch  52/99 train Loss: 1.6886 Acc: 0.4165 val Loss: 1.7643 Acc: 0.4177
# Epoch  53/99 train Loss: 1.6576 Acc: 0.4324 val Loss: 1.7394 Acc: 0.4226
# Epoch  54/99 train Loss: 1.6278 Acc: 0.4478 val Loss: 1.7952 Acc: 0.4029
# Epoch  55/99 train Loss: 1.6892 Acc: 0.4355 val Loss: 1.7634 Acc: 0.3882
# Epoch  56/99 train Loss: 1.6812 Acc: 0.4312 val Loss: 1.7610 Acc: 0.4029
# Epoch  57/99 train Loss: 1.6987 Acc: 0.4195 val Loss: 1.7411 Acc: 0.4079
# Epoch  58/99 train Loss: 1.6553 Acc: 0.4269 val Loss: 1.6893 Acc: 0.4349
# Epoch  59/99 train Loss: 1.6146 Acc: 0.4466 val Loss: 1.6910 Acc: 0.4177
# Epoch  60/99 train Loss: 1.6237 Acc: 0.4404 val Loss: 1.6691 Acc: 0.4472
# Epoch  61/99 train Loss: 1.6001 Acc: 0.4459 val Loss: 1.6603 Acc: 0.4447
# Epoch  62/99 train Loss: 1.5928 Acc: 0.4545 val Loss: 1.6873 Acc: 0.4226
# Epoch  63/99 train Loss: 1.6281 Acc: 0.4380 val Loss: 1.6616 Acc: 0.4349
# Epoch  64/99 train Loss: 1.6208 Acc: 0.4392 val Loss: 1.6664 Acc: 0.4324
# Epoch  65/99 train Loss: 1.6048 Acc: 0.4484 val Loss: 1.7130 Acc: 0.4300
# Epoch  66/99 train Loss: 1.5868 Acc: 0.4527 val Loss: 1.6609 Acc: 0.4324
# Epoch  67/99 train Loss: 1.5701 Acc: 0.4429 val Loss: 1.6687 Acc: 0.4423
# Epoch  68/99 train Loss: 1.5908 Acc: 0.4527 val Loss: 1.6731 Acc: 0.4373
# Epoch  69/99 train Loss: 1.5953 Acc: 0.4576 val Loss: 1.6947 Acc: 0.4103
# Epoch  70/99 train Loss: 1.5978 Acc: 0.4570 val Loss: 1.6789 Acc: 0.4251
# Epoch  71/99 train Loss: 1.5603 Acc: 0.4558 val Loss: 1.6905 Acc: 0.4128
# Epoch  72/99 train Loss: 1.5942 Acc: 0.4509 val Loss: 1.6473 Acc: 0.4275
# Epoch  73/99 train Loss: 1.5917 Acc: 0.4533 val Loss: 1.6704 Acc: 0.4349
# Epoch  74/99 train Loss: 1.5668 Acc: 0.4662 val Loss: 1.6720 Acc: 0.4521
# Epoch  75/99 train Loss: 1.5657 Acc: 0.4681 val Loss: 1.6618 Acc: 0.4373
# Epoch  76/99 train Loss: 1.5265 Acc: 0.4889 val Loss: 1.6421 Acc: 0.4398
# Epoch  77/99 train Loss: 1.5371 Acc: 0.4619 val Loss: 1.6559 Acc: 0.4472
# Epoch  78/99 train Loss: 1.5464 Acc: 0.4693 val Loss: 1.6426 Acc: 0.4349
# Epoch  79/99 train Loss: 1.5008 Acc: 0.5025 val Loss: 1.6602 Acc: 0.4251
# Epoch  80/99 train Loss: 1.5304 Acc: 0.4607 val Loss: 1.6514 Acc: 0.4349
# Epoch  81/99 train Loss: 1.5112 Acc: 0.4822 val Loss: 1.6574 Acc: 0.4447
# Epoch  82/99 train Loss: 1.5236 Acc: 0.4699 val Loss: 1.6341 Acc: 0.4521
# Epoch  83/99 train Loss: 1.4929 Acc: 0.4902 val Loss: 1.6357 Acc: 0.4545
# Epoch  84/99 train Loss: 1.5222 Acc: 0.4748 val Loss: 1.6285 Acc: 0.4521
# Epoch  85/99 train Loss: 1.4957 Acc: 0.4914 val Loss: 1.6414 Acc: 0.4324
# Epoch  86/99 train Loss: 1.5141 Acc: 0.4779 val Loss: 1.6259 Acc: 0.4545
# Epoch  87/99 train Loss: 1.5119 Acc: 0.4779 val Loss: 1.6381 Acc: 0.4472
# Epoch  88/99 train Loss: 1.4810 Acc: 0.4969 val Loss: 1.6410 Acc: 0.4398
# Epoch  89/99 train Loss: 1.5140 Acc: 0.4699 val Loss: 1.6437 Acc: 0.4521
# Epoch  90/99 train Loss: 1.5053 Acc: 0.4975 val Loss: 1.6408 Acc: 0.4496
# Epoch  91/99 train Loss: 1.4745 Acc: 0.5018 val Loss: 1.6316 Acc: 0.4521
# Epoch  92/99 train Loss: 1.4353 Acc: 0.5129 val Loss: 1.6336 Acc: 0.4521
# Epoch  93/99 train Loss: 1.4719 Acc: 0.4914 val Loss: 1.6444 Acc: 0.4496
# Epoch  94/99 train Loss: 1.4864 Acc: 0.4889 val Loss: 1.6252 Acc: 0.4545
# Epoch  95/99 train Loss: 1.4603 Acc: 0.4957 val Loss: 1.6270 Acc: 0.4496
# Epoch  96/99 train Loss: 1.4555 Acc: 0.4896 val Loss: 1.6323 Acc: 0.4423
# Epoch  97/99 train Loss: 1.4573 Acc: 0.4896 val Loss: 1.6336 Acc: 0.4545
# Epoch  98/99 train Loss: 1.4618 Acc: 0.4908 val Loss: 1.6323 Acc: 0.4349
# Epoch  99/99 train Loss: 1.4811 Acc: 0.4920 val Loss: 1.6370 Acc: 0.4423
# Training complete in 106m 15s
# Best val Acc: 0.454545
# Fold  4 test Loss: 1.8545 Acc: 0.3839
# --------------------------------------------------
# Epoch   0/99 train Loss: 2.3489 Acc: 0.1886 val Loss: 2.2099 Acc: 0.2088
# Epoch   1/99 train Loss: 2.2567 Acc: 0.2107 val Loss: 2.1896 Acc: 0.2531
# Epoch   2/99 train Loss: 2.2171 Acc: 0.2297 val Loss: 2.1538 Acc: 0.2187
# Epoch   3/99 train Loss: 2.1910 Acc: 0.2322 val Loss: 2.1801 Acc: 0.2211
# Epoch   4/99 train Loss: 2.1543 Acc: 0.2316 val Loss: 2.1158 Acc: 0.2776
# Epoch   5/99 train Loss: 2.1430 Acc: 0.2469 val Loss: 2.1441 Acc: 0.2654
# Epoch   6/99 train Loss: 2.1272 Acc: 0.2402 val Loss: 2.0916 Acc: 0.2604
# Epoch   7/99 train Loss: 2.1019 Acc: 0.2647 val Loss: 2.1979 Acc: 0.2531
# Epoch   8/99 train Loss: 2.1147 Acc: 0.2752 val Loss: 2.1133 Acc: 0.2408
# Epoch   9/99 train Loss: 2.0775 Acc: 0.2832 val Loss: 2.0954 Acc: 0.2555
# Epoch  10/99 train Loss: 2.0872 Acc: 0.2770 val Loss: 2.1777 Acc: 0.2408
# Epoch  11/99 train Loss: 2.0605 Acc: 0.2862 val Loss: 2.0579 Acc: 0.2875
# Epoch  12/99 train Loss: 2.0384 Acc: 0.2783 val Loss: 2.0197 Acc: 0.2801
# Epoch  13/99 train Loss: 2.0199 Acc: 0.2899 val Loss: 2.1378 Acc: 0.2948
# Epoch  14/99 train Loss: 2.0485 Acc: 0.2850 val Loss: 2.0990 Acc: 0.2776
# Epoch  15/99 train Loss: 2.0883 Acc: 0.2795 val Loss: 2.1626 Acc: 0.2285
# Epoch  16/99 train Loss: 2.0679 Acc: 0.2844 val Loss: 2.0322 Acc: 0.2924
# Epoch  17/99 train Loss: 2.0404 Acc: 0.2856 val Loss: 2.0084 Acc: 0.3170
# Epoch  18/99 train Loss: 1.9814 Acc: 0.3127 val Loss: 1.9747 Acc: 0.3145
# Epoch  19/99 train Loss: 1.9707 Acc: 0.3151 val Loss: 1.8890 Acc: 0.3587
# Epoch  20/99 train Loss: 1.9410 Acc: 0.3354 val Loss: 2.0009 Acc: 0.2948
# Epoch  21/99 train Loss: 1.9362 Acc: 0.3213 val Loss: 1.8890 Acc: 0.3464
# Epoch  22/99 train Loss: 1.9127 Acc: 0.3348 val Loss: 1.9153 Acc: 0.3415
# Epoch  23/99 train Loss: 1.9153 Acc: 0.3446 val Loss: 1.9008 Acc: 0.3464
# Epoch  24/99 train Loss: 1.8760 Acc: 0.3514 val Loss: 1.8891 Acc: 0.3514
# Epoch  25/99 train Loss: 1.8769 Acc: 0.3563 val Loss: 1.8654 Acc: 0.3563
# Epoch  26/99 train Loss: 1.8729 Acc: 0.3372 val Loss: 1.8978 Acc: 0.3636
# Epoch  27/99 train Loss: 1.8601 Acc: 0.3673 val Loss: 1.9128 Acc: 0.3268
# Epoch  28/99 train Loss: 1.8611 Acc: 0.3643 val Loss: 1.9884 Acc: 0.2973
# Epoch  29/99 train Loss: 1.8965 Acc: 0.3385 val Loss: 1.8748 Acc: 0.3342
# Epoch  30/99 train Loss: 1.9023 Acc: 0.3262 val Loss: 1.8200 Acc: 0.3735
# Epoch  31/99 train Loss: 1.8260 Acc: 0.3624 val Loss: 1.8283 Acc: 0.3808
# Epoch  32/99 train Loss: 1.8343 Acc: 0.3661 val Loss: 1.8485 Acc: 0.3735
# Epoch  33/99 train Loss: 1.8321 Acc: 0.3526 val Loss: 1.8325 Acc: 0.3612
# Epoch  34/99 train Loss: 1.8444 Acc: 0.3630 val Loss: 1.8899 Acc: 0.3464
# Epoch  35/99 train Loss: 1.8130 Acc: 0.3833 val Loss: 1.8044 Acc: 0.3710
# Epoch  36/99 train Loss: 1.8129 Acc: 0.3722 val Loss: 1.8609 Acc: 0.3563
# Epoch  37/99 train Loss: 1.8290 Acc: 0.3692 val Loss: 1.8027 Acc: 0.3857
# Epoch  38/99 train Loss: 1.7948 Acc: 0.3864 val Loss: 1.7993 Acc: 0.3907
# Epoch  39/99 train Loss: 1.7734 Acc: 0.4054 val Loss: 1.8420 Acc: 0.3538
# Epoch  40/99 train Loss: 1.8184 Acc: 0.3771 val Loss: 1.7995 Acc: 0.3980
# Epoch  41/99 train Loss: 1.7964 Acc: 0.3876 val Loss: 1.9056 Acc: 0.3464
# Epoch  42/99 train Loss: 1.7866 Acc: 0.3839 val Loss: 1.7727 Acc: 0.3686
# Epoch  43/99 train Loss: 1.7470 Acc: 0.3962 val Loss: 1.7887 Acc: 0.3980
# Epoch  44/99 train Loss: 1.7555 Acc: 0.4017 val Loss: 1.8137 Acc: 0.3808
# Epoch  45/99 train Loss: 1.7696 Acc: 0.3851 val Loss: 1.8281 Acc: 0.3587
# Epoch  46/99 train Loss: 1.7884 Acc: 0.3937 val Loss: 1.7627 Acc: 0.3980
# Epoch  47/99 train Loss: 1.7565 Acc: 0.4054 val Loss: 1.7949 Acc: 0.3759
# Epoch  48/99 train Loss: 1.7174 Acc: 0.4085 val Loss: 1.7898 Acc: 0.4005
# Epoch  49/99 train Loss: 1.6860 Acc: 0.4183 val Loss: 1.7562 Acc: 0.3857
# Epoch  50/99 train Loss: 1.7422 Acc: 0.4097 val Loss: 1.7556 Acc: 0.3833
# Epoch  51/99 train Loss: 1.7058 Acc: 0.4201 val Loss: 1.7363 Acc: 0.3784
# Epoch  52/99 train Loss: 1.6860 Acc: 0.4232 val Loss: 1.7450 Acc: 0.3956
# Epoch  53/99 train Loss: 1.7143 Acc: 0.4189 val Loss: 1.7785 Acc: 0.3833
# Epoch  54/99 train Loss: 1.6713 Acc: 0.4287 val Loss: 1.7338 Acc: 0.3907
# Epoch  55/99 train Loss: 1.6480 Acc: 0.4318 val Loss: 1.7427 Acc: 0.3931
# Epoch  56/99 train Loss: 1.6430 Acc: 0.4392 val Loss: 1.7231 Acc: 0.3931
# Epoch  57/99 train Loss: 1.6635 Acc: 0.4263 val Loss: 1.7441 Acc: 0.4103
# Epoch  58/99 train Loss: 1.6712 Acc: 0.4152 val Loss: 1.7247 Acc: 0.4005
# Epoch  59/99 train Loss: 1.6596 Acc: 0.4281 val Loss: 1.7297 Acc: 0.3980
# Epoch  60/99 train Loss: 1.6400 Acc: 0.4294 val Loss: 1.7315 Acc: 0.4177
# Epoch  61/99 train Loss: 1.6575 Acc: 0.4300 val Loss: 1.7146 Acc: 0.3882
# Epoch  62/99 train Loss: 1.6084 Acc: 0.4490 val Loss: 1.7199 Acc: 0.4152
# Epoch  63/99 train Loss: 1.6561 Acc: 0.4343 val Loss: 1.7469 Acc: 0.4177
# Epoch  64/99 train Loss: 1.6576 Acc: 0.4165 val Loss: 1.7277 Acc: 0.4005
# Epoch  65/99 train Loss: 1.6464 Acc: 0.4232 val Loss: 1.7061 Acc: 0.4128
# Epoch  66/99 train Loss: 1.6495 Acc: 0.4251 val Loss: 1.7013 Acc: 0.4054
# Epoch  67/99 train Loss: 1.6461 Acc: 0.4269 val Loss: 1.7245 Acc: 0.4079
# Epoch  68/99 train Loss: 1.6375 Acc: 0.4416 val Loss: 1.7182 Acc: 0.4128
# Epoch  69/99 train Loss: 1.6125 Acc: 0.4380 val Loss: 1.7134 Acc: 0.4201
# Epoch  70/99 train Loss: 1.6270 Acc: 0.4496 val Loss: 1.7136 Acc: 0.4054
# Epoch  71/99 train Loss: 1.6102 Acc: 0.4484 val Loss: 1.6991 Acc: 0.4251
# Epoch  72/99 train Loss: 1.6086 Acc: 0.4490 val Loss: 1.6944 Acc: 0.4251
# Epoch  73/99 train Loss: 1.5948 Acc: 0.4564 val Loss: 1.6943 Acc: 0.4201
# Epoch  74/99 train Loss: 1.6200 Acc: 0.4539 val Loss: 1.6997 Acc: 0.4275
# Epoch  75/99 train Loss: 1.5826 Acc: 0.4490 val Loss: 1.7007 Acc: 0.4201
# Epoch  76/99 train Loss: 1.6319 Acc: 0.4429 val Loss: 1.6964 Acc: 0.4275
# Epoch  77/99 train Loss: 1.5696 Acc: 0.4509 val Loss: 1.7093 Acc: 0.4029
# Epoch  78/99 train Loss: 1.5726 Acc: 0.4564 val Loss: 1.7076 Acc: 0.4103
# Epoch  79/99 train Loss: 1.5696 Acc: 0.4453 val Loss: 1.7091 Acc: 0.4079
# Epoch  80/99 train Loss: 1.5949 Acc: 0.4521 val Loss: 1.7042 Acc: 0.4079
# Epoch  81/99 train Loss: 1.5981 Acc: 0.4490 val Loss: 1.7000 Acc: 0.4226
# Epoch  82/99 train Loss: 1.5979 Acc: 0.4539 val Loss: 1.6981 Acc: 0.4251
# Epoch  83/99 train Loss: 1.5930 Acc: 0.4576 val Loss: 1.6959 Acc: 0.4079
# Epoch  84/99 train Loss: 1.5770 Acc: 0.4674 val Loss: 1.6996 Acc: 0.4152
# Epoch  85/99 train Loss: 1.5962 Acc: 0.4582 val Loss: 1.6995 Acc: 0.4226
# Epoch  86/99 train Loss: 1.6091 Acc: 0.4588 val Loss: 1.6960 Acc: 0.4226
# Epoch  87/99 train Loss: 1.5444 Acc: 0.4681 val Loss: 1.6928 Acc: 0.4226
# Epoch  88/99 train Loss: 1.5870 Acc: 0.4582 val Loss: 1.6992 Acc: 0.4226
# Epoch  89/99 train Loss: 1.5867 Acc: 0.4478 val Loss: 1.6940 Acc: 0.4226
# Epoch  90/99 train Loss: 1.5971 Acc: 0.4367 val Loss: 1.6971 Acc: 0.4300
# Epoch  91/99 train Loss: 1.5754 Acc: 0.4668 val Loss: 1.6970 Acc: 0.4275
# Epoch  92/99 train Loss: 1.5769 Acc: 0.4662 val Loss: 1.6943 Acc: 0.4226
# Epoch  93/99 train Loss: 1.6035 Acc: 0.4545 val Loss: 1.7007 Acc: 0.4275
# Epoch  94/99 train Loss: 1.5852 Acc: 0.4509 val Loss: 1.6929 Acc: 0.4152
# Epoch  95/99 train Loss: 1.5771 Acc: 0.4570 val Loss: 1.6986 Acc: 0.4226
# Epoch  96/99 train Loss: 1.5853 Acc: 0.4607 val Loss: 1.6977 Acc: 0.4226
# Epoch  97/99 train Loss: 1.5606 Acc: 0.4656 val Loss: 1.7014 Acc: 0.4128
# Epoch  98/99 train Loss: 1.5724 Acc: 0.4484 val Loss: 1.6955 Acc: 0.4152
# Epoch  99/99 train Loss: 1.5714 Acc: 0.4539 val Loss: 1.7014 Acc: 0.4251
# Training complete in 104m 5s
# Best val Acc: 0.429975
# Fold  5 test Loss: 1.7096 Acc: 0.4173

# %%
print(classifier)
# Out:
# Classifier(
#   (cnn_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (self_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=11, bias=True)
#   )
# )

# %% [markdown]
# ### 顯示結果

# %%
plt.figure(figsize=(8,3*len(histories)))

max_loss = 0
max_acc  = 0
for i,history in enumerate(histories):
    max_loss = max(max_loss,np.max(history['loss']),np.max(history['val_loss']))

max_loss *= 1.05
for i,history in enumerate(histories):
    plt.subplot(len(histories),2,i*2+1)
    plt.title(f'fold:{i+1}')
    plt.plot(history['loss'],label='train')
    plt.plot(history['val_loss'],label='valid')
    plt.xlabel('epoch')
    step = int(np.ceil(len(history['loss'])/5))
    plt.xticks(np.arange(0,len(history['loss']),step),[str(u+1) for u in np.arange(0,len(history['loss']),step)])
    plt.ylabel('loss')
    plt.ylim([0,max_loss])
    plt.grid(True)
    plt.legend()

    plt.subplot(len(histories),2,i*2+2)
    plt.title(f'fold:{i+1}')
    plt.plot(history['accuracy'],label='train')
    plt.plot(history['val_accuracy'],label='valid')
    plt.xticks(np.arange(0,len(history['accuracy']),step),[str(u+1) for u in np.arange(0,len(history['accuracy']),step)])
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.ylim([0,1.0])
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()

plt.figure()
plt.bar(x=np.arange(len(test_accuracy)),height=np.array(test_accuracy))
plt.xlabel('fold')
plt.xticks(np.arange(len(test_accuracy)),[str(i+1) for i in np.arange(len(test_accuracy))])
plt.ylabel('accuracy')
plt.title(f'average accuracy rate:{np.mean(np.array(test_accuracy)):.3f}+/-{np.std(np.array(test_accuracy)):.3f}')
plt.grid(True)
plt.ylim([0,1.0])
plt.show()
print(f'average accuracy rate:{np.mean(np.array(test_accuracy)):.3f}+/-{np.std(np.array(test_accuracy)):.3f}')
# Out:
# average accuracy rate:0.406+/-0.015
