# %% [markdown]
# ### PyTorch官方參考範例
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %%
import os
import glob
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import torchvision
import time
from PIL import Image

def CCSN_images(dataset_dir):
    classfolder = glob.glob(os.path.join(dataset_dir,"*"),recursive=True)
    class_name  = [f.split(os.path.sep)[-1] for f in classfolder]
    img_labels  = []
    img_list    = []

    for class_id, f in enumerate(classfolder):
        files = glob.glob(os.path.join(f,"*.jpg"),recursive=True)
        img_labels.extend([class_id]*len(files))
        img_list.extend(files)

    img_labels = np.array(img_labels)
    img_list   = np.array(img_list,dtype=object)

    return img_list.reshape((-1,1)), img_labels, class_name

# %% [markdown]
# ### 定義Dataset

# %%
class CCSNImageDataset(torch.utils.data.Dataset):
    def __init__(self, img_list, img_labels, transform=None, target_transform=None):
        self.transform        = transform
        self.target_transform = target_transform
        self.img_list         = img_list
        self.img_labels       = img_labels

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = self.img_list[idx,0]
        image    = Image.open(img_path)
        label    = self.img_labels[idx]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %% [markdown]
# ### 設定CCSN資料集路徑
# 例如:
# ![image.png](attachment:image.png)

# %%
CCSNDataset_Path = "CCSN_v2"
img_list, img_labels, label_names = CCSN_images(CCSNDataset_Path)

CCSNDataset = CCSNImageDataset(img_list,img_labels)

# %% [markdown]
# ### 範例:透過Dataset載入並顯示部分資料集

# %%
N = len(CCSNDataset)

plt.figure(figsize=(16,8))

for i in range(16):
    plt.subplot(4,8,i+1)
    image, label = CCSNDataset[np.random.randint(0,N)]
    plt.imshow(image)
    plt.title(label_names[label])
    plt.axis(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 使用預訓練模型
# 列出torchvision.models裡內建預訓練模型。

# %%
import torchvision
dir(torchvision.models)
# Out:
# ['AlexNet',
#  'AlexNet_Weights',
#  'ConvNeXt',
#  'ConvNeXt_Base_Weights',
#  'ConvNeXt_Large_Weights',
#  'ConvNeXt_Small_Weights',
#  'ConvNeXt_Tiny_Weights',
#  'DenseNet',
#  'DenseNet121_Weights',
#  'DenseNet161_Weights',
#  'DenseNet169_Weights',
#  'DenseNet201_Weights',
#  'EfficientNet',
#  'EfficientNet_B0_Weights',
#  'EfficientNet_B1_Weights',
#  'EfficientNet_B2_Weights',
#  'EfficientNet_B3_Weights',
#  'EfficientNet_B4_Weights',
#  'EfficientNet_B5_Weights',
#  'EfficientNet_B6_Weights',
#  'EfficientNet_B7_Weights',
#  'EfficientNet_V2_L_Weights',
#  'EfficientNet_V2_M_Weights',
#  'EfficientNet_V2_S_Weights',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'GoogLeNet_Weights',
#  'Inception3',
#  'InceptionOutputs',
#  'Inception_V3_Weights',
#  'MNASNet',
#  'MNASNet0_5_Weights',
#  'MNASNet0_75_Weights',
#  'MNASNet1_0_Weights',
#  'MNASNet1_3_Weights',
#  'MaxVit',
#  'MaxVit_T_Weights',
#  'MobileNetV2',
#  'MobileNetV3',
#  'MobileNet_V2_Weights',
#  'MobileNet_V3_Large_Weights',
#  'MobileNet_V3_Small_Weights',
#  'RegNet',
#  'RegNet_X_16GF_Weights',
#  'RegNet_X_1_6GF_Weights',
#  'RegNet_X_32GF_Weights',
#  'RegNet_X_3_2GF_Weights',
#  'RegNet_X_400MF_Weights',
#  'RegNet_X_800MF_Weights',
#  'RegNet_X_8GF_Weights',
#  'RegNet_Y_128GF_Weights',
#  'RegNet_Y_16GF_Weights',
#  'RegNet_Y_1_6GF_Weights',
#  'RegNet_Y_32GF_Weights',
#  'RegNet_Y_3_2GF_Weights',
#  'RegNet_Y_400MF_Weights',
#  'RegNet_Y_800MF_Weights',
#  'RegNet_Y_8GF_Weights',
#  'ResNeXt101_32X8D_Weights',
#  'ResNeXt101_64X4D_Weights',
#  'ResNeXt50_32X4D_Weights',
#  'ResNet',
#  'ResNet101_Weights',
#  'ResNet152_Weights',
#  'ResNet18_Weights',
#  'ResNet34_Weights',
#  'ResNet50_Weights',
#  'ShuffleNetV2',
#  'ShuffleNet_V2_X0_5_Weights',
#  'ShuffleNet_V2_X1_0_Weights',
#  'ShuffleNet_V2_X1_5_Weights',
#  'ShuffleNet_V2_X2_0_Weights',
#  'SqueezeNet',
#  'SqueezeNet1_0_Weights',
#  'SqueezeNet1_1_Weights',
#  'SwinTransformer',
#  'Swin_B_Weights',
#  'Swin_S_Weights',
#  'Swin_T_Weights',
#  'Swin_V2_B_Weights',
#  'Swin_V2_S_Weights',
#  'Swin_V2_T_Weights',
#  'VGG',
#  'VGG11_BN_Weights',
#  'VGG11_Weights',
#  'VGG13_BN_Weights',
#  'VGG13_Weights',
#  'VGG16_BN_Weights',
#  'VGG16_Weights',
#  'VGG19_BN_Weights',
#  'VGG19_Weights',
#  'ViT_B_16_Weights',
#  'ViT_B_32_Weights',
#  'ViT_H_14_Weights',
#  'ViT_L_16_Weights',
#  'ViT_L_32_Weights',
#  'VisionTransformer',
#  'Weights',
#  'WeightsEnum',
#  'Wide_ResNet101_2_Weights',
#  'Wide_ResNet50_2_Weights',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_api',
#  '_meta',
#  '_utils',
#  'alexnet',
#  'convnext',
#  'convnext_base',
#  'convnext_large',
#  'convnext_small',
#  'convnext_tiny',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'efficientnet',
#  'efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b2',
#  'efficientnet_b3',
#  'efficientnet_b4',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'efficientnet_v2_l',
#  'efficientnet_v2_m',
#  'efficientnet_v2_s',
#  'get_model',
#  'get_model_builder',
#  'get_model_weights',
#  'get_weight',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'list_models',
#  'maxvit',
#  'maxvit_t',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
#  'mobilenet_v3_small',
#  'mobilenetv2',
#  'mobilenetv3',
#  'optical_flow',
#  'quantization',
#  'regnet',
#  'regnet_x_16gf',
#  'regnet_x_1_6gf',
#  'regnet_x_32gf',
#  'regnet_x_3_2gf',
#  'regnet_x_400mf',
#  'regnet_x_800mf',
#  'regnet_x_8gf',
#  'regnet_y_128gf',
#  'regnet_y_16gf',
#  'regnet_y_1_6gf',
#  'regnet_y_32gf',
#  'regnet_y_3_2gf',
#  'regnet_y_400mf',
#  'regnet_y_800mf',
#  'regnet_y_8gf',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext101_64x4d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'shufflenetv2',
#  'squeezenet',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'swin_b',
#  'swin_s',
#  'swin_t',
#  'swin_transformer',
#  'swin_v2_b',
#  'swin_v2_s',
#  'swin_v2_t',
#  'vgg',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'video',
#  'vision_transformer',
#  'vit_b_16',
#  'vit_b_32',
#  'vit_h_14',
#  'vit_l_16',
#  'vit_l_32',
#  'wide_resnet101_2',
#  'wide_resnet50_2']

# %%
from tempfile import TemporaryDirectory

def train_model(model, criterion, optimizer, dataloaders, dataset_sizes, num_epochs=25, patience = 0,scheduler = None):

    device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model = model.to(device)

    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_loss = None
        best_acc  = 0
        history = {'loss':[],'accuracy':[],'val_loss':[],'val_accuracy':[]}
        patience_c = 0
        for epoch in range(num_epochs):
            print(f'Epoch {epoch:3d}/{num_epochs - 1}',end=' ')

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                if phase == 'train' and scheduler:
                    scheduler.step(epoch_loss)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}',end=' ' if phase=='train' else '\n')
                if phase == 'train':
                    history['loss'].append(epoch_loss)
                    history['accuracy'].append(epoch_acc.cpu().numpy())

                # deep copy the model
                if phase == 'val':
                    history['val_loss'].append(epoch_loss)
                    history['val_accuracy'].append(epoch_acc.cpu().numpy())
                    if best_acc < epoch_acc.cpu().numpy():
                        best_acc = epoch_acc.cpu().numpy()
                    if epoch == 0 or epoch_loss < best_loss:
                        best_loss = epoch_loss
                        patience_c= 0
                        torch.save(model.state_dict(), best_model_params_path)
                    else:
                        patience_c += 1

            if patience_c > patience:
                break

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model, history

def evaluate(model, dataloader):

    device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model.eval()   # Set model to evaluate mode

    running_loss = 0.0
    running_corrects = 0
    dataset_size     = 0
        # Iterate over data.
    for inputs, labels in dataloader:

        dataset_size += inputs.size(0)

        inputs = inputs.to(device)
        labels = labels.to(device)

        # forward
        # track history if only in train
        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        # statistics
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / dataset_size
    epoch_acc = running_corrects.double() / dataset_size

    print(f'test Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return epoch_loss, epoch_acc.cpu().numpy()

# %% [markdown]
# ### MyClassifierModel

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        # The arguments for commonly used modules:
        # torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        # torch.nn.MaxPool2d(kernel_size, stride, padding)
        
        self.cnn_layers = nn.Sequential(
            # 3 * 224 * 224 -> 64 * 111 * 111
            nn.Conv2d(3, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            nn.Conv2d(32, 64, 3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            # 64 * 111 * 111 -> 128 * 54 * 54
            nn.Conv2d(64, 128, 3),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            # 128 * 54 * 54 -> 256 * 26 * 26
            nn.Conv2d(128, 256, 3),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.MaxPool2d(kernel_size=2),
        )
        
        #self-attention layer
        self.self_attn = nn.MultiheadAttention(embed_dim=256, num_heads=2, batch_first=True)

        self.fc_layers = nn.Sequential(
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),
            nn.Linear(256, 11),
        )

    def forward(self, x):
        # input (x): [batch_size, 3, 128, 128]
        # output: [batch_size, 11]

        # Extract features by convolutional layers.
        x = self.cnn_layers(x)

        # output -> [batch_size, 256 ,26 ,26] -> [batch_size, 512, 26*26] -> [batch_size, 26*26, 512]
        x = x.view(x.size(0), 256, -1).permute(0, 2, 1)  

        # output -> [batch_size, 26*26, 256]
        x, _ = self.self_attn(x, x, x)

        # global average pooling,output -> [batch_size, 256]
        x = x.mean(dim=1)  

        # The features are transformed by fully-connected layers to obtain the final logits.
        x = self.fc_layers(x)
        return x

# %%
from sklearn.model_selection import StratifiedKFold

device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

if torch.cuda.is_available():
    print('gpu is available')
else:
    print('cpu only')

data_transforms = {
    'train': torchvision.transforms.Compose([
        torchvision.transforms.RandomRotation(40),
        torchvision.transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        torchvision.transforms.RandomResizedCrop(224),
        torchvision.transforms.RandomHorizontalFlip(),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.CenterCrop(224),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

skf        = StratifiedKFold(n_splits=5, shuffle=True, random_state=0) # 80 % for training and validation sets, 20 % for the test set

batch_size = 64
epochs     = 100
patience   = epochs//5

test_accuracy = []
test_loss     = []
histories     = []

criterion = nn.CrossEntropyLoss()

for i, (train_idx, test_idx) in enumerate(skf.split(img_list,img_labels)):

    print('-'*50)

    X_train, X_valid, y_train, y_valid = sklearn.model_selection.train_test_split(img_list[train_idx],img_labels[train_idx],test_size=0.2,random_state=i)

    testloader = torch.utils.data.DataLoader(CCSNImageDataset(img_list[test_idx],img_labels[test_idx],data_transforms['train'],lambda x : torch.tensor(x,dtype=torch.long)),batch_size=1,shuffle=True)
    trainloader= torch.utils.data.DataLoader(CCSNImageDataset(X_train,y_train,data_transforms['train'],lambda x : torch.tensor(x,dtype=torch.long)),batch_size=batch_size,shuffle=True)
    validloader= torch.utils.data.DataLoader(CCSNImageDataset(X_valid,y_valid,data_transforms['val'],lambda x : torch.tensor(x,dtype=torch.long)),batch_size=batch_size,shuffle=True)

    classifier = Classifier()
    for name, param in classifier.self_attn.named_parameters():
        param.requires_grad = False
    for name, param in classifier.named_parameters():
        print(name, param.requires_grad)
    classifier = classifier.to(device)
    # Observe that all parameters are being optimized
    optimizer_ft = optim.Adam(classifier.parameters(), lr=0.001, weight_decay=1e-4)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_ft, mode='min', factor=0.5, patience=3)

    trained_model, history = train_model(classifier, criterion, optimizer_ft,
                                         dataloaders={'train':trainloader,'val':validloader},
                                         dataset_sizes={'train':X_train.shape[0],'val':X_valid.shape[0]},
                                         patience=patience,
                                         num_epochs=epochs,
                                         scheduler = scheduler)

    histories.append(history)
    print(f'Fold {i+1:2d}',end=' ')
    loss, acc = evaluate(trained_model, testloader)

    test_loss.append(loss)
    test_accuracy.append(acc)
# Out:
# gpu is available
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.3861 Acc: 0.1746 val Loss: 2.1896 Acc: 0.2383
# Epoch   1/99 train Loss: 2.2905 Acc: 0.2188 val Loss: 2.0728 Acc: 0.2899
# Epoch   2/99 train Loss: 2.2204 Acc: 0.2372 val Loss: 2.0634 Acc: 0.2776
# Epoch   3/99 train Loss: 2.2201 Acc: 0.2145 val Loss: 2.0661 Acc: 0.2752
# Epoch   4/99 train Loss: 2.1396 Acc: 0.2557 val Loss: 1.9373 Acc: 0.3342
# Epoch   5/99 train Loss: 2.1640 Acc: 0.2667 val Loss: 1.9859 Acc: 0.3145
# Epoch   6/99 train Loss: 2.1252 Acc: 0.2508 val Loss: 2.0014 Acc: 0.3071
# Epoch   7/99 train Loss: 2.1221 Acc: 0.2489 val Loss: 1.9713 Acc: 0.3440
# Epoch   8/99 train Loss: 2.0879 Acc: 0.2643 val Loss: 1.9473 Acc: 0.3538
# Epoch   9/99 train Loss: 2.0611 Acc: 0.2821 val Loss: 1.9365 Acc: 0.3440
# Epoch  10/99 train Loss: 2.0398 Acc: 0.2913 val Loss: 1.8964 Acc: 0.3342
# Epoch  11/99 train Loss: 2.0636 Acc: 0.2919 val Loss: 1.9237 Acc: 0.3317
# Epoch  12/99 train Loss: 2.0369 Acc: 0.2876 val Loss: 1.9835 Acc: 0.3268
# Epoch  13/99 train Loss: 2.0442 Acc: 0.2797 val Loss: 1.9187 Acc: 0.3440
# Epoch  14/99 train Loss: 1.9949 Acc: 0.3147 val Loss: 1.8803 Acc: 0.3317
# Epoch  15/99 train Loss: 2.0009 Acc: 0.3110 val Loss: 1.8588 Acc: 0.3391
# Epoch  16/99 train Loss: 1.9846 Acc: 0.2987 val Loss: 1.8994 Acc: 0.3686
# Epoch  17/99 train Loss: 1.9751 Acc: 0.3159 val Loss: 1.8338 Acc: 0.3686
# Epoch  18/99 train Loss: 1.9772 Acc: 0.3092 val Loss: 1.8174 Acc: 0.3686
# Epoch  19/99 train Loss: 1.9601 Acc: 0.3171 val Loss: 1.8202 Acc: 0.4029
# Epoch  20/99 train Loss: 1.9593 Acc: 0.3202 val Loss: 1.8388 Acc: 0.3514
# Epoch  21/99 train Loss: 1.9343 Acc: 0.3239 val Loss: 1.8830 Acc: 0.3514
# Epoch  22/99 train Loss: 1.9352 Acc: 0.3141 val Loss: 1.7746 Acc: 0.4152
# Epoch  23/99 train Loss: 1.9530 Acc: 0.3165 val Loss: 1.8712 Acc: 0.3538
# Epoch  24/99 train Loss: 1.9155 Acc: 0.3344 val Loss: 1.7784 Acc: 0.3857
# Epoch  25/99 train Loss: 1.8978 Acc: 0.3319 val Loss: 1.8353 Acc: 0.3735
# Epoch  26/99 train Loss: 1.8991 Acc: 0.3331 val Loss: 1.8065 Acc: 0.3735
# Epoch  27/99 train Loss: 1.8985 Acc: 0.3356 val Loss: 1.8669 Acc: 0.3710
# Epoch  28/99 train Loss: 1.8943 Acc: 0.3319 val Loss: 1.8148 Acc: 0.3759
# Epoch  29/99 train Loss: 1.8779 Acc: 0.3319 val Loss: 1.7668 Acc: 0.3980
# Epoch  30/99 train Loss: 1.8646 Acc: 0.3608 val Loss: 1.7637 Acc: 0.4128
# Epoch  31/99 train Loss: 1.8733 Acc: 0.3411 val Loss: 1.7623 Acc: 0.4177
# Epoch  32/99 train Loss: 1.8388 Acc: 0.3467 val Loss: 1.7887 Acc: 0.3808
# Epoch  33/99 train Loss: 1.8453 Acc: 0.3460 val Loss: 1.7523 Acc: 0.4152
# Epoch  34/99 train Loss: 1.8339 Acc: 0.3411 val Loss: 1.7494 Acc: 0.4128
# Epoch  35/99 train Loss: 1.8294 Acc: 0.3571 val Loss: 1.7273 Acc: 0.4201
# Epoch  36/99 train Loss: 1.8471 Acc: 0.3589 val Loss: 1.7711 Acc: 0.4152
# Epoch  37/99 train Loss: 1.8400 Acc: 0.3442 val Loss: 1.7307 Acc: 0.4177
# Epoch  38/99 train Loss: 1.8299 Acc: 0.3632 val Loss: 1.7035 Acc: 0.4373
# Epoch  39/99 train Loss: 1.8197 Acc: 0.3626 val Loss: 1.7481 Acc: 0.4251
# Epoch  40/99 train Loss: 1.8403 Acc: 0.3479 val Loss: 1.7385 Acc: 0.3980
# Epoch  41/99 train Loss: 1.8031 Acc: 0.3706 val Loss: 1.7544 Acc: 0.4177
# Epoch  42/99 train Loss: 1.8000 Acc: 0.3626 val Loss: 1.7606 Acc: 0.4128
# Epoch  43/99 train Loss: 1.8364 Acc: 0.3553 val Loss: 1.8359 Acc: 0.3735
# Epoch  44/99 train Loss: 1.8121 Acc: 0.3700 val Loss: 1.7330 Acc: 0.4226
# Epoch  45/99 train Loss: 1.8051 Acc: 0.3559 val Loss: 1.6796 Acc: 0.4521
# Epoch  46/99 train Loss: 1.7485 Acc: 0.3903 val Loss: 1.6727 Acc: 0.4300
# Epoch  47/99 train Loss: 1.7849 Acc: 0.3860 val Loss: 1.6751 Acc: 0.4324
# Epoch  48/99 train Loss: 1.7972 Acc: 0.3620 val Loss: 1.7125 Acc: 0.4103
# Epoch  49/99 train Loss: 1.7994 Acc: 0.3774 val Loss: 1.7061 Acc: 0.4226
# Epoch  50/99 train Loss: 1.7594 Acc: 0.4014 val Loss: 1.7221 Acc: 0.4152
# Epoch  51/99 train Loss: 1.7704 Acc: 0.3663 val Loss: 1.6602 Acc: 0.4324
# Epoch  52/99 train Loss: 1.7166 Acc: 0.4057 val Loss: 1.6340 Acc: 0.4693
# Epoch  53/99 train Loss: 1.7079 Acc: 0.4130 val Loss: 1.6385 Acc: 0.4472
# Epoch  54/99 train Loss: 1.7019 Acc: 0.4143 val Loss: 1.6288 Acc: 0.4423
# Epoch  55/99 train Loss: 1.7497 Acc: 0.3921 val Loss: 1.6626 Acc: 0.4472
# Epoch  56/99 train Loss: 1.6947 Acc: 0.4075 val Loss: 1.6309 Acc: 0.4472
# Epoch  57/99 train Loss: 1.6759 Acc: 0.4173 val Loss: 1.6202 Acc: 0.4545
# Epoch  58/99 train Loss: 1.7311 Acc: 0.3989 val Loss: 1.6303 Acc: 0.4619
# Epoch  59/99 train Loss: 1.6756 Acc: 0.4186 val Loss: 1.6284 Acc: 0.4619
# Epoch  60/99 train Loss: 1.6859 Acc: 0.4247 val Loss: 1.5921 Acc: 0.4545
# Epoch  61/99 train Loss: 1.6841 Acc: 0.4290 val Loss: 1.5934 Acc: 0.4447
# Epoch  62/99 train Loss: 1.7194 Acc: 0.4001 val Loss: 1.5856 Acc: 0.4668
# Epoch  63/99 train Loss: 1.6791 Acc: 0.4124 val Loss: 1.6062 Acc: 0.4742
# Epoch  64/99 train Loss: 1.6735 Acc: 0.4069 val Loss: 1.5996 Acc: 0.4570
# Epoch  65/99 train Loss: 1.6530 Acc: 0.4284 val Loss: 1.5975 Acc: 0.4595
# Epoch  66/99 train Loss: 1.6236 Acc: 0.4431 val Loss: 1.5945 Acc: 0.4742
# Epoch  67/99 train Loss: 1.6627 Acc: 0.4259 val Loss: 1.5833 Acc: 0.4816
# Epoch  68/99 train Loss: 1.6417 Acc: 0.4272 val Loss: 1.5884 Acc: 0.4742
# Epoch  69/99 train Loss: 1.6331 Acc: 0.4241 val Loss: 1.5658 Acc: 0.4816
# Epoch  70/99 train Loss: 1.6456 Acc: 0.4235 val Loss: 1.5754 Acc: 0.4595
# Epoch  71/99 train Loss: 1.6159 Acc: 0.4370 val Loss: 1.5700 Acc: 0.4767
# Epoch  72/99 train Loss: 1.5796 Acc: 0.4444 val Loss: 1.5627 Acc: 0.4767
# Epoch  73/99 train Loss: 1.6181 Acc: 0.4229 val Loss: 1.5570 Acc: 0.4914
# Epoch  74/99 train Loss: 1.5915 Acc: 0.4505 val Loss: 1.5592 Acc: 0.4914
# Epoch  75/99 train Loss: 1.6076 Acc: 0.4493 val Loss: 1.5487 Acc: 0.4767
# Epoch  76/99 train Loss: 1.5952 Acc: 0.4597 val Loss: 1.5517 Acc: 0.4865
# Epoch  77/99 train Loss: 1.5804 Acc: 0.4462 val Loss: 1.5512 Acc: 0.4816
# Epoch  78/99 train Loss: 1.5902 Acc: 0.4524 val Loss: 1.5550 Acc: 0.4717
# Epoch  79/99 train Loss: 1.5800 Acc: 0.4450 val Loss: 1.5394 Acc: 0.4767
# Epoch  80/99 train Loss: 1.5742 Acc: 0.4597 val Loss: 1.5422 Acc: 0.4717
# Epoch  81/99 train Loss: 1.5854 Acc: 0.4634 val Loss: 1.5421 Acc: 0.4767
# Epoch  82/99 train Loss: 1.5926 Acc: 0.4431 val Loss: 1.5386 Acc: 0.4865
# Epoch  83/99 train Loss: 1.5725 Acc: 0.4505 val Loss: 1.5453 Acc: 0.4767
# Epoch  84/99 train Loss: 1.5733 Acc: 0.4431 val Loss: 1.5403 Acc: 0.4742
# Epoch  85/99 train Loss: 1.5396 Acc: 0.4628 val Loss: 1.5458 Acc: 0.4988
# Epoch  86/99 train Loss: 1.5652 Acc: 0.4419 val Loss: 1.5449 Acc: 0.4742
# Epoch  87/99 train Loss: 1.5598 Acc: 0.4554 val Loss: 1.5444 Acc: 0.5012
# Epoch  88/99 train Loss: 1.5496 Acc: 0.4616 val Loss: 1.5389 Acc: 0.4865
# Epoch  89/99 train Loss: 1.5539 Acc: 0.4561 val Loss: 1.5402 Acc: 0.4865
# Epoch  90/99 train Loss: 1.5915 Acc: 0.4474 val Loss: 1.5374 Acc: 0.4840
# Epoch  91/99 train Loss: 1.5748 Acc: 0.4444 val Loss: 1.5422 Acc: 0.4742
# Epoch  92/99 train Loss: 1.5490 Acc: 0.4739 val Loss: 1.5446 Acc: 0.4742
# Epoch  93/99 train Loss: 1.5708 Acc: 0.4487 val Loss: 1.5366 Acc: 0.4816
# Epoch  94/99 train Loss: 1.5600 Acc: 0.4597 val Loss: 1.5376 Acc: 0.4865
# Epoch  95/99 train Loss: 1.5737 Acc: 0.4604 val Loss: 1.5352 Acc: 0.4816
# Epoch  96/99 train Loss: 1.5511 Acc: 0.4677 val Loss: 1.5356 Acc: 0.4840
# Epoch  97/99 train Loss: 1.5898 Acc: 0.4456 val Loss: 1.5345 Acc: 0.4914
# Epoch  98/99 train Loss: 1.5789 Acc: 0.4499 val Loss: 1.5349 Acc: 0.4963
# Epoch  99/99 train Loss: 1.5588 Acc: 0.4542 val Loss: 1.5402 Acc: 0.5012
# Training complete in 143m 21s
# Best val Acc: 0.501229
# Fold  1 test Loss: 1.7860 Acc: 0.4008
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.4228 Acc: 0.1524 val Loss: 2.2117 Acc: 0.2334
# Epoch   1/99 train Loss: 2.2782 Acc: 0.2016 val Loss: 2.1106 Acc: 0.2580
# Epoch   2/99 train Loss: 2.2687 Acc: 0.1991 val Loss: 2.0821 Acc: 0.3317
# Epoch   3/99 train Loss: 2.2189 Acc: 0.2225 val Loss: 2.0202 Acc: 0.2826
# Epoch   4/99 train Loss: 2.1509 Acc: 0.2483 val Loss: 2.0121 Acc: 0.3120
# Epoch   5/99 train Loss: 2.1339 Acc: 0.2551 val Loss: 2.0145 Acc: 0.2998
# Epoch   6/99 train Loss: 2.0983 Acc: 0.2409 val Loss: 2.0047 Acc: 0.2703
# Epoch   7/99 train Loss: 2.0882 Acc: 0.2741 val Loss: 2.0069 Acc: 0.2826
# Epoch   8/99 train Loss: 2.0812 Acc: 0.2766 val Loss: 1.8755 Acc: 0.3415
# Epoch   9/99 train Loss: 2.0453 Acc: 0.2778 val Loss: 1.9283 Acc: 0.3170
# Epoch  10/99 train Loss: 2.0403 Acc: 0.2778 val Loss: 1.9746 Acc: 0.2924
# Epoch  11/99 train Loss: 2.0112 Acc: 0.3098 val Loss: 1.8635 Acc: 0.3661
# Epoch  12/99 train Loss: 2.0166 Acc: 0.3012 val Loss: 1.9343 Acc: 0.3219
# Epoch  13/99 train Loss: 2.0032 Acc: 0.3073 val Loss: 1.9039 Acc: 0.3759
# Epoch  14/99 train Loss: 1.9842 Acc: 0.2981 val Loss: 1.8954 Acc: 0.3587
# Epoch  15/99 train Loss: 1.9560 Acc: 0.3258 val Loss: 1.8316 Acc: 0.3784
# Epoch  16/99 train Loss: 1.9605 Acc: 0.3036 val Loss: 1.8792 Acc: 0.3636
# Epoch  17/99 train Loss: 1.9590 Acc: 0.3018 val Loss: 1.8435 Acc: 0.3882
# Epoch  18/99 train Loss: 1.9595 Acc: 0.3233 val Loss: 1.8106 Acc: 0.3931
# Epoch  19/99 train Loss: 1.9501 Acc: 0.3153 val Loss: 1.8230 Acc: 0.3931
# Epoch  20/99 train Loss: 1.9126 Acc: 0.3258 val Loss: 1.8436 Acc: 0.3833
# Epoch  21/99 train Loss: 1.9067 Acc: 0.3374 val Loss: 1.8410 Acc: 0.4054
# Epoch  22/99 train Loss: 1.9011 Acc: 0.3380 val Loss: 1.8334 Acc: 0.3857
# Epoch  23/99 train Loss: 1.8935 Acc: 0.3350 val Loss: 1.8232 Acc: 0.3587
# Epoch  24/99 train Loss: 1.8752 Acc: 0.3331 val Loss: 1.8007 Acc: 0.3931
# Epoch  25/99 train Loss: 1.8896 Acc: 0.3399 val Loss: 1.8061 Acc: 0.3563
# Epoch  26/99 train Loss: 1.8768 Acc: 0.3307 val Loss: 1.8065 Acc: 0.3980
# Epoch  27/99 train Loss: 1.9036 Acc: 0.3417 val Loss: 1.7989 Acc: 0.3759
# Epoch  28/99 train Loss: 1.8878 Acc: 0.3510 val Loss: 1.8193 Acc: 0.3882
# Epoch  29/99 train Loss: 1.8477 Acc: 0.3460 val Loss: 1.7519 Acc: 0.4275
# Epoch  30/99 train Loss: 1.8154 Acc: 0.3688 val Loss: 1.7802 Acc: 0.3931
# Epoch  31/99 train Loss: 1.7933 Acc: 0.3811 val Loss: 1.7629 Acc: 0.4054
# Epoch  32/99 train Loss: 1.8184 Acc: 0.3589 val Loss: 1.7595 Acc: 0.3956
# Epoch  33/99 train Loss: 1.7945 Acc: 0.3706 val Loss: 1.7702 Acc: 0.3956
# Epoch  34/99 train Loss: 1.7599 Acc: 0.3731 val Loss: 1.7166 Acc: 0.4128
# Epoch  35/99 train Loss: 1.7791 Acc: 0.3811 val Loss: 1.7289 Acc: 0.4177
# Epoch  36/99 train Loss: 1.7813 Acc: 0.3829 val Loss: 1.7661 Acc: 0.3956
# Epoch  37/99 train Loss: 1.7705 Acc: 0.3841 val Loss: 1.7502 Acc: 0.4177
# Epoch  38/99 train Loss: 1.7756 Acc: 0.3854 val Loss: 1.7979 Acc: 0.3857
# Epoch  39/99 train Loss: 1.7896 Acc: 0.3719 val Loss: 1.7450 Acc: 0.4275
# Epoch  40/99 train Loss: 1.7435 Acc: 0.3927 val Loss: 1.7250 Acc: 0.4251
# Epoch  41/99 train Loss: 1.7311 Acc: 0.3841 val Loss: 1.7022 Acc: 0.4300
# Epoch  42/99 train Loss: 1.7235 Acc: 0.4063 val Loss: 1.7040 Acc: 0.4300
# Epoch  43/99 train Loss: 1.7069 Acc: 0.4007 val Loss: 1.6841 Acc: 0.4472
# Epoch  44/99 train Loss: 1.6972 Acc: 0.4081 val Loss: 1.7008 Acc: 0.4423
# Epoch  45/99 train Loss: 1.6688 Acc: 0.4075 val Loss: 1.7353 Acc: 0.4373
# Epoch  46/99 train Loss: 1.7036 Acc: 0.4007 val Loss: 1.6892 Acc: 0.4275
# Epoch  47/99 train Loss: 1.7065 Acc: 0.4050 val Loss: 1.7149 Acc: 0.4423
# Epoch  48/99 train Loss: 1.7159 Acc: 0.3970 val Loss: 1.6984 Acc: 0.4447
# Epoch  49/99 train Loss: 1.7048 Acc: 0.4026 val Loss: 1.7073 Acc: 0.4226
# Epoch  50/99 train Loss: 1.7000 Acc: 0.3995 val Loss: 1.6793 Acc: 0.4349
# Epoch  51/99 train Loss: 1.6620 Acc: 0.4075 val Loss: 1.6830 Acc: 0.4447
# Epoch  52/99 train Loss: 1.6748 Acc: 0.4173 val Loss: 1.6622 Acc: 0.4373
# Epoch  53/99 train Loss: 1.6726 Acc: 0.4216 val Loss: 1.6753 Acc: 0.4398
# Epoch  54/99 train Loss: 1.6566 Acc: 0.4124 val Loss: 1.6798 Acc: 0.4447
# Epoch  55/99 train Loss: 1.6451 Acc: 0.4296 val Loss: 1.6724 Acc: 0.4472
# Epoch  56/99 train Loss: 1.6502 Acc: 0.4130 val Loss: 1.6663 Acc: 0.4447
# Epoch  57/99 train Loss: 1.6710 Acc: 0.4050 val Loss: 1.6660 Acc: 0.4373
# Epoch  58/99 train Loss: 1.6628 Acc: 0.4339 val Loss: 1.6713 Acc: 0.4472
# Epoch  59/99 train Loss: 1.6448 Acc: 0.4229 val Loss: 1.6804 Acc: 0.4472
# Epoch  60/99 train Loss: 1.6457 Acc: 0.4339 val Loss: 1.6760 Acc: 0.4472
# Epoch  61/99 train Loss: 1.6562 Acc: 0.4179 val Loss: 1.6662 Acc: 0.4423
# Epoch  62/99 train Loss: 1.6427 Acc: 0.4229 val Loss: 1.6675 Acc: 0.4398
# Epoch  63/99 train Loss: 1.6595 Acc: 0.4198 val Loss: 1.6670 Acc: 0.4545
# Epoch  64/99 train Loss: 1.6262 Acc: 0.4309 val Loss: 1.6811 Acc: 0.4570
# Epoch  65/99 train Loss: 1.6232 Acc: 0.4431 val Loss: 1.6630 Acc: 0.4619
# Epoch  66/99 train Loss: 1.6359 Acc: 0.4155 val Loss: 1.6726 Acc: 0.4472
# Epoch  67/99 train Loss: 1.6545 Acc: 0.4186 val Loss: 1.6496 Acc: 0.4545
# Epoch  68/99 train Loss: 1.6154 Acc: 0.4413 val Loss: 1.6643 Acc: 0.4742
# Epoch  69/99 train Loss: 1.6002 Acc: 0.4493 val Loss: 1.6637 Acc: 0.4521
# Epoch  70/99 train Loss: 1.6305 Acc: 0.4210 val Loss: 1.6803 Acc: 0.4496
# Epoch  71/99 train Loss: 1.6152 Acc: 0.4309 val Loss: 1.6565 Acc: 0.4447
# Epoch  72/99 train Loss: 1.6086 Acc: 0.4401 val Loss: 1.6698 Acc: 0.4251
# Epoch  73/99 train Loss: 1.6482 Acc: 0.4167 val Loss: 1.6671 Acc: 0.4447
# Epoch  74/99 train Loss: 1.6153 Acc: 0.4284 val Loss: 1.6608 Acc: 0.4521
# Epoch  75/99 train Loss: 1.6060 Acc: 0.4296 val Loss: 1.6577 Acc: 0.4570
# Epoch  76/99 train Loss: 1.6102 Acc: 0.4395 val Loss: 1.6623 Acc: 0.4595
# Epoch  77/99 train Loss: 1.5959 Acc: 0.4468 val Loss: 1.6631 Acc: 0.4644
# Epoch  78/99 train Loss: 1.6055 Acc: 0.4425 val Loss: 1.6552 Acc: 0.4472
# Epoch  79/99 train Loss: 1.5963 Acc: 0.4499 val Loss: 1.6585 Acc: 0.4472
# Epoch  80/99 train Loss: 1.6032 Acc: 0.4315 val Loss: 1.6740 Acc: 0.4423
# Epoch  81/99 train Loss: 1.6077 Acc: 0.4382 val Loss: 1.6555 Acc: 0.4472
# Epoch  82/99 train Loss: 1.5723 Acc: 0.4518 val Loss: 1.6575 Acc: 0.4496
# Epoch  83/99 train Loss: 1.6156 Acc: 0.4364 val Loss: 1.6544 Acc: 0.4619
# Epoch  84/99 train Loss: 1.5854 Acc: 0.4518 val Loss: 1.6544 Acc: 0.4595
# Epoch  85/99 train Loss: 1.5574 Acc: 0.4585 val Loss: 1.6579 Acc: 0.4644
# Epoch  86/99 train Loss: 1.5577 Acc: 0.4579 val Loss: 1.6604 Acc: 0.4619
# Epoch  87/99 train Loss: 1.5951 Acc: 0.4272 val Loss: 1.6570 Acc: 0.4496
# Epoch  88/99 train Loss: 1.5752 Acc: 0.4450 val Loss: 1.6531 Acc: 0.4472
# Training complete in 128m 38s
# Best val Acc: 0.474201
# Fold  2 test Loss: 1.7896 Acc: 0.3811
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.3766 Acc: 0.1832 val Loss: 2.1851 Acc: 0.2629
# Epoch   1/99 train Loss: 2.2721 Acc: 0.2163 val Loss: 2.1233 Acc: 0.2555
# Epoch   2/99 train Loss: 2.2119 Acc: 0.2354 val Loss: 2.1126 Acc: 0.2752
# Epoch   3/99 train Loss: 2.1478 Acc: 0.2606 val Loss: 2.1261 Acc: 0.2408
# Epoch   4/99 train Loss: 2.1334 Acc: 0.2348 val Loss: 2.0655 Acc: 0.2850
# Epoch   5/99 train Loss: 2.1354 Acc: 0.2514 val Loss: 2.0430 Acc: 0.2752
# Epoch   6/99 train Loss: 2.1264 Acc: 0.2569 val Loss: 2.0752 Acc: 0.2654
# Epoch   7/99 train Loss: 2.1336 Acc: 0.2600 val Loss: 2.0709 Acc: 0.2752
# Epoch   8/99 train Loss: 2.0997 Acc: 0.2655 val Loss: 2.0207 Acc: 0.3047
# Epoch   9/99 train Loss: 2.0644 Acc: 0.2747 val Loss: 2.0088 Acc: 0.3145
# Epoch  10/99 train Loss: 2.0726 Acc: 0.2772 val Loss: 2.0036 Acc: 0.2998
# Epoch  11/99 train Loss: 2.0733 Acc: 0.2741 val Loss: 2.0151 Acc: 0.3022
# Epoch  12/99 train Loss: 2.0712 Acc: 0.2754 val Loss: 2.0153 Acc: 0.2899
# Epoch  13/99 train Loss: 2.0394 Acc: 0.2876 val Loss: 1.9528 Acc: 0.3268
# Epoch  14/99 train Loss: 2.0409 Acc: 0.2870 val Loss: 1.9594 Acc: 0.3194
# Epoch  15/99 train Loss: 2.0199 Acc: 0.2926 val Loss: 2.0375 Acc: 0.2973
# Epoch  16/99 train Loss: 2.0435 Acc: 0.2981 val Loss: 1.9765 Acc: 0.3514
# Epoch  17/99 train Loss: 1.9996 Acc: 0.2932 val Loss: 1.9906 Acc: 0.3243
# Epoch  18/99 train Loss: 1.9933 Acc: 0.2926 val Loss: 1.9996 Acc: 0.3022
# Epoch  19/99 train Loss: 1.9996 Acc: 0.2981 val Loss: 1.9617 Acc: 0.3145
# Epoch  20/99 train Loss: 2.0066 Acc: 0.3018 val Loss: 2.0257 Acc: 0.3096
# Epoch  21/99 train Loss: 1.9738 Acc: 0.3202 val Loss: 1.9473 Acc: 0.3342
# Epoch  22/99 train Loss: 1.9964 Acc: 0.2963 val Loss: 1.9251 Acc: 0.3612
# Epoch  23/99 train Loss: 1.9844 Acc: 0.3147 val Loss: 1.9091 Acc: 0.3464
# Epoch  24/99 train Loss: 1.9637 Acc: 0.3085 val Loss: 1.9219 Acc: 0.3587
# Epoch  25/99 train Loss: 1.9436 Acc: 0.3245 val Loss: 2.0013 Acc: 0.3096
# Epoch  26/99 train Loss: 1.9438 Acc: 0.3079 val Loss: 1.8809 Acc: 0.3661
# Epoch  27/99 train Loss: 1.9197 Acc: 0.3227 val Loss: 1.8571 Acc: 0.3759
# Epoch  28/99 train Loss: 1.9331 Acc: 0.3159 val Loss: 1.8789 Acc: 0.3907
# Epoch  29/99 train Loss: 1.9183 Acc: 0.3233 val Loss: 1.9009 Acc: 0.3538
# Epoch  30/99 train Loss: 1.9174 Acc: 0.3436 val Loss: 1.8699 Acc: 0.3686
# Epoch  31/99 train Loss: 1.9196 Acc: 0.3227 val Loss: 1.8569 Acc: 0.3907
# Epoch  32/99 train Loss: 1.9037 Acc: 0.3208 val Loss: 1.8586 Acc: 0.3784
# Epoch  33/99 train Loss: 1.8879 Acc: 0.3614 val Loss: 1.8624 Acc: 0.3686
# Epoch  34/99 train Loss: 1.9289 Acc: 0.3153 val Loss: 1.9097 Acc: 0.3440
# Epoch  35/99 train Loss: 1.9069 Acc: 0.3313 val Loss: 1.8671 Acc: 0.3808
# Epoch  36/99 train Loss: 1.9059 Acc: 0.3276 val Loss: 1.8739 Acc: 0.3710
# Epoch  37/99 train Loss: 1.8654 Acc: 0.3448 val Loss: 1.8800 Acc: 0.3464
# Epoch  38/99 train Loss: 1.8301 Acc: 0.3663 val Loss: 1.8682 Acc: 0.3636
# Epoch  39/99 train Loss: 1.8607 Acc: 0.3583 val Loss: 1.8487 Acc: 0.3833
# Epoch  40/99 train Loss: 1.8692 Acc: 0.3454 val Loss: 1.8510 Acc: 0.3661
# Epoch  41/99 train Loss: 1.8702 Acc: 0.3467 val Loss: 1.8328 Acc: 0.3612
# Epoch  42/99 train Loss: 1.8474 Acc: 0.3589 val Loss: 1.8510 Acc: 0.3980
# Epoch  43/99 train Loss: 1.8118 Acc: 0.3700 val Loss: 1.7994 Acc: 0.3980
# Epoch  44/99 train Loss: 1.7994 Acc: 0.3651 val Loss: 1.8345 Acc: 0.3857
# Epoch  45/99 train Loss: 1.7997 Acc: 0.3731 val Loss: 1.7730 Acc: 0.3956
# Epoch  46/99 train Loss: 1.7451 Acc: 0.3884 val Loss: 1.7496 Acc: 0.3980
# Epoch  47/99 train Loss: 1.7653 Acc: 0.3774 val Loss: 1.7473 Acc: 0.4103
# Epoch  48/99 train Loss: 1.7541 Acc: 0.3970 val Loss: 1.7462 Acc: 0.3980
# Epoch  49/99 train Loss: 1.7794 Acc: 0.3792 val Loss: 1.7903 Acc: 0.3956
# Epoch  50/99 train Loss: 1.7818 Acc: 0.3651 val Loss: 1.7514 Acc: 0.4005
# Epoch  51/99 train Loss: 1.7427 Acc: 0.3977 val Loss: 1.7337 Acc: 0.4300
# Epoch  52/99 train Loss: 1.7417 Acc: 0.3983 val Loss: 1.7313 Acc: 0.4201
# Epoch  53/99 train Loss: 1.7003 Acc: 0.4093 val Loss: 1.7495 Acc: 0.4128
# Epoch  54/99 train Loss: 1.7294 Acc: 0.3964 val Loss: 1.7309 Acc: 0.4103
# Epoch  55/99 train Loss: 1.7123 Acc: 0.4093 val Loss: 1.7214 Acc: 0.4226
# Epoch  56/99 train Loss: 1.7494 Acc: 0.4038 val Loss: 1.7329 Acc: 0.4398
# Epoch  57/99 train Loss: 1.6987 Acc: 0.4026 val Loss: 1.7256 Acc: 0.4152
# Epoch  58/99 train Loss: 1.7191 Acc: 0.4143 val Loss: 1.7427 Acc: 0.4177
# Epoch  59/99 train Loss: 1.6792 Acc: 0.4241 val Loss: 1.7225 Acc: 0.4324
# Epoch  60/99 train Loss: 1.7306 Acc: 0.3934 val Loss: 1.7011 Acc: 0.4300
# Epoch  61/99 train Loss: 1.7158 Acc: 0.3989 val Loss: 1.7416 Acc: 0.4472
# Epoch  62/99 train Loss: 1.7086 Acc: 0.4001 val Loss: 1.7202 Acc: 0.4300
# Epoch  63/99 train Loss: 1.6977 Acc: 0.4050 val Loss: 1.7032 Acc: 0.4423
# Epoch  64/99 train Loss: 1.6966 Acc: 0.4063 val Loss: 1.6972 Acc: 0.4472
# Epoch  65/99 train Loss: 1.6709 Acc: 0.3983 val Loss: 1.6934 Acc: 0.4398
# Epoch  66/99 train Loss: 1.6688 Acc: 0.4130 val Loss: 1.6894 Acc: 0.4300
# Epoch  67/99 train Loss: 1.6705 Acc: 0.4167 val Loss: 1.6882 Acc: 0.4398
# Epoch  68/99 train Loss: 1.6620 Acc: 0.4253 val Loss: 1.6798 Acc: 0.4373
# Epoch  69/99 train Loss: 1.6509 Acc: 0.4241 val Loss: 1.6901 Acc: 0.4152
# Epoch  70/99 train Loss: 1.6586 Acc: 0.4278 val Loss: 1.6814 Acc: 0.4472
# Epoch  71/99 train Loss: 1.6637 Acc: 0.4253 val Loss: 1.6821 Acc: 0.4349
# Epoch  72/99 train Loss: 1.6332 Acc: 0.4259 val Loss: 1.6940 Acc: 0.4226
# Epoch  73/99 train Loss: 1.6505 Acc: 0.4241 val Loss: 1.6876 Acc: 0.4349
# Epoch  74/99 train Loss: 1.6435 Acc: 0.4407 val Loss: 1.6850 Acc: 0.4226
# Epoch  75/99 train Loss: 1.6321 Acc: 0.4204 val Loss: 1.6840 Acc: 0.4398
# Epoch  76/99 train Loss: 1.6202 Acc: 0.4474 val Loss: 1.6979 Acc: 0.4275
# Epoch  77/99 train Loss: 1.6465 Acc: 0.4358 val Loss: 1.6989 Acc: 0.4398
# Epoch  78/99 train Loss: 1.6389 Acc: 0.4321 val Loss: 1.6729 Acc: 0.4226
# Epoch  79/99 train Loss: 1.6473 Acc: 0.4259 val Loss: 1.6771 Acc: 0.4251
# Epoch  80/99 train Loss: 1.6390 Acc: 0.4382 val Loss: 1.6680 Acc: 0.4423
# Epoch  81/99 train Loss: 1.6540 Acc: 0.4216 val Loss: 1.6743 Acc: 0.4496
# Epoch  82/99 train Loss: 1.6442 Acc: 0.4241 val Loss: 1.6526 Acc: 0.4472
# Epoch  83/99 train Loss: 1.6287 Acc: 0.4278 val Loss: 1.6606 Acc: 0.4447
# Epoch  84/99 train Loss: 1.6421 Acc: 0.4333 val Loss: 1.6509 Acc: 0.4472
# Epoch  85/99 train Loss: 1.6017 Acc: 0.4278 val Loss: 1.6534 Acc: 0.4447
# Epoch  86/99 train Loss: 1.6160 Acc: 0.4425 val Loss: 1.6441 Acc: 0.4521
# Epoch  87/99 train Loss: 1.6160 Acc: 0.4388 val Loss: 1.6582 Acc: 0.4521
# Epoch  88/99 train Loss: 1.6040 Acc: 0.4327 val Loss: 1.6565 Acc: 0.4447
# Epoch  89/99 train Loss: 1.5953 Acc: 0.4468 val Loss: 1.6648 Acc: 0.4447
# Epoch  90/99 train Loss: 1.6146 Acc: 0.4431 val Loss: 1.6593 Acc: 0.4545
# Epoch  91/99 train Loss: 1.6198 Acc: 0.4468 val Loss: 1.6599 Acc: 0.4324
# Epoch  92/99 train Loss: 1.5853 Acc: 0.4395 val Loss: 1.6616 Acc: 0.4423
# Epoch  93/99 train Loss: 1.6255 Acc: 0.4388 val Loss: 1.6572 Acc: 0.4398
# Epoch  94/99 train Loss: 1.5898 Acc: 0.4444 val Loss: 1.6454 Acc: 0.4545
# Epoch  95/99 train Loss: 1.6342 Acc: 0.4370 val Loss: 1.6520 Acc: 0.4521
# Epoch  96/99 train Loss: 1.6004 Acc: 0.4339 val Loss: 1.6472 Acc: 0.4472
# Epoch  97/99 train Loss: 1.6209 Acc: 0.4376 val Loss: 1.6495 Acc: 0.4496
# Epoch  98/99 train Loss: 1.6300 Acc: 0.4321 val Loss: 1.6533 Acc: 0.4472
# Epoch  99/99 train Loss: 1.6233 Acc: 0.4456 val Loss: 1.6565 Acc: 0.4373
# Training complete in 144m 34s
# Best val Acc: 0.454545
# Fold  3 test Loss: 1.7441 Acc: 0.3988
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.4276 Acc: 0.1474 val Loss: 2.2037 Acc: 0.2211
# Epoch   1/99 train Loss: 2.2632 Acc: 0.2199 val Loss: 2.1217 Acc: 0.2629
# Epoch   2/99 train Loss: 2.2272 Acc: 0.2131 val Loss: 2.0435 Acc: 0.2604
# Epoch   3/99 train Loss: 2.1936 Acc: 0.2340 val Loss: 2.0329 Acc: 0.2875
# Epoch   4/99 train Loss: 2.1968 Acc: 0.2291 val Loss: 2.0310 Acc: 0.2948
# Epoch   5/99 train Loss: 2.1697 Acc: 0.2451 val Loss: 2.0229 Acc: 0.2948
# Epoch   6/99 train Loss: 2.1279 Acc: 0.2518 val Loss: 2.0480 Acc: 0.2899
# Epoch   7/99 train Loss: 2.1269 Acc: 0.2555 val Loss: 2.0355 Acc: 0.2973
# Epoch   8/99 train Loss: 2.1062 Acc: 0.2746 val Loss: 2.0088 Acc: 0.3145
# Epoch   9/99 train Loss: 2.0861 Acc: 0.2678 val Loss: 2.0165 Acc: 0.3145
# Epoch  10/99 train Loss: 2.0636 Acc: 0.2826 val Loss: 1.9948 Acc: 0.3170
# Epoch  11/99 train Loss: 2.0569 Acc: 0.2893 val Loss: 1.9695 Acc: 0.3489
# Epoch  12/99 train Loss: 2.0182 Acc: 0.3047 val Loss: 1.9821 Acc: 0.2948
# Epoch  13/99 train Loss: 2.0182 Acc: 0.2918 val Loss: 1.9623 Acc: 0.3219
# Epoch  14/99 train Loss: 2.0419 Acc: 0.3010 val Loss: 1.9025 Acc: 0.3391
# Epoch  15/99 train Loss: 1.9874 Acc: 0.3114 val Loss: 2.0003 Acc: 0.3071
# Epoch  16/99 train Loss: 2.0104 Acc: 0.3114 val Loss: 1.9467 Acc: 0.3514
# Epoch  17/99 train Loss: 1.9694 Acc: 0.3133 val Loss: 1.9185 Acc: 0.3440
# Epoch  18/99 train Loss: 1.9720 Acc: 0.3219 val Loss: 1.9141 Acc: 0.3342
# Epoch  19/99 train Loss: 1.9695 Acc: 0.3157 val Loss: 1.8902 Acc: 0.3587
# Epoch  20/99 train Loss: 1.9619 Acc: 0.3182 val Loss: 1.8644 Acc: 0.3636
# Epoch  21/99 train Loss: 1.9792 Acc: 0.2955 val Loss: 1.8541 Acc: 0.3636
# Epoch  22/99 train Loss: 1.9344 Acc: 0.3262 val Loss: 1.8845 Acc: 0.3096
# Epoch  23/99 train Loss: 1.9426 Acc: 0.3237 val Loss: 1.9320 Acc: 0.3219
# Epoch  24/99 train Loss: 1.9351 Acc: 0.3292 val Loss: 1.8248 Acc: 0.3612
# Epoch  25/99 train Loss: 1.9122 Acc: 0.3391 val Loss: 1.8824 Acc: 0.3612
# Epoch  26/99 train Loss: 1.9555 Acc: 0.3188 val Loss: 1.8202 Acc: 0.3759
# Epoch  27/99 train Loss: 1.9116 Acc: 0.3311 val Loss: 1.8386 Acc: 0.3784
# Epoch  28/99 train Loss: 1.8720 Acc: 0.3471 val Loss: 1.8143 Acc: 0.3735
# Epoch  29/99 train Loss: 1.8858 Acc: 0.3452 val Loss: 1.7777 Acc: 0.3759
# Epoch  30/99 train Loss: 1.8596 Acc: 0.3391 val Loss: 1.8615 Acc: 0.3710
# Epoch  31/99 train Loss: 1.8819 Acc: 0.3458 val Loss: 1.8139 Acc: 0.3833
# Epoch  32/99 train Loss: 1.8880 Acc: 0.3458 val Loss: 1.8376 Acc: 0.3612
# Epoch  33/99 train Loss: 1.8809 Acc: 0.3403 val Loss: 1.8370 Acc: 0.3514
# Epoch  34/99 train Loss: 1.8851 Acc: 0.3452 val Loss: 1.7807 Acc: 0.3808
# Epoch  35/99 train Loss: 1.8162 Acc: 0.3686 val Loss: 1.7467 Acc: 0.3980
# Epoch  36/99 train Loss: 1.8195 Acc: 0.3802 val Loss: 1.7576 Acc: 0.3833
# Epoch  37/99 train Loss: 1.8088 Acc: 0.3857 val Loss: 1.7792 Acc: 0.3784
# Epoch  38/99 train Loss: 1.8110 Acc: 0.3667 val Loss: 1.7700 Acc: 0.3759
# Epoch  39/99 train Loss: 1.7933 Acc: 0.3796 val Loss: 1.7426 Acc: 0.4005
# Epoch  40/99 train Loss: 1.7900 Acc: 0.3845 val Loss: 1.7225 Acc: 0.4079
# Epoch  41/99 train Loss: 1.7880 Acc: 0.3796 val Loss: 1.7609 Acc: 0.3808
# Epoch  42/99 train Loss: 1.7833 Acc: 0.3765 val Loss: 1.7467 Acc: 0.3882
# Epoch  43/99 train Loss: 1.7571 Acc: 0.3943 val Loss: 1.7298 Acc: 0.4029
# Epoch  44/99 train Loss: 1.7836 Acc: 0.3986 val Loss: 1.7399 Acc: 0.3980
# Epoch  45/99 train Loss: 1.7526 Acc: 0.3956 val Loss: 1.7572 Acc: 0.3808
# Epoch  46/99 train Loss: 1.7585 Acc: 0.3937 val Loss: 1.7104 Acc: 0.3980
# Epoch  47/99 train Loss: 1.7461 Acc: 0.3962 val Loss: 1.7119 Acc: 0.3907
# Epoch  48/99 train Loss: 1.7183 Acc: 0.4042 val Loss: 1.7224 Acc: 0.3808
# Epoch  49/99 train Loss: 1.7658 Acc: 0.3870 val Loss: 1.7139 Acc: 0.3980
# Epoch  50/99 train Loss: 1.7433 Acc: 0.4036 val Loss: 1.7056 Acc: 0.4103
# Epoch  51/99 train Loss: 1.7393 Acc: 0.4017 val Loss: 1.6790 Acc: 0.4103
# Epoch  52/99 train Loss: 1.7536 Acc: 0.4017 val Loss: 1.7033 Acc: 0.4029
# Epoch  53/99 train Loss: 1.7210 Acc: 0.4208 val Loss: 1.6834 Acc: 0.4177
# Epoch  54/99 train Loss: 1.6972 Acc: 0.4226 val Loss: 1.6821 Acc: 0.4103
# Epoch  55/99 train Loss: 1.6782 Acc: 0.4263 val Loss: 1.6685 Acc: 0.4251
# Epoch  56/99 train Loss: 1.6904 Acc: 0.4146 val Loss: 1.7037 Acc: 0.4177
# Epoch  57/99 train Loss: 1.6852 Acc: 0.4097 val Loss: 1.6683 Acc: 0.3907
# Epoch  58/99 train Loss: 1.6821 Acc: 0.4232 val Loss: 1.6815 Acc: 0.4201
# Epoch  59/99 train Loss: 1.6655 Acc: 0.4128 val Loss: 1.6887 Acc: 0.4054
# Epoch  60/99 train Loss: 1.7023 Acc: 0.4072 val Loss: 1.7008 Acc: 0.4275
# Epoch  61/99 train Loss: 1.6684 Acc: 0.4318 val Loss: 1.6989 Acc: 0.4251
# Epoch  62/99 train Loss: 1.6660 Acc: 0.4269 val Loss: 1.6804 Acc: 0.4324
# Epoch  63/99 train Loss: 1.6490 Acc: 0.4269 val Loss: 1.6797 Acc: 0.4226
# Epoch  64/99 train Loss: 1.6365 Acc: 0.4355 val Loss: 1.6944 Acc: 0.4029
# Epoch  65/99 train Loss: 1.6451 Acc: 0.4367 val Loss: 1.6626 Acc: 0.4079
# Epoch  66/99 train Loss: 1.6092 Acc: 0.4398 val Loss: 1.6554 Acc: 0.4349
# Epoch  67/99 train Loss: 1.6690 Acc: 0.4367 val Loss: 1.6529 Acc: 0.4201
# Epoch  68/99 train Loss: 1.6782 Acc: 0.4134 val Loss: 1.6792 Acc: 0.4226
# Epoch  69/99 train Loss: 1.6375 Acc: 0.4447 val Loss: 1.7194 Acc: 0.4103
# Epoch  70/99 train Loss: 1.6287 Acc: 0.4318 val Loss: 1.6383 Acc: 0.4324
# Epoch  71/99 train Loss: 1.6183 Acc: 0.4527 val Loss: 1.6312 Acc: 0.4226
# Epoch  72/99 train Loss: 1.6195 Acc: 0.4423 val Loss: 1.6484 Acc: 0.4373
# Epoch  73/99 train Loss: 1.6213 Acc: 0.4349 val Loss: 1.6388 Acc: 0.4349
# Epoch  74/99 train Loss: 1.6137 Acc: 0.4466 val Loss: 1.6609 Acc: 0.4152
# Epoch  75/99 train Loss: 1.6074 Acc: 0.4416 val Loss: 1.6333 Acc: 0.4349
# Epoch  76/99 train Loss: 1.5803 Acc: 0.4484 val Loss: 1.6348 Acc: 0.4349
# Epoch  77/99 train Loss: 1.5819 Acc: 0.4564 val Loss: 1.6410 Acc: 0.4275
# Epoch  78/99 train Loss: 1.6109 Acc: 0.4337 val Loss: 1.6378 Acc: 0.4201
# Epoch  79/99 train Loss: 1.5994 Acc: 0.4380 val Loss: 1.6463 Acc: 0.4251
# Epoch  80/99 train Loss: 1.5603 Acc: 0.4656 val Loss: 1.6343 Acc: 0.4300
# Epoch  81/99 train Loss: 1.5665 Acc: 0.4570 val Loss: 1.6340 Acc: 0.4251
# Epoch  82/99 train Loss: 1.6116 Acc: 0.4533 val Loss: 1.6405 Acc: 0.4300
# Epoch  83/99 train Loss: 1.5686 Acc: 0.4490 val Loss: 1.6362 Acc: 0.4300
# Epoch  84/99 train Loss: 1.5853 Acc: 0.4545 val Loss: 1.6331 Acc: 0.4300
# Epoch  85/99 train Loss: 1.5924 Acc: 0.4429 val Loss: 1.6344 Acc: 0.4324
# Epoch  86/99 train Loss: 1.5673 Acc: 0.4490 val Loss: 1.6356 Acc: 0.4251
# Epoch  87/99 train Loss: 1.5559 Acc: 0.4588 val Loss: 1.6367 Acc: 0.4201
# Epoch  88/99 train Loss: 1.5500 Acc: 0.4644 val Loss: 1.6305 Acc: 0.4349
# Epoch  89/99 train Loss: 1.5305 Acc: 0.4724 val Loss: 1.6334 Acc: 0.4349
# Epoch  90/99 train Loss: 1.5690 Acc: 0.4552 val Loss: 1.6281 Acc: 0.4423
# Epoch  91/99 train Loss: 1.5392 Acc: 0.4539 val Loss: 1.6462 Acc: 0.4226
# Epoch  92/99 train Loss: 1.5722 Acc: 0.4447 val Loss: 1.6323 Acc: 0.4373
# Epoch  93/99 train Loss: 1.5792 Acc: 0.4631 val Loss: 1.6223 Acc: 0.4373
# Epoch  94/99 train Loss: 1.5558 Acc: 0.4539 val Loss: 1.6278 Acc: 0.4447
# Epoch  95/99 train Loss: 1.5752 Acc: 0.4484 val Loss: 1.6322 Acc: 0.4324
# Epoch  96/99 train Loss: 1.5629 Acc: 0.4576 val Loss: 1.6243 Acc: 0.4398
# Epoch  97/99 train Loss: 1.5386 Acc: 0.4717 val Loss: 1.6273 Acc: 0.4324
# Epoch  98/99 train Loss: 1.5316 Acc: 0.4797 val Loss: 1.6286 Acc: 0.4447
# Epoch  99/99 train Loss: 1.5535 Acc: 0.4558 val Loss: 1.6300 Acc: 0.4251
# Training complete in 144m 29s
# Best val Acc: 0.444717
# Fold  4 test Loss: 1.7975 Acc: 0.4193
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.4094 Acc: 0.1560 val Loss: 2.2257 Acc: 0.2187
# Epoch   1/99 train Loss: 2.2530 Acc: 0.2205 val Loss: 2.1536 Acc: 0.2531
# Epoch   2/99 train Loss: 2.2206 Acc: 0.2211 val Loss: 2.1805 Acc: 0.2531
# Epoch   3/99 train Loss: 2.2142 Acc: 0.2377 val Loss: 2.1251 Acc: 0.2678
# Epoch   4/99 train Loss: 2.2024 Acc: 0.2353 val Loss: 2.1254 Acc: 0.2506
# Epoch   5/99 train Loss: 2.2014 Acc: 0.2297 val Loss: 2.1006 Acc: 0.2875
# Epoch   6/99 train Loss: 2.1236 Acc: 0.2629 val Loss: 2.1326 Acc: 0.2727
# Epoch   7/99 train Loss: 2.1364 Acc: 0.2690 val Loss: 2.0838 Acc: 0.2580
# Epoch   8/99 train Loss: 2.1171 Acc: 0.2457 val Loss: 2.0829 Acc: 0.2727
# Epoch   9/99 train Loss: 2.0835 Acc: 0.2709 val Loss: 2.0603 Acc: 0.2826
# Epoch  10/99 train Loss: 2.1053 Acc: 0.2604 val Loss: 2.0633 Acc: 0.2776
# Epoch  11/99 train Loss: 2.0821 Acc: 0.2844 val Loss: 2.0189 Acc: 0.3071
# Epoch  12/99 train Loss: 2.0497 Acc: 0.2862 val Loss: 2.0323 Acc: 0.2973
# Epoch  13/99 train Loss: 2.0644 Acc: 0.2801 val Loss: 2.0436 Acc: 0.2924
# Epoch  14/99 train Loss: 2.0526 Acc: 0.2881 val Loss: 2.0221 Acc: 0.3047
# Epoch  15/99 train Loss: 2.0630 Acc: 0.2862 val Loss: 2.0413 Acc: 0.2826
# Epoch  16/99 train Loss: 2.0479 Acc: 0.2801 val Loss: 2.0445 Acc: 0.3096
# Epoch  17/99 train Loss: 2.0463 Acc: 0.2955 val Loss: 2.0347 Acc: 0.3022
# Epoch  18/99 train Loss: 2.0144 Acc: 0.2991 val Loss: 2.0168 Acc: 0.2875
# Epoch  19/99 train Loss: 2.0547 Acc: 0.2727 val Loss: 2.0317 Acc: 0.2973
# Epoch  20/99 train Loss: 2.0283 Acc: 0.2905 val Loss: 1.9716 Acc: 0.3440
# Epoch  21/99 train Loss: 2.0241 Acc: 0.2930 val Loss: 2.0122 Acc: 0.3071
# Epoch  22/99 train Loss: 2.0143 Acc: 0.3059 val Loss: 2.0010 Acc: 0.3096
# Epoch  23/99 train Loss: 1.9974 Acc: 0.3151 val Loss: 1.9775 Acc: 0.3096
# Epoch  24/99 train Loss: 1.9555 Acc: 0.3256 val Loss: 1.9484 Acc: 0.3366
# Epoch  25/99 train Loss: 1.9543 Acc: 0.3292 val Loss: 1.9577 Acc: 0.3317
# Epoch  26/99 train Loss: 1.9426 Acc: 0.3366 val Loss: 1.9438 Acc: 0.3219
# Epoch  27/99 train Loss: 1.9284 Acc: 0.3421 val Loss: 1.9566 Acc: 0.3120
# Epoch  28/99 train Loss: 1.9619 Acc: 0.3139 val Loss: 1.9271 Acc: 0.3292
# Epoch  29/99 train Loss: 1.8958 Acc: 0.3354 val Loss: 1.8979 Acc: 0.3342
# Epoch  30/99 train Loss: 1.9222 Acc: 0.3409 val Loss: 1.9151 Acc: 0.3391
# Epoch  31/99 train Loss: 1.9143 Acc: 0.3397 val Loss: 1.9337 Acc: 0.3096
# Epoch  32/99 train Loss: 1.9086 Acc: 0.3354 val Loss: 1.9201 Acc: 0.3268
# Epoch  33/99 train Loss: 1.8642 Acc: 0.3587 val Loss: 1.8884 Acc: 0.3292
# Epoch  34/99 train Loss: 1.9247 Acc: 0.3311 val Loss: 1.8788 Acc: 0.3538
# Epoch  35/99 train Loss: 1.8903 Acc: 0.3421 val Loss: 1.8881 Acc: 0.3661
# Epoch  36/99 train Loss: 1.9177 Acc: 0.3335 val Loss: 1.8648 Acc: 0.3514
# Epoch  37/99 train Loss: 1.9169 Acc: 0.3409 val Loss: 1.8663 Acc: 0.3489
# Epoch  38/99 train Loss: 1.8566 Acc: 0.3575 val Loss: 1.8486 Acc: 0.3907
# Epoch  39/99 train Loss: 1.8389 Acc: 0.3808 val Loss: 1.8329 Acc: 0.3514
# Epoch  40/99 train Loss: 1.8594 Acc: 0.3501 val Loss: 1.8283 Acc: 0.3538
# Epoch  41/99 train Loss: 1.8323 Acc: 0.3710 val Loss: 1.8234 Acc: 0.3710
# Epoch  42/99 train Loss: 1.8479 Acc: 0.3544 val Loss: 1.8265 Acc: 0.3587
# Epoch  43/99 train Loss: 1.8376 Acc: 0.3729 val Loss: 1.8122 Acc: 0.3710
# Epoch  44/99 train Loss: 1.8167 Acc: 0.3722 val Loss: 1.8036 Acc: 0.3857
# Epoch  45/99 train Loss: 1.8380 Acc: 0.3624 val Loss: 1.8208 Acc: 0.3538
# Epoch  46/99 train Loss: 1.8334 Acc: 0.3673 val Loss: 1.7931 Acc: 0.3686
# Epoch  47/99 train Loss: 1.8028 Acc: 0.3833 val Loss: 1.8144 Acc: 0.3735
# Epoch  48/99 train Loss: 1.8132 Acc: 0.3710 val Loss: 1.7969 Acc: 0.3808
# Epoch  49/99 train Loss: 1.8129 Acc: 0.3790 val Loss: 1.7965 Acc: 0.3808
# Epoch  50/99 train Loss: 1.8264 Acc: 0.3630 val Loss: 1.7859 Acc: 0.3735
# Epoch  51/99 train Loss: 1.8085 Acc: 0.3857 val Loss: 1.8140 Acc: 0.3612
# Epoch  52/99 train Loss: 1.8157 Acc: 0.3913 val Loss: 1.7842 Acc: 0.3759
# Epoch  53/99 train Loss: 1.7813 Acc: 0.3753 val Loss: 1.7989 Acc: 0.3808
# Epoch  54/99 train Loss: 1.7679 Acc: 0.3876 val Loss: 1.7569 Acc: 0.3882
# Epoch  55/99 train Loss: 1.7763 Acc: 0.3968 val Loss: 1.7748 Acc: 0.4029
# Epoch  56/99 train Loss: 1.7597 Acc: 0.3999 val Loss: 1.7690 Acc: 0.4005
# Epoch  57/99 train Loss: 1.7515 Acc: 0.3962 val Loss: 1.7501 Acc: 0.4079
# Epoch  58/99 train Loss: 1.7548 Acc: 0.3968 val Loss: 1.7675 Acc: 0.3882
# Epoch  59/99 train Loss: 1.7826 Acc: 0.3821 val Loss: 1.7470 Acc: 0.3808
# Epoch  60/99 train Loss: 1.7540 Acc: 0.3913 val Loss: 1.7652 Acc: 0.3808
# Epoch  61/99 train Loss: 1.7580 Acc: 0.3833 val Loss: 1.7554 Acc: 0.4079
# Epoch  62/99 train Loss: 1.7382 Acc: 0.4097 val Loss: 1.7426 Acc: 0.4054
# Epoch  63/99 train Loss: 1.7519 Acc: 0.4060 val Loss: 1.7337 Acc: 0.3980
# Epoch  64/99 train Loss: 1.7323 Acc: 0.4036 val Loss: 1.7508 Acc: 0.4005
# Epoch  65/99 train Loss: 1.7278 Acc: 0.4152 val Loss: 1.7340 Acc: 0.4128
# Epoch  66/99 train Loss: 1.7396 Acc: 0.4079 val Loss: 1.7471 Acc: 0.3956
# Epoch  67/99 train Loss: 1.7171 Acc: 0.3980 val Loss: 1.7325 Acc: 0.4079
# Epoch  68/99 train Loss: 1.7270 Acc: 0.4079 val Loss: 1.7260 Acc: 0.4152
# Epoch  69/99 train Loss: 1.7351 Acc: 0.4072 val Loss: 1.7259 Acc: 0.4152
# Epoch  70/99 train Loss: 1.7075 Acc: 0.4146 val Loss: 1.7266 Acc: 0.4079
# Epoch  71/99 train Loss: 1.7356 Acc: 0.4060 val Loss: 1.7297 Acc: 0.4103
# Epoch  72/99 train Loss: 1.7237 Acc: 0.4066 val Loss: 1.7292 Acc: 0.4029
# Epoch  73/99 train Loss: 1.7284 Acc: 0.4011 val Loss: 1.7170 Acc: 0.4128
# Epoch  74/99 train Loss: 1.7102 Acc: 0.3993 val Loss: 1.7099 Acc: 0.4177
# Epoch  75/99 train Loss: 1.6857 Acc: 0.4158 val Loss: 1.7086 Acc: 0.4201
# Epoch  76/99 train Loss: 1.7046 Acc: 0.4287 val Loss: 1.7076 Acc: 0.4152
# Epoch  77/99 train Loss: 1.6998 Acc: 0.4128 val Loss: 1.7068 Acc: 0.4226
# Epoch  78/99 train Loss: 1.6703 Acc: 0.4152 val Loss: 1.7073 Acc: 0.4128
# Epoch  79/99 train Loss: 1.6945 Acc: 0.4195 val Loss: 1.7017 Acc: 0.4177
# Epoch  80/99 train Loss: 1.6869 Acc: 0.4263 val Loss: 1.7090 Acc: 0.4128
# Epoch  81/99 train Loss: 1.6997 Acc: 0.4300 val Loss: 1.7043 Acc: 0.4152
# Epoch  82/99 train Loss: 1.6923 Acc: 0.4146 val Loss: 1.7195 Acc: 0.4128
# Epoch  83/99 train Loss: 1.7072 Acc: 0.4085 val Loss: 1.7099 Acc: 0.4226
# Epoch  84/99 train Loss: 1.6991 Acc: 0.4079 val Loss: 1.7110 Acc: 0.4152
# Epoch  85/99 train Loss: 1.7059 Acc: 0.4158 val Loss: 1.7164 Acc: 0.4103
# Epoch  86/99 train Loss: 1.6916 Acc: 0.4214 val Loss: 1.7098 Acc: 0.4177
# Epoch  87/99 train Loss: 1.7006 Acc: 0.4122 val Loss: 1.7070 Acc: 0.4251
# Epoch  88/99 train Loss: 1.6835 Acc: 0.4183 val Loss: 1.6987 Acc: 0.4300
# Epoch  89/99 train Loss: 1.6882 Acc: 0.4251 val Loss: 1.7095 Acc: 0.4226
# Epoch  90/99 train Loss: 1.6831 Acc: 0.4208 val Loss: 1.7082 Acc: 0.4300
# Epoch  91/99 train Loss: 1.6458 Acc: 0.4361 val Loss: 1.7041 Acc: 0.4201
# Epoch  92/99 train Loss: 1.6669 Acc: 0.4294 val Loss: 1.7050 Acc: 0.4201
# Epoch  93/99 train Loss: 1.6822 Acc: 0.4091 val Loss: 1.7036 Acc: 0.4226
# Epoch  94/99 train Loss: 1.6697 Acc: 0.4251 val Loss: 1.7069 Acc: 0.4201
# Epoch  95/99 train Loss: 1.7007 Acc: 0.4079 val Loss: 1.7103 Acc: 0.4177
# Epoch  96/99 train Loss: 1.6814 Acc: 0.4238 val Loss: 1.7095 Acc: 0.4251
# Epoch  97/99 train Loss: 1.7024 Acc: 0.4251 val Loss: 1.7088 Acc: 0.4300
# Epoch  98/99 train Loss: 1.6720 Acc: 0.4115 val Loss: 1.7030 Acc: 0.4177
# Epoch  99/99 train Loss: 1.6524 Acc: 0.4380 val Loss: 1.7079 Acc: 0.4226
# Training complete in 145m 54s
# Best val Acc: 0.429975
# Fold  5 test Loss: 1.7199 Acc: 0.3957

# %%
print(classifier)
# Out:
# Classifier(
#   (cnn_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (self_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=11, bias=True)
#   )
# )

# %% [markdown]
# ### 顯示結果

# %%
plt.figure(figsize=(8,3*len(histories)))

max_loss = 0
max_acc  = 0
for i,history in enumerate(histories):
    max_loss = max(max_loss,np.max(history['loss']),np.max(history['val_loss']))

max_loss *= 1.05
for i,history in enumerate(histories):
    plt.subplot(len(histories),2,i*2+1)
    plt.title(f'fold:{i+1}')
    plt.plot(history['loss'],label='train')
    plt.plot(history['val_loss'],label='valid')
    plt.xlabel('epoch')
    step = int(np.ceil(len(history['loss'])/5))
    plt.xticks(np.arange(0,len(history['loss']),step),[str(u+1) for u in np.arange(0,len(history['loss']),step)])
    plt.ylabel('loss')
    plt.ylim([0,max_loss])
    plt.grid(True)
    plt.legend()

    plt.subplot(len(histories),2,i*2+2)
    plt.title(f'fold:{i+1}')
    plt.plot(history['accuracy'],label='train')
    plt.plot(history['val_accuracy'],label='valid')
    plt.xticks(np.arange(0,len(history['accuracy']),step),[str(u+1) for u in np.arange(0,len(history['accuracy']),step)])
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.ylim([0,1.0])
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()

plt.figure()
plt.bar(x=np.arange(len(test_accuracy)),height=np.array(test_accuracy))
plt.xlabel('fold')
plt.xticks(np.arange(len(test_accuracy)),[str(i+1) for i in np.arange(len(test_accuracy))])
plt.ylabel('accuracy')
plt.title(f'average accuracy rate:{np.mean(np.array(test_accuracy)):.3f}+/-{np.std(np.array(test_accuracy)):.3f}')
plt.grid(True)
plt.ylim([0,1.0])
plt.show()
print(f'average accuracy rate:{np.mean(np.array(test_accuracy)):.3f}+/-{np.std(np.array(test_accuracy)):.3f}')
# Out:
# average accuracy rate:0.399+/-0.012
