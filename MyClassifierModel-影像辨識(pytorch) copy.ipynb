# %% [markdown]
# ### PyTorch官方參考範例
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %%
import os
import glob
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import torchvision
import time
from PIL import Image

def CCSN_images(dataset_dir):
    classfolder = glob.glob(os.path.join(dataset_dir,"*"),recursive=True)
    class_name  = [f.split(os.path.sep)[-1] for f in classfolder]
    img_labels  = []
    img_list    = []

    for class_id, f in enumerate(classfolder):
        files = glob.glob(os.path.join(f,"*.jpg"),recursive=True)
        img_labels.extend([class_id]*len(files))
        img_list.extend(files)

    img_labels = np.array(img_labels)
    img_list   = np.array(img_list,dtype=object)

    return img_list.reshape((-1,1)), img_labels, class_name

# %% [markdown]
# ### 定義Dataset

# %%
class CCSNImageDataset(torch.utils.data.Dataset):
    def __init__(self, img_list, img_labels, transform=None, target_transform=None):
        self.transform        = transform
        self.target_transform = target_transform
        self.img_list         = img_list
        self.img_labels       = img_labels

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = self.img_list[idx,0]
        image    = Image.open(img_path)
        label    = self.img_labels[idx]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %% [markdown]
# ### 設定CCSN資料集路徑
# 例如:
# ![image.png](attachment:image.png)

# %%
CCSNDataset_Path = "CCSN_v2"
img_list, img_labels, label_names = CCSN_images(CCSNDataset_Path)

CCSNDataset = CCSNImageDataset(img_list,img_labels)

# %% [markdown]
# ### 範例:透過Dataset載入並顯示部分資料集

# %%
N = len(CCSNDataset)

plt.figure(figsize=(16,8))

for i in range(16):
    plt.subplot(4,8,i+1)
    image, label = CCSNDataset[np.random.randint(0,N)]
    plt.imshow(image)
    plt.title(label_names[label])
    plt.axis(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 使用預訓練模型
# 列出torchvision.models裡內建預訓練模型。

# %%
import torchvision
dir(torchvision.models)
# Out:
# ['AlexNet',
#  'AlexNet_Weights',
#  'ConvNeXt',
#  'ConvNeXt_Base_Weights',
#  'ConvNeXt_Large_Weights',
#  'ConvNeXt_Small_Weights',
#  'ConvNeXt_Tiny_Weights',
#  'DenseNet',
#  'DenseNet121_Weights',
#  'DenseNet161_Weights',
#  'DenseNet169_Weights',
#  'DenseNet201_Weights',
#  'EfficientNet',
#  'EfficientNet_B0_Weights',
#  'EfficientNet_B1_Weights',
#  'EfficientNet_B2_Weights',
#  'EfficientNet_B3_Weights',
#  'EfficientNet_B4_Weights',
#  'EfficientNet_B5_Weights',
#  'EfficientNet_B6_Weights',
#  'EfficientNet_B7_Weights',
#  'EfficientNet_V2_L_Weights',
#  'EfficientNet_V2_M_Weights',
#  'EfficientNet_V2_S_Weights',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'GoogLeNet_Weights',
#  'Inception3',
#  'InceptionOutputs',
#  'Inception_V3_Weights',
#  'MNASNet',
#  'MNASNet0_5_Weights',
#  'MNASNet0_75_Weights',
#  'MNASNet1_0_Weights',
#  'MNASNet1_3_Weights',
#  'MaxVit',
#  'MaxVit_T_Weights',
#  'MobileNetV2',
#  'MobileNetV3',
#  'MobileNet_V2_Weights',
#  'MobileNet_V3_Large_Weights',
#  'MobileNet_V3_Small_Weights',
#  'RegNet',
#  'RegNet_X_16GF_Weights',
#  'RegNet_X_1_6GF_Weights',
#  'RegNet_X_32GF_Weights',
#  'RegNet_X_3_2GF_Weights',
#  'RegNet_X_400MF_Weights',
#  'RegNet_X_800MF_Weights',
#  'RegNet_X_8GF_Weights',
#  'RegNet_Y_128GF_Weights',
#  'RegNet_Y_16GF_Weights',
#  'RegNet_Y_1_6GF_Weights',
#  'RegNet_Y_32GF_Weights',
#  'RegNet_Y_3_2GF_Weights',
#  'RegNet_Y_400MF_Weights',
#  'RegNet_Y_800MF_Weights',
#  'RegNet_Y_8GF_Weights',
#  'ResNeXt101_32X8D_Weights',
#  'ResNeXt101_64X4D_Weights',
#  'ResNeXt50_32X4D_Weights',
#  'ResNet',
#  'ResNet101_Weights',
#  'ResNet152_Weights',
#  'ResNet18_Weights',
#  'ResNet34_Weights',
#  'ResNet50_Weights',
#  'ShuffleNetV2',
#  'ShuffleNet_V2_X0_5_Weights',
#  'ShuffleNet_V2_X1_0_Weights',
#  'ShuffleNet_V2_X1_5_Weights',
#  'ShuffleNet_V2_X2_0_Weights',
#  'SqueezeNet',
#  'SqueezeNet1_0_Weights',
#  'SqueezeNet1_1_Weights',
#  'SwinTransformer',
#  'Swin_B_Weights',
#  'Swin_S_Weights',
#  'Swin_T_Weights',
#  'Swin_V2_B_Weights',
#  'Swin_V2_S_Weights',
#  'Swin_V2_T_Weights',
#  'VGG',
#  'VGG11_BN_Weights',
#  'VGG11_Weights',
#  'VGG13_BN_Weights',
#  'VGG13_Weights',
#  'VGG16_BN_Weights',
#  'VGG16_Weights',
#  'VGG19_BN_Weights',
#  'VGG19_Weights',
#  'ViT_B_16_Weights',
#  'ViT_B_32_Weights',
#  'ViT_H_14_Weights',
#  'ViT_L_16_Weights',
#  'ViT_L_32_Weights',
#  'VisionTransformer',
#  'Weights',
#  'WeightsEnum',
#  'Wide_ResNet101_2_Weights',
#  'Wide_ResNet50_2_Weights',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_api',
#  '_meta',
#  '_utils',
#  'alexnet',
#  'convnext',
#  'convnext_base',
#  'convnext_large',
#  'convnext_small',
#  'convnext_tiny',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'efficientnet',
#  'efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b2',
#  'efficientnet_b3',
#  'efficientnet_b4',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'efficientnet_v2_l',
#  'efficientnet_v2_m',
#  'efficientnet_v2_s',
#  'get_model',
#  'get_model_builder',
#  'get_model_weights',
#  'get_weight',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'list_models',
#  'maxvit',
#  'maxvit_t',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
#  'mobilenet_v3_small',
#  'mobilenetv2',
#  'mobilenetv3',
#  'optical_flow',
#  'quantization',
#  'regnet',
#  'regnet_x_16gf',
#  'regnet_x_1_6gf',
#  'regnet_x_32gf',
#  'regnet_x_3_2gf',
#  'regnet_x_400mf',
#  'regnet_x_800mf',
#  'regnet_x_8gf',
#  'regnet_y_128gf',
#  'regnet_y_16gf',
#  'regnet_y_1_6gf',
#  'regnet_y_32gf',
#  'regnet_y_3_2gf',
#  'regnet_y_400mf',
#  'regnet_y_800mf',
#  'regnet_y_8gf',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext101_64x4d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'shufflenetv2',
#  'squeezenet',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'swin_b',
#  'swin_s',
#  'swin_t',
#  'swin_transformer',
#  'swin_v2_b',
#  'swin_v2_s',
#  'swin_v2_t',
#  'vgg',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'video',
#  'vision_transformer',
#  'vit_b_16',
#  'vit_b_32',
#  'vit_h_14',
#  'vit_l_16',
#  'vit_l_32',
#  'wide_resnet101_2',
#  'wide_resnet50_2']

# %%
from tempfile import TemporaryDirectory

def train_model(model, criterion, optimizer, dataloaders, dataset_sizes, num_epochs=25, patience = 0,scheduler = None):

    device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model = model.to(device)

    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_loss = None
        best_acc  = 0
        history = {'loss':[],'accuracy':[],'val_loss':[],'val_accuracy':[]}
        patience_c = 0
        for epoch in range(num_epochs):
            print(f'Epoch {epoch:3d}/{num_epochs - 1}',end=' ')

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                if phase == 'train' and scheduler:
                    scheduler.step(epoch_loss)

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}',end=' ' if phase=='train' else '\n')
                if phase == 'train':
                    history['loss'].append(epoch_loss)
                    history['accuracy'].append(epoch_acc.cpu().numpy())

                # deep copy the model
                if phase == 'val':
                    history['val_loss'].append(epoch_loss)
                    history['val_accuracy'].append(epoch_acc.cpu().numpy())
                    if best_acc < epoch_acc.cpu().numpy():
                        best_acc = epoch_acc.cpu().numpy()
                    if epoch == 0 or epoch_loss < best_loss:
                        best_loss = epoch_loss
                        patience_c= 0
                        torch.save(model.state_dict(), best_model_params_path)
                    else:
                        patience_c += 1

            if patience_c > patience:
                break

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model, history

def evaluate(model, dataloader):

    device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model.eval()   # Set model to evaluate mode

    running_loss = 0.0
    running_corrects = 0
    dataset_size     = 0
        # Iterate over data.
    for inputs, labels in dataloader:

        dataset_size += inputs.size(0)

        inputs = inputs.to(device)
        labels = labels.to(device)

        # forward
        # track history if only in train
        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        # statistics
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / dataset_size
    epoch_acc = running_corrects.double() / dataset_size

    print(f'test Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return epoch_loss, epoch_acc.cpu().numpy()

# %% [markdown]
# ### MyClassifierModel

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        # The arguments for commonly used modules:
        # torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        # torch.nn.MaxPool2d(kernel_size, stride, padding)
        
        self.cnn_layers = nn.Sequential(
            # 3 * 224 * 224 -> 64 * 111 * 111
            nn.Conv2d(3, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            nn.Conv2d(32, 64, 3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            # 64 * 111 * 111 -> 128 * 54 * 54
            nn.Conv2d(64, 128, 3),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),

            # 128 * 54 * 54 -> 256 * 26 * 26
            nn.Conv2d(128, 256, 3),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
        )
        
        #self-attention layer
        self.self_attn = nn.MultiheadAttention(embed_dim=256, num_heads=8, batch_first=True)

        self.fc_layers = nn.Sequential(
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),
            nn.Linear(256, 11),
        )

    def forward(self, x):
        # input (x): [batch_size, 3, 128, 128]
        # output: [batch_size, 11]

        # Extract features by convolutional layers.
        x = self.cnn_layers(x)

        # output -> [batch_size, 256 ,26 ,26] -> [batch_size, 512, 26*26] -> [batch_size, 26*26, 512]
        x = x.view(x.size(0), 256, -1).permute(0, 2, 1)  

        # output -> [batch_size, 26*26, 256]
        x, _ = self.self_attn(x, x, x)

        # global average pooling,output -> [batch_size, 256]
        x = x.mean(dim=1)  

        # The features are transformed by fully-connected layers to obtain the final logits.
        x = self.fc_layers(x)
        return x

# %%
from sklearn.model_selection import StratifiedKFold

device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

if torch.cuda.is_available():
    print('gpu is available')
else:
    print('cpu only')

data_transforms = {
    'train': torchvision.transforms.Compose([
        torchvision.transforms.RandomRotation(40),
        torchvision.transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        torchvision.transforms.RandomResizedCrop(224),
        torchvision.transforms.RandomHorizontalFlip(),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.CenterCrop(224),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

skf        = StratifiedKFold(n_splits=5, shuffle=True, random_state=0) # 80 % for training and validation sets, 20 % for the test set

batch_size = 64
epochs     = 100
patience   = epochs//5

test_accuracy = []
test_loss     = []
histories     = []

criterion = nn.CrossEntropyLoss()

for i, (train_idx, test_idx) in enumerate(skf.split(img_list,img_labels)):

    print('-'*50)

    X_train, X_valid, y_train, y_valid = sklearn.model_selection.train_test_split(img_list[train_idx],img_labels[train_idx],test_size=0.2,random_state=i)

    testloader = torch.utils.data.DataLoader(CCSNImageDataset(img_list[test_idx],img_labels[test_idx],data_transforms['train'],lambda x : torch.tensor(x,dtype=torch.long)),batch_size=1,shuffle=True)
    trainloader= torch.utils.data.DataLoader(CCSNImageDataset(X_train,y_train,data_transforms['train'],lambda x : torch.tensor(x,dtype=torch.long)),batch_size=batch_size,shuffle=True)
    validloader= torch.utils.data.DataLoader(CCSNImageDataset(X_valid,y_valid,data_transforms['val'],lambda x : torch.tensor(x,dtype=torch.long)),batch_size=batch_size,shuffle=True)

    classifier = Classifier()
    for name, param in classifier.self_attn.named_parameters():
        param.requires_grad = False
    for name, param in classifier.named_parameters():
        print(name, param.requires_grad)
    classifier = classifier.to(device)
    # Observe that all parameters are being optimized
    optimizer_ft = optim.Adam(classifier.parameters(), lr=0.001, weight_decay=1e-4)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_ft, mode='min', factor=0.5, patience=3)

    trained_model, history = train_model(classifier, criterion, optimizer_ft,
                                         dataloaders={'train':trainloader,'val':validloader},
                                         dataset_sizes={'train':X_train.shape[0],'val':X_valid.shape[0]},
                                         patience=patience,
                                         num_epochs=epochs,
                                         scheduler = scheduler)

    histories.append(history)
    print(f'Fold {i+1:2d}',end=' ')
    loss, acc = evaluate(trained_model, testloader)

    test_loss.append(loss)
    test_accuracy.append(acc)
# Out:
# gpu is available
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.4206 Acc: 0.1530 val Loss: 2.2221 Acc: 0.2482
# Epoch   1/99 train Loss: 2.2645 Acc: 0.2237 val Loss: 2.1871 Acc: 0.2973
# Epoch   2/99 train Loss: 2.2669 Acc: 0.2194 val Loss: 2.1015 Acc: 0.2850
# Epoch   3/99 train Loss: 2.1805 Acc: 0.2274 val Loss: 2.0166 Acc: 0.2875
# Epoch   4/99 train Loss: 2.1931 Acc: 0.2403 val Loss: 2.0441 Acc: 0.3022
# Epoch   5/99 train Loss: 2.1721 Acc: 0.2391 val Loss: 2.0676 Acc: 0.2801
# Epoch   6/99 train Loss: 2.1469 Acc: 0.2618 val Loss: 1.9924 Acc: 0.3219
# Epoch   7/99 train Loss: 2.1196 Acc: 0.2575 val Loss: 2.0836 Acc: 0.2703
# Epoch   8/99 train Loss: 2.1405 Acc: 0.2557 val Loss: 1.9828 Acc: 0.3464
# Epoch   9/99 train Loss: 2.1020 Acc: 0.2674 val Loss: 2.0165 Acc: 0.2998
# Epoch  10/99 train Loss: 2.0725 Acc: 0.2655 val Loss: 2.1546 Acc: 0.2727
# Epoch  11/99 train Loss: 2.1086 Acc: 0.2661 val Loss: 1.9725 Acc: 0.3391
# Epoch  12/99 train Loss: 2.0765 Acc: 0.2747 val Loss: 2.0026 Acc: 0.2998
# Epoch  13/99 train Loss: 2.0577 Acc: 0.2680 val Loss: 1.9567 Acc: 0.3268
# Epoch  14/99 train Loss: 2.0735 Acc: 0.2661 val Loss: 1.9542 Acc: 0.3686
# Epoch  15/99 train Loss: 2.0361 Acc: 0.2926 val Loss: 1.9789 Acc: 0.2998
# Epoch  16/99 train Loss: 2.0387 Acc: 0.2919 val Loss: 1.9137 Acc: 0.3219
# Epoch  17/99 train Loss: 2.0237 Acc: 0.3036 val Loss: 1.9356 Acc: 0.3808
# Epoch  18/99 train Loss: 2.0126 Acc: 0.2895 val Loss: 1.8932 Acc: 0.3563
# Epoch  19/99 train Loss: 1.9905 Acc: 0.3061 val Loss: 1.9177 Acc: 0.3342
# Epoch  20/99 train Loss: 2.0089 Acc: 0.3018 val Loss: 1.8791 Acc: 0.3784
# Epoch  21/99 train Loss: 1.9897 Acc: 0.3098 val Loss: 1.8410 Acc: 0.3882
# Epoch  22/99 train Loss: 1.9771 Acc: 0.3141 val Loss: 1.8992 Acc: 0.3145
# Epoch  23/99 train Loss: 1.9741 Acc: 0.2999 val Loss: 1.9110 Acc: 0.3440
# Epoch  24/99 train Loss: 1.9875 Acc: 0.3030 val Loss: 1.8890 Acc: 0.3219
# Epoch  25/99 train Loss: 1.9740 Acc: 0.3153 val Loss: 1.8556 Acc: 0.3538
# Epoch  26/99 train Loss: 1.9445 Acc: 0.3208 val Loss: 1.8240 Acc: 0.4054
# Epoch  27/99 train Loss: 1.9537 Acc: 0.3264 val Loss: 1.8047 Acc: 0.3882
# Epoch  28/99 train Loss: 1.9357 Acc: 0.3153 val Loss: 1.8359 Acc: 0.3931
# Epoch  29/99 train Loss: 1.9188 Acc: 0.3282 val Loss: 1.8393 Acc: 0.3808
# Epoch  30/99 train Loss: 1.9432 Acc: 0.3122 val Loss: 1.8333 Acc: 0.3808
# Epoch  31/99 train Loss: 1.9194 Acc: 0.3282 val Loss: 1.8502 Acc: 0.3489
# Epoch  32/99 train Loss: 1.8947 Acc: 0.3313 val Loss: 1.7665 Acc: 0.3956
# Epoch  33/99 train Loss: 1.9003 Acc: 0.3356 val Loss: 1.8736 Acc: 0.3661
# Epoch  34/99 train Loss: 1.9125 Acc: 0.3245 val Loss: 1.7956 Acc: 0.3907
# Epoch  35/99 train Loss: 1.9149 Acc: 0.3423 val Loss: 1.7795 Acc: 0.3980
# Epoch  36/99 train Loss: 1.8950 Acc: 0.3380 val Loss: 1.8351 Acc: 0.3735
# Epoch  37/99 train Loss: 1.8982 Acc: 0.3337 val Loss: 1.7772 Acc: 0.4128
# Epoch  38/99 train Loss: 1.8663 Acc: 0.3546 val Loss: 1.7229 Acc: 0.4373
# Epoch  39/99 train Loss: 1.8567 Acc: 0.3497 val Loss: 1.7624 Acc: 0.4177
# Epoch  40/99 train Loss: 1.8686 Acc: 0.3510 val Loss: 1.7107 Acc: 0.4447
# Epoch  41/99 train Loss: 1.8822 Acc: 0.3399 val Loss: 1.7086 Acc: 0.4300
# Epoch  42/99 train Loss: 1.8619 Acc: 0.3423 val Loss: 1.7229 Acc: 0.4275
# Epoch  43/99 train Loss: 1.8413 Acc: 0.3663 val Loss: 1.7138 Acc: 0.4152
# Epoch  44/99 train Loss: 1.8305 Acc: 0.3614 val Loss: 1.7079 Acc: 0.4373
# Epoch  45/99 train Loss: 1.8234 Acc: 0.3651 val Loss: 1.6913 Acc: 0.4054
# Epoch  46/99 train Loss: 1.8160 Acc: 0.3657 val Loss: 1.7290 Acc: 0.4201
# Epoch  47/99 train Loss: 1.8301 Acc: 0.3596 val Loss: 1.7357 Acc: 0.4251
# Epoch  48/99 train Loss: 1.8177 Acc: 0.3602 val Loss: 1.6885 Acc: 0.4201
# Epoch  49/99 train Loss: 1.8261 Acc: 0.3577 val Loss: 1.6929 Acc: 0.4300
# Epoch  50/99 train Loss: 1.8365 Acc: 0.3614 val Loss: 1.6891 Acc: 0.4275
# Epoch  51/99 train Loss: 1.7763 Acc: 0.3688 val Loss: 1.6671 Acc: 0.4324
# Epoch  52/99 train Loss: 1.8044 Acc: 0.3768 val Loss: 1.6686 Acc: 0.4373
# Epoch  53/99 train Loss: 1.7991 Acc: 0.3811 val Loss: 1.6464 Acc: 0.4767
# Epoch  54/99 train Loss: 1.7880 Acc: 0.3786 val Loss: 1.6660 Acc: 0.4447
# Epoch  55/99 train Loss: 1.7954 Acc: 0.3669 val Loss: 1.6666 Acc: 0.4373
# Epoch  56/99 train Loss: 1.7644 Acc: 0.3737 val Loss: 1.6444 Acc: 0.4545
# Epoch  57/99 train Loss: 1.7482 Acc: 0.3891 val Loss: 1.6374 Acc: 0.4447
# Epoch  58/99 train Loss: 1.7685 Acc: 0.3958 val Loss: 1.6406 Acc: 0.4767
# Epoch  59/99 train Loss: 1.7596 Acc: 0.3884 val Loss: 1.6362 Acc: 0.4595
# Epoch  60/99 train Loss: 1.7493 Acc: 0.3903 val Loss: 1.6344 Acc: 0.4595
# Epoch  61/99 train Loss: 1.7405 Acc: 0.3940 val Loss: 1.6217 Acc: 0.4693
# Epoch  62/99 train Loss: 1.7109 Acc: 0.4020 val Loss: 1.6252 Acc: 0.4595
# Epoch  63/99 train Loss: 1.7356 Acc: 0.3805 val Loss: 1.6210 Acc: 0.4619
# Epoch  64/99 train Loss: 1.7371 Acc: 0.4020 val Loss: 1.6330 Acc: 0.4496
# Epoch  65/99 train Loss: 1.7053 Acc: 0.4210 val Loss: 1.6307 Acc: 0.4570
# Epoch  66/99 train Loss: 1.7326 Acc: 0.4143 val Loss: 1.5981 Acc: 0.4816
# Epoch  67/99 train Loss: 1.7318 Acc: 0.4075 val Loss: 1.6199 Acc: 0.4472
# Epoch  68/99 train Loss: 1.7193 Acc: 0.4001 val Loss: 1.6141 Acc: 0.4472
# Epoch  69/99 train Loss: 1.7214 Acc: 0.4063 val Loss: 1.6188 Acc: 0.4472
# Epoch  70/99 train Loss: 1.7311 Acc: 0.3989 val Loss: 1.6051 Acc: 0.4668
# Epoch  71/99 train Loss: 1.7014 Acc: 0.4106 val Loss: 1.6112 Acc: 0.4545
# Epoch  72/99 train Loss: 1.7019 Acc: 0.4198 val Loss: 1.6071 Acc: 0.4496
# Epoch  73/99 train Loss: 1.6747 Acc: 0.3903 val Loss: 1.5869 Acc: 0.4693
# Epoch  74/99 train Loss: 1.6944 Acc: 0.4026 val Loss: 1.6000 Acc: 0.4717
# Epoch  75/99 train Loss: 1.7152 Acc: 0.4161 val Loss: 1.6094 Acc: 0.4668
# Epoch  76/99 train Loss: 1.6855 Acc: 0.4204 val Loss: 1.6136 Acc: 0.4595
# Epoch  77/99 train Loss: 1.6823 Acc: 0.4124 val Loss: 1.5973 Acc: 0.4619
# Epoch  78/99 train Loss: 1.6964 Acc: 0.4118 val Loss: 1.5935 Acc: 0.4742
# Epoch  79/99 train Loss: 1.6646 Acc: 0.4198 val Loss: 1.5936 Acc: 0.4668
# Epoch  80/99 train Loss: 1.6752 Acc: 0.4278 val Loss: 1.5954 Acc: 0.4717
# Epoch  81/99 train Loss: 1.6704 Acc: 0.4038 val Loss: 1.5992 Acc: 0.4545
# Epoch  82/99 train Loss: 1.6533 Acc: 0.4247 val Loss: 1.5927 Acc: 0.4644
# Epoch  83/99 train Loss: 1.6944 Acc: 0.4093 val Loss: 1.5960 Acc: 0.4644
# Epoch  84/99 train Loss: 1.6842 Acc: 0.4057 val Loss: 1.5965 Acc: 0.4644
# Epoch  85/99 train Loss: 1.6810 Acc: 0.4124 val Loss: 1.6019 Acc: 0.4717
# Epoch  86/99 train Loss: 1.6786 Acc: 0.4327 val Loss: 1.5944 Acc: 0.4693
# Epoch  87/99 train Loss: 1.6990 Acc: 0.4057 val Loss: 1.5926 Acc: 0.4742
# Epoch  88/99 train Loss: 1.6903 Acc: 0.4161 val Loss: 1.5865 Acc: 0.4791
# Epoch  89/99 train Loss: 1.6739 Acc: 0.4136 val Loss: 1.5892 Acc: 0.4742
# Epoch  90/99 train Loss: 1.6840 Acc: 0.4026 val Loss: 1.5895 Acc: 0.4717
# Epoch  91/99 train Loss: 1.6765 Acc: 0.4216 val Loss: 1.5863 Acc: 0.4668
# Epoch  92/99 train Loss: 1.6870 Acc: 0.4106 val Loss: 1.5794 Acc: 0.4791
# Epoch  93/99 train Loss: 1.7032 Acc: 0.3940 val Loss: 1.5817 Acc: 0.4840
# Epoch  94/99 train Loss: 1.6748 Acc: 0.4186 val Loss: 1.5791 Acc: 0.4767
# Epoch  95/99 train Loss: 1.6846 Acc: 0.3964 val Loss: 1.5822 Acc: 0.4840
# Epoch  96/99 train Loss: 1.7009 Acc: 0.4081 val Loss: 1.5798 Acc: 0.4816
# Epoch  97/99 train Loss: 1.6871 Acc: 0.4216 val Loss: 1.5828 Acc: 0.4767
# Epoch  98/99 train Loss: 1.6725 Acc: 0.4204 val Loss: 1.5862 Acc: 0.4742
# Epoch  99/99 train Loss: 1.6724 Acc: 0.4124 val Loss: 1.5843 Acc: 0.4742
# Training complete in 137m 49s
# Best val Acc: 0.484029
# Fold  1 test Loss: 1.8237 Acc: 0.3674
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.4105 Acc: 0.1739 val Loss: 2.2011 Acc: 0.2580
# Epoch   1/99 train Loss: 2.2749 Acc: 0.2028 val Loss: 2.1238 Acc: 0.2752
# Epoch   2/99 train Loss: 2.2570 Acc: 0.2133 val Loss: 2.0647 Acc: 0.2531
# Epoch   3/99 train Loss: 2.2065 Acc: 0.2145 val Loss: 2.0855 Acc: 0.2875
# Epoch   4/99 train Loss: 2.2037 Acc: 0.2280 val Loss: 2.0966 Acc: 0.2924
# Epoch   5/99 train Loss: 2.1642 Acc: 0.2366 val Loss: 2.0092 Acc: 0.3071
# Epoch   6/99 train Loss: 2.1378 Acc: 0.2471 val Loss: 2.0068 Acc: 0.2973
# Epoch   7/99 train Loss: 2.1389 Acc: 0.2483 val Loss: 2.0150 Acc: 0.3022
# Epoch   8/99 train Loss: 2.1230 Acc: 0.2526 val Loss: 1.9577 Acc: 0.3538
# Epoch   9/99 train Loss: 2.1059 Acc: 0.2434 val Loss: 2.0060 Acc: 0.2580
# Epoch  10/99 train Loss: 2.1037 Acc: 0.2618 val Loss: 1.9662 Acc: 0.3268
# Epoch  11/99 train Loss: 2.0751 Acc: 0.2680 val Loss: 2.0337 Acc: 0.2850
# Epoch  12/99 train Loss: 2.0643 Acc: 0.2827 val Loss: 1.9306 Acc: 0.3170
# Epoch  13/99 train Loss: 2.0556 Acc: 0.2797 val Loss: 1.9182 Acc: 0.3317
# Epoch  14/99 train Loss: 2.0485 Acc: 0.2766 val Loss: 1.9317 Acc: 0.3587
# Epoch  15/99 train Loss: 2.0250 Acc: 0.2889 val Loss: 1.9212 Acc: 0.3047
# Epoch  16/99 train Loss: 2.0354 Acc: 0.2852 val Loss: 1.9445 Acc: 0.3268
# Epoch  17/99 train Loss: 2.0391 Acc: 0.2944 val Loss: 1.9591 Acc: 0.3415
# Epoch  18/99 train Loss: 1.9880 Acc: 0.3012 val Loss: 1.9159 Acc: 0.3464
# Epoch  19/99 train Loss: 2.0247 Acc: 0.2876 val Loss: 1.8946 Acc: 0.3563
# Epoch  20/99 train Loss: 1.9980 Acc: 0.3042 val Loss: 1.9260 Acc: 0.3120
# Epoch  21/99 train Loss: 1.9910 Acc: 0.3061 val Loss: 1.9392 Acc: 0.3464
# Epoch  22/99 train Loss: 1.9790 Acc: 0.3036 val Loss: 1.8749 Acc: 0.3661
# Epoch  23/99 train Loss: 1.9621 Acc: 0.3085 val Loss: 1.8520 Acc: 0.3440
# Epoch  24/99 train Loss: 1.9474 Acc: 0.3055 val Loss: 1.9173 Acc: 0.3514
# Epoch  25/99 train Loss: 1.9434 Acc: 0.3227 val Loss: 1.8486 Acc: 0.3808
# Epoch  26/99 train Loss: 1.9564 Acc: 0.2926 val Loss: 1.8912 Acc: 0.3710
# Epoch  27/99 train Loss: 1.9212 Acc: 0.3294 val Loss: 1.8791 Acc: 0.3661
# Epoch  28/99 train Loss: 1.9197 Acc: 0.3190 val Loss: 1.8554 Acc: 0.3735
# Epoch  29/99 train Loss: 1.9571 Acc: 0.3270 val Loss: 1.8194 Acc: 0.3784
# Epoch  30/99 train Loss: 1.9289 Acc: 0.3245 val Loss: 1.7999 Acc: 0.3636
# Epoch  31/99 train Loss: 1.8941 Acc: 0.3423 val Loss: 1.7740 Acc: 0.4029
# Epoch  32/99 train Loss: 1.8792 Acc: 0.3362 val Loss: 1.8580 Acc: 0.3759
# Epoch  33/99 train Loss: 1.8764 Acc: 0.3473 val Loss: 1.8066 Acc: 0.3857
# Epoch  34/99 train Loss: 1.8981 Acc: 0.3301 val Loss: 1.8437 Acc: 0.3784
# Epoch  35/99 train Loss: 1.8992 Acc: 0.3239 val Loss: 1.7537 Acc: 0.4152
# Epoch  36/99 train Loss: 1.8818 Acc: 0.3362 val Loss: 1.7884 Acc: 0.3907
# Epoch  37/99 train Loss: 1.8614 Acc: 0.3374 val Loss: 1.7574 Acc: 0.4054
# Epoch  38/99 train Loss: 1.8536 Acc: 0.3448 val Loss: 1.7540 Acc: 0.4128
# Epoch  39/99 train Loss: 1.8539 Acc: 0.3344 val Loss: 1.7615 Acc: 0.3931
# Epoch  40/99 train Loss: 1.8541 Acc: 0.3423 val Loss: 1.7909 Acc: 0.3563
# Epoch  41/99 train Loss: 1.8313 Acc: 0.3620 val Loss: 1.7365 Acc: 0.4079
# Epoch  42/99 train Loss: 1.8420 Acc: 0.3546 val Loss: 1.7834 Acc: 0.4103
# Epoch  43/99 train Loss: 1.8286 Acc: 0.3546 val Loss: 1.7744 Acc: 0.3956
# Epoch  44/99 train Loss: 1.8244 Acc: 0.3608 val Loss: 1.7377 Acc: 0.3931
# Epoch  45/99 train Loss: 1.7969 Acc: 0.3737 val Loss: 1.7040 Acc: 0.4177
# Epoch  46/99 train Loss: 1.7950 Acc: 0.3755 val Loss: 1.7565 Acc: 0.3980
# Epoch  47/99 train Loss: 1.8041 Acc: 0.3817 val Loss: 1.7526 Acc: 0.3808
# Epoch  48/99 train Loss: 1.7803 Acc: 0.3663 val Loss: 1.7136 Acc: 0.4054
# Epoch  49/99 train Loss: 1.7935 Acc: 0.3632 val Loss: 1.7136 Acc: 0.4300
# Epoch  50/99 train Loss: 1.7959 Acc: 0.3675 val Loss: 1.7075 Acc: 0.4275
# Epoch  51/99 train Loss: 1.7694 Acc: 0.3964 val Loss: 1.8414 Acc: 0.4029
# Epoch  52/99 train Loss: 1.7600 Acc: 0.3762 val Loss: 1.7834 Acc: 0.3784
# Epoch  53/99 train Loss: 1.7857 Acc: 0.3755 val Loss: 1.7011 Acc: 0.4349
# Epoch  54/99 train Loss: 1.7927 Acc: 0.3712 val Loss: 1.7748 Acc: 0.4177
# Epoch  55/99 train Loss: 1.8252 Acc: 0.3577 val Loss: 1.7106 Acc: 0.4349
# Epoch  56/99 train Loss: 1.7736 Acc: 0.3780 val Loss: 1.7254 Acc: 0.4054
# Epoch  57/99 train Loss: 1.7350 Acc: 0.4032 val Loss: 1.6816 Acc: 0.4423
# Epoch  58/99 train Loss: 1.7166 Acc: 0.4130 val Loss: 1.6964 Acc: 0.4496
# Epoch  59/99 train Loss: 1.7131 Acc: 0.3866 val Loss: 1.6752 Acc: 0.4472
# Epoch  60/99 train Loss: 1.6907 Acc: 0.4020 val Loss: 1.6635 Acc: 0.4423
# Epoch  61/99 train Loss: 1.7029 Acc: 0.3884 val Loss: 1.6892 Acc: 0.4275
# Epoch  62/99 train Loss: 1.6946 Acc: 0.3946 val Loss: 1.6765 Acc: 0.4545
# Epoch  63/99 train Loss: 1.7058 Acc: 0.4026 val Loss: 1.6595 Acc: 0.4496
# Epoch  64/99 train Loss: 1.7015 Acc: 0.3964 val Loss: 1.6973 Acc: 0.4447
# Epoch  65/99 train Loss: 1.6632 Acc: 0.4124 val Loss: 1.6742 Acc: 0.4496
# Epoch  66/99 train Loss: 1.6347 Acc: 0.4014 val Loss: 1.6775 Acc: 0.4447
# Epoch  67/99 train Loss: 1.6402 Acc: 0.4216 val Loss: 1.6746 Acc: 0.4619
# Epoch  68/99 train Loss: 1.6395 Acc: 0.4290 val Loss: 1.6651 Acc: 0.4447
# Epoch  69/99 train Loss: 1.6449 Acc: 0.4253 val Loss: 1.6810 Acc: 0.4349
# Epoch  70/99 train Loss: 1.6387 Acc: 0.4210 val Loss: 1.6678 Acc: 0.4644
# Epoch  71/99 train Loss: 1.6294 Acc: 0.4302 val Loss: 1.6480 Acc: 0.4496
# Epoch  72/99 train Loss: 1.6712 Acc: 0.4075 val Loss: 1.6514 Acc: 0.4423
# Epoch  73/99 train Loss: 1.6261 Acc: 0.4186 val Loss: 1.6505 Acc: 0.4496
# Epoch  74/99 train Loss: 1.6201 Acc: 0.4321 val Loss: 1.6500 Acc: 0.4668
# Epoch  75/99 train Loss: 1.6352 Acc: 0.4309 val Loss: 1.6530 Acc: 0.4644
# Epoch  76/99 train Loss: 1.5936 Acc: 0.4530 val Loss: 1.6463 Acc: 0.4521
# Epoch  77/99 train Loss: 1.6116 Acc: 0.4345 val Loss: 1.6591 Acc: 0.4496
# Epoch  78/99 train Loss: 1.6091 Acc: 0.4431 val Loss: 1.6465 Acc: 0.4644
# Epoch  79/99 train Loss: 1.6248 Acc: 0.4395 val Loss: 1.6620 Acc: 0.4595
# Epoch  80/99 train Loss: 1.6151 Acc: 0.4253 val Loss: 1.6546 Acc: 0.4595
# Epoch  81/99 train Loss: 1.5941 Acc: 0.4542 val Loss: 1.6492 Acc: 0.4644
# Epoch  82/99 train Loss: 1.6189 Acc: 0.4235 val Loss: 1.6497 Acc: 0.4545
# Epoch  83/99 train Loss: 1.5930 Acc: 0.4462 val Loss: 1.6517 Acc: 0.4644
# Epoch  84/99 train Loss: 1.6000 Acc: 0.4382 val Loss: 1.6488 Acc: 0.4644
# Epoch  85/99 train Loss: 1.5880 Acc: 0.4518 val Loss: 1.6462 Acc: 0.4693
# Epoch  86/99 train Loss: 1.5876 Acc: 0.4462 val Loss: 1.6532 Acc: 0.4717
# Epoch  87/99 train Loss: 1.5841 Acc: 0.4302 val Loss: 1.6461 Acc: 0.4595
# Epoch  88/99 train Loss: 1.5984 Acc: 0.4370 val Loss: 1.6421 Acc: 0.4668
# Epoch  89/99 train Loss: 1.5916 Acc: 0.4438 val Loss: 1.6507 Acc: 0.4619
# Epoch  90/99 train Loss: 1.5949 Acc: 0.4345 val Loss: 1.6499 Acc: 0.4668
# Epoch  91/99 train Loss: 1.6096 Acc: 0.4284 val Loss: 1.6490 Acc: 0.4644
# Epoch  92/99 train Loss: 1.5882 Acc: 0.4487 val Loss: 1.6443 Acc: 0.4570
# Epoch  93/99 train Loss: 1.5709 Acc: 0.4395 val Loss: 1.6483 Acc: 0.4570
# Epoch  94/99 train Loss: 1.5987 Acc: 0.4487 val Loss: 1.6480 Acc: 0.4717
# Epoch  95/99 train Loss: 1.5742 Acc: 0.4456 val Loss: 1.6519 Acc: 0.4595
# Epoch  96/99 train Loss: 1.5813 Acc: 0.4450 val Loss: 1.6503 Acc: 0.4619
# Epoch  97/99 train Loss: 1.5627 Acc: 0.4493 val Loss: 1.6425 Acc: 0.4644
# Epoch  98/99 train Loss: 1.5679 Acc: 0.4339 val Loss: 1.6443 Acc: 0.4619
# Epoch  99/99 train Loss: 1.5967 Acc: 0.4241 val Loss: 1.6454 Acc: 0.4668
# Training complete in 141m 29s
# Best val Acc: 0.471744
# Fold  2 test Loss: 1.8097 Acc: 0.4047
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.3964 Acc: 0.1696 val Loss: 2.2242 Acc: 0.2801
# Epoch   1/99 train Loss: 2.2758 Acc: 0.2102 val Loss: 2.0983 Acc: 0.2629
# Epoch   2/99 train Loss: 2.2237 Acc: 0.2163 val Loss: 2.1311 Acc: 0.2555
# Epoch   3/99 train Loss: 2.1772 Acc: 0.2532 val Loss: 2.0450 Acc: 0.2899
# Epoch   4/99 train Loss: 2.1506 Acc: 0.2459 val Loss: 2.1588 Acc: 0.2408
# Epoch   5/99 train Loss: 2.1508 Acc: 0.2526 val Loss: 2.0869 Acc: 0.2752
# Epoch   6/99 train Loss: 2.0883 Acc: 0.2680 val Loss: 2.0453 Acc: 0.2875
# Epoch   7/99 train Loss: 2.1024 Acc: 0.2735 val Loss: 2.0300 Acc: 0.3096
# Epoch   8/99 train Loss: 2.0688 Acc: 0.2741 val Loss: 2.0446 Acc: 0.2850
# Epoch   9/99 train Loss: 2.0591 Acc: 0.2846 val Loss: 1.9862 Acc: 0.3071
# Epoch  10/99 train Loss: 2.0546 Acc: 0.2809 val Loss: 2.0397 Acc: 0.2973
# Epoch  11/99 train Loss: 2.0254 Acc: 0.2790 val Loss: 2.0716 Acc: 0.2555
# Epoch  12/99 train Loss: 2.0514 Acc: 0.2821 val Loss: 1.9916 Acc: 0.3096
# Epoch  13/99 train Loss: 2.0275 Acc: 0.2809 val Loss: 1.9987 Acc: 0.3243
# Epoch  14/99 train Loss: 2.0319 Acc: 0.2938 val Loss: 1.9916 Acc: 0.2875
# Epoch  15/99 train Loss: 2.0312 Acc: 0.2975 val Loss: 1.9720 Acc: 0.3292
# Epoch  16/99 train Loss: 1.9885 Acc: 0.2993 val Loss: 1.9330 Acc: 0.3636
# Epoch  17/99 train Loss: 1.9660 Acc: 0.3030 val Loss: 1.9270 Acc: 0.3464
# Epoch  18/99 train Loss: 1.9473 Acc: 0.3307 val Loss: 1.9106 Acc: 0.3686
# Epoch  19/99 train Loss: 1.9680 Acc: 0.3344 val Loss: 1.9626 Acc: 0.3464
# Epoch  20/99 train Loss: 1.9551 Acc: 0.3153 val Loss: 1.9169 Acc: 0.3514
# Epoch  21/99 train Loss: 1.9434 Acc: 0.3092 val Loss: 1.9493 Acc: 0.3366
# Epoch  22/99 train Loss: 1.9480 Acc: 0.3227 val Loss: 1.8851 Acc: 0.3686
# Epoch  23/99 train Loss: 1.9497 Acc: 0.3153 val Loss: 1.9452 Acc: 0.3219
# Epoch  24/99 train Loss: 1.9220 Acc: 0.3159 val Loss: 1.8830 Acc: 0.3759
# Epoch  25/99 train Loss: 1.9448 Acc: 0.3215 val Loss: 1.8670 Acc: 0.3686
# Epoch  26/99 train Loss: 1.9054 Acc: 0.3362 val Loss: 1.9359 Acc: 0.3464
# Epoch  27/99 train Loss: 1.9101 Acc: 0.3417 val Loss: 1.8778 Acc: 0.3587
# Epoch  28/99 train Loss: 1.9418 Acc: 0.3184 val Loss: 1.9037 Acc: 0.3587
# Epoch  29/99 train Loss: 1.9027 Acc: 0.3460 val Loss: 1.8836 Acc: 0.3636
# Epoch  30/99 train Loss: 1.9145 Acc: 0.3288 val Loss: 1.8475 Acc: 0.3784
# Epoch  31/99 train Loss: 1.9014 Acc: 0.3344 val Loss: 1.8771 Acc: 0.3636
# Epoch  32/99 train Loss: 1.9147 Acc: 0.3282 val Loss: 1.9279 Acc: 0.3440
# Epoch  33/99 train Loss: 1.8892 Acc: 0.3460 val Loss: 1.8707 Acc: 0.3808
# Epoch  34/99 train Loss: 1.8601 Acc: 0.3608 val Loss: 1.8309 Acc: 0.3833
# Epoch  35/99 train Loss: 1.8733 Acc: 0.3442 val Loss: 1.8379 Acc: 0.3636
# Epoch  36/99 train Loss: 1.8631 Acc: 0.3546 val Loss: 1.8154 Acc: 0.3833
# Epoch  37/99 train Loss: 1.9087 Acc: 0.3356 val Loss: 1.8449 Acc: 0.3759
# Epoch  38/99 train Loss: 1.8927 Acc: 0.3405 val Loss: 1.8300 Acc: 0.4054
# Epoch  39/99 train Loss: 1.8496 Acc: 0.3577 val Loss: 1.8208 Acc: 0.3857
# Epoch  40/99 train Loss: 1.8192 Acc: 0.3719 val Loss: 1.8110 Acc: 0.3931
# Epoch  41/99 train Loss: 1.8250 Acc: 0.3510 val Loss: 1.8088 Acc: 0.4005
# Epoch  42/99 train Loss: 1.8166 Acc: 0.3755 val Loss: 1.7776 Acc: 0.4079
# Epoch  43/99 train Loss: 1.8284 Acc: 0.3712 val Loss: 1.7758 Acc: 0.4226
# Epoch  44/99 train Loss: 1.8098 Acc: 0.3651 val Loss: 1.7828 Acc: 0.4079
# Epoch  45/99 train Loss: 1.8232 Acc: 0.3614 val Loss: 1.7791 Acc: 0.4226
# Epoch  46/99 train Loss: 1.8164 Acc: 0.3762 val Loss: 1.8234 Acc: 0.3882
# Epoch  47/99 train Loss: 1.8153 Acc: 0.3712 val Loss: 1.7888 Acc: 0.4079
# Epoch  48/99 train Loss: 1.8075 Acc: 0.3626 val Loss: 1.7709 Acc: 0.4300
# Epoch  49/99 train Loss: 1.8102 Acc: 0.3749 val Loss: 1.7661 Acc: 0.3980
# Epoch  50/99 train Loss: 1.8137 Acc: 0.3755 val Loss: 1.7472 Acc: 0.4300
# Epoch  51/99 train Loss: 1.8297 Acc: 0.3540 val Loss: 1.7777 Acc: 0.4373
# Epoch  52/99 train Loss: 1.7875 Acc: 0.3805 val Loss: 1.7922 Acc: 0.3956
# Epoch  53/99 train Loss: 1.7946 Acc: 0.3792 val Loss: 1.7640 Acc: 0.4152
# Epoch  54/99 train Loss: 1.7992 Acc: 0.3762 val Loss: 1.7538 Acc: 0.4128
# Epoch  55/99 train Loss: 1.7879 Acc: 0.3675 val Loss: 1.7557 Acc: 0.4201
# Epoch  56/99 train Loss: 1.7843 Acc: 0.3841 val Loss: 1.7585 Acc: 0.3956
# Epoch  57/99 train Loss: 1.7817 Acc: 0.3927 val Loss: 1.7676 Acc: 0.4349
# Epoch  58/99 train Loss: 1.7805 Acc: 0.3762 val Loss: 1.7352 Acc: 0.4251
# Epoch  59/99 train Loss: 1.7769 Acc: 0.3780 val Loss: 1.7433 Acc: 0.4300
# Epoch  60/99 train Loss: 1.7898 Acc: 0.3823 val Loss: 1.7506 Acc: 0.4079
# Epoch  61/99 train Loss: 1.7676 Acc: 0.3934 val Loss: 1.7492 Acc: 0.4103
# Epoch  62/99 train Loss: 1.7677 Acc: 0.3792 val Loss: 1.7321 Acc: 0.4029
# Epoch  63/99 train Loss: 1.7745 Acc: 0.3946 val Loss: 1.7035 Acc: 0.4054
# Epoch  64/99 train Loss: 1.7623 Acc: 0.3897 val Loss: 1.7487 Acc: 0.4128
# Epoch  65/99 train Loss: 1.7731 Acc: 0.3817 val Loss: 1.7574 Acc: 0.4128
# Epoch  66/99 train Loss: 1.7776 Acc: 0.3755 val Loss: 1.7276 Acc: 0.4226
# Epoch  67/99 train Loss: 1.7501 Acc: 0.3872 val Loss: 1.7112 Acc: 0.4103
# Epoch  68/99 train Loss: 1.7428 Acc: 0.3989 val Loss: 1.7347 Acc: 0.4029
# Epoch  69/99 train Loss: 1.7442 Acc: 0.3743 val Loss: 1.7443 Acc: 0.4005
# Epoch  70/99 train Loss: 1.7291 Acc: 0.3946 val Loss: 1.7188 Acc: 0.4152
# Epoch  71/99 train Loss: 1.7540 Acc: 0.3829 val Loss: 1.7373 Acc: 0.4054
# Epoch  72/99 train Loss: 1.7517 Acc: 0.3835 val Loss: 1.7117 Acc: 0.4251
# Epoch  73/99 train Loss: 1.7224 Acc: 0.3970 val Loss: 1.7200 Acc: 0.4201
# Epoch  74/99 train Loss: 1.7359 Acc: 0.3983 val Loss: 1.7267 Acc: 0.4226
# Epoch  75/99 train Loss: 1.7343 Acc: 0.3989 val Loss: 1.7201 Acc: 0.4201
# Epoch  76/99 train Loss: 1.7111 Acc: 0.3983 val Loss: 1.7222 Acc: 0.4029
# Epoch  77/99 train Loss: 1.7145 Acc: 0.4001 val Loss: 1.7076 Acc: 0.4373
# Epoch  78/99 train Loss: 1.7424 Acc: 0.3921 val Loss: 1.7140 Acc: 0.4152
# Epoch  79/99 train Loss: 1.7225 Acc: 0.4038 val Loss: 1.6862 Acc: 0.4545
# Epoch  80/99 train Loss: 1.7267 Acc: 0.3915 val Loss: 1.7212 Acc: 0.4349
# Epoch  81/99 train Loss: 1.7020 Acc: 0.4161 val Loss: 1.6871 Acc: 0.4496
# Epoch  82/99 train Loss: 1.6879 Acc: 0.4032 val Loss: 1.6876 Acc: 0.4521
# Epoch  83/99 train Loss: 1.6918 Acc: 0.4161 val Loss: 1.6640 Acc: 0.4521
# Epoch  84/99 train Loss: 1.6629 Acc: 0.4149 val Loss: 1.6785 Acc: 0.4251
# Epoch  85/99 train Loss: 1.6836 Acc: 0.4118 val Loss: 1.6636 Acc: 0.4472
# Epoch  86/99 train Loss: 1.6744 Acc: 0.4136 val Loss: 1.6620 Acc: 0.4496
# Epoch  87/99 train Loss: 1.6574 Acc: 0.4222 val Loss: 1.6413 Acc: 0.4423
# Epoch  88/99 train Loss: 1.6823 Acc: 0.4130 val Loss: 1.6627 Acc: 0.4423
# Epoch  89/99 train Loss: 1.6806 Acc: 0.4087 val Loss: 1.6671 Acc: 0.4423
# Epoch  90/99 train Loss: 1.6670 Acc: 0.4272 val Loss: 1.6685 Acc: 0.4423
# Epoch  91/99 train Loss: 1.6800 Acc: 0.4173 val Loss: 1.6496 Acc: 0.4472
# Epoch  92/99 train Loss: 1.6464 Acc: 0.4315 val Loss: 1.6459 Acc: 0.4496
# Epoch  93/99 train Loss: 1.6531 Acc: 0.4222 val Loss: 1.6477 Acc: 0.4570
# Epoch  94/99 train Loss: 1.6516 Acc: 0.4198 val Loss: 1.6446 Acc: 0.4595
# Epoch  95/99 train Loss: 1.6361 Acc: 0.4204 val Loss: 1.6393 Acc: 0.4693
# Epoch  96/99 train Loss: 1.6379 Acc: 0.4345 val Loss: 1.6318 Acc: 0.4619
# Epoch  97/99 train Loss: 1.6323 Acc: 0.4419 val Loss: 1.6324 Acc: 0.4545
# Epoch  98/99 train Loss: 1.6378 Acc: 0.4278 val Loss: 1.6465 Acc: 0.4595
# Epoch  99/99 train Loss: 1.6380 Acc: 0.4401 val Loss: 1.6516 Acc: 0.4521
# Training complete in 147m 21s
# Best val Acc: 0.469287
# Fold  3 test Loss: 1.7219 Acc: 0.4047
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.4142 Acc: 0.1652 val Loss: 2.2294 Acc: 0.2138
# Epoch   1/99 train Loss: 2.2839 Acc: 0.1880 val Loss: 2.1044 Acc: 0.2752
# Epoch   2/99 train Loss: 2.2025 Acc: 0.2150 val Loss: 2.1268 Acc: 0.2826
# Epoch   3/99 train Loss: 2.1908 Acc: 0.2285 val Loss: 2.1039 Acc: 0.2776
# Epoch   4/99 train Loss: 2.2161 Acc: 0.2156 val Loss: 2.0505 Acc: 0.2998
# Epoch   5/99 train Loss: 2.1739 Acc: 0.2322 val Loss: 2.0326 Acc: 0.3071
# Epoch   6/99 train Loss: 2.1677 Acc: 0.2488 val Loss: 2.0672 Acc: 0.2875
# Epoch   7/99 train Loss: 2.1518 Acc: 0.2500 val Loss: 2.0300 Acc: 0.2973
# Epoch   8/99 train Loss: 2.1135 Acc: 0.2617 val Loss: 2.0094 Acc: 0.3243
# Epoch   9/99 train Loss: 2.0856 Acc: 0.2623 val Loss: 2.0000 Acc: 0.3120
# Epoch  10/99 train Loss: 2.1108 Acc: 0.2690 val Loss: 1.9755 Acc: 0.3292
# Epoch  11/99 train Loss: 2.0801 Acc: 0.2752 val Loss: 1.9500 Acc: 0.3391
# Epoch  12/99 train Loss: 2.0776 Acc: 0.2875 val Loss: 1.9642 Acc: 0.3268
# Epoch  13/99 train Loss: 2.0721 Acc: 0.2592 val Loss: 1.9794 Acc: 0.3120
# Epoch  14/99 train Loss: 2.0439 Acc: 0.2973 val Loss: 1.9440 Acc: 0.3292
# Epoch  15/99 train Loss: 2.0388 Acc: 0.2881 val Loss: 1.9172 Acc: 0.3292
# Epoch  16/99 train Loss: 2.0393 Acc: 0.3071 val Loss: 1.9089 Acc: 0.3415
# Epoch  17/99 train Loss: 2.0114 Acc: 0.3059 val Loss: 1.9506 Acc: 0.3514
# Epoch  18/99 train Loss: 2.0005 Acc: 0.3047 val Loss: 1.8760 Acc: 0.3464
# Epoch  19/99 train Loss: 2.0171 Acc: 0.2819 val Loss: 1.9395 Acc: 0.3440
# Epoch  20/99 train Loss: 1.9958 Acc: 0.3016 val Loss: 1.9733 Acc: 0.3071
# Epoch  21/99 train Loss: 1.9926 Acc: 0.3028 val Loss: 1.8996 Acc: 0.3612
# Epoch  22/99 train Loss: 1.9846 Acc: 0.3041 val Loss: 1.8905 Acc: 0.3391
# Epoch  23/99 train Loss: 1.9966 Acc: 0.3096 val Loss: 1.8781 Acc: 0.3514
# Epoch  24/99 train Loss: 1.9644 Acc: 0.3182 val Loss: 1.9297 Acc: 0.3268
# Epoch  25/99 train Loss: 1.9656 Acc: 0.3127 val Loss: 1.8702 Acc: 0.3514
# Epoch  26/99 train Loss: 1.9777 Acc: 0.3213 val Loss: 1.9236 Acc: 0.3391
# Epoch  27/99 train Loss: 1.9377 Acc: 0.3108 val Loss: 1.9385 Acc: 0.3415
# Epoch  28/99 train Loss: 1.9369 Acc: 0.3182 val Loss: 1.8458 Acc: 0.3735
# Epoch  29/99 train Loss: 1.9243 Acc: 0.3311 val Loss: 1.8683 Acc: 0.3563
# Epoch  30/99 train Loss: 1.9013 Acc: 0.3299 val Loss: 1.8336 Acc: 0.3661
# Epoch  31/99 train Loss: 1.8779 Acc: 0.3458 val Loss: 1.8484 Acc: 0.3243
# Epoch  32/99 train Loss: 1.9365 Acc: 0.3317 val Loss: 1.8285 Acc: 0.3587
# Epoch  33/99 train Loss: 1.9071 Acc: 0.3280 val Loss: 1.8237 Acc: 0.3833
# Epoch  34/99 train Loss: 1.8673 Acc: 0.3581 val Loss: 1.8287 Acc: 0.3661
# Epoch  35/99 train Loss: 1.8709 Acc: 0.3458 val Loss: 1.8928 Acc: 0.3514
# Epoch  36/99 train Loss: 1.8798 Acc: 0.3366 val Loss: 1.8234 Acc: 0.3833
# Epoch  37/99 train Loss: 1.8748 Acc: 0.3471 val Loss: 1.8581 Acc: 0.3686
# Epoch  38/99 train Loss: 1.8584 Acc: 0.3612 val Loss: 1.7807 Acc: 0.4079
# Epoch  39/99 train Loss: 1.8430 Acc: 0.3575 val Loss: 1.8456 Acc: 0.3710
# Epoch  40/99 train Loss: 1.8916 Acc: 0.3489 val Loss: 1.8236 Acc: 0.3833
# Epoch  41/99 train Loss: 1.8822 Acc: 0.3446 val Loss: 1.8057 Acc: 0.3710
# Epoch  42/99 train Loss: 1.8500 Acc: 0.3587 val Loss: 1.7838 Acc: 0.3931
# Epoch  43/99 train Loss: 1.8665 Acc: 0.3593 val Loss: 1.8215 Acc: 0.3735
# Epoch  44/99 train Loss: 1.8234 Acc: 0.3704 val Loss: 1.7459 Acc: 0.3833
# Epoch  45/99 train Loss: 1.8197 Acc: 0.3600 val Loss: 1.7283 Acc: 0.4251
# Epoch  46/99 train Loss: 1.7915 Acc: 0.3735 val Loss: 1.7832 Acc: 0.4054
# Epoch  47/99 train Loss: 1.7990 Acc: 0.3649 val Loss: 1.7253 Acc: 0.4177
# Epoch  48/99 train Loss: 1.8042 Acc: 0.3655 val Loss: 1.7944 Acc: 0.3686
# Epoch  49/99 train Loss: 1.7579 Acc: 0.3943 val Loss: 1.7585 Acc: 0.4152
# Epoch  50/99 train Loss: 1.7783 Acc: 0.3913 val Loss: 1.7403 Acc: 0.4251
# Epoch  51/99 train Loss: 1.7495 Acc: 0.4134 val Loss: 1.7224 Acc: 0.3980
# Epoch  52/99 train Loss: 1.7665 Acc: 0.3882 val Loss: 1.7983 Acc: 0.4103
# Epoch  53/99 train Loss: 1.7458 Acc: 0.4023 val Loss: 1.7265 Acc: 0.3980
# Epoch  54/99 train Loss: 1.7550 Acc: 0.3943 val Loss: 1.7128 Acc: 0.4128
# Epoch  55/99 train Loss: 1.7724 Acc: 0.3790 val Loss: 1.7575 Acc: 0.4275
# Epoch  56/99 train Loss: 1.7297 Acc: 0.3993 val Loss: 1.7529 Acc: 0.4103
# Epoch  57/99 train Loss: 1.7297 Acc: 0.3962 val Loss: 1.7467 Acc: 0.4300
# Epoch  58/99 train Loss: 1.7363 Acc: 0.4036 val Loss: 1.7285 Acc: 0.4177
# Epoch  59/99 train Loss: 1.7289 Acc: 0.3993 val Loss: 1.6978 Acc: 0.4226
# Epoch  60/99 train Loss: 1.7308 Acc: 0.3937 val Loss: 1.7134 Acc: 0.4226
# Epoch  61/99 train Loss: 1.7102 Acc: 0.4048 val Loss: 1.7280 Acc: 0.4201
# Epoch  62/99 train Loss: 1.7376 Acc: 0.4011 val Loss: 1.7069 Acc: 0.4251
# Epoch  63/99 train Loss: 1.7584 Acc: 0.4005 val Loss: 1.7367 Acc: 0.4251
# Epoch  64/99 train Loss: 1.7167 Acc: 0.4128 val Loss: 1.7251 Acc: 0.4128
# Epoch  65/99 train Loss: 1.7183 Acc: 0.4060 val Loss: 1.7034 Acc: 0.4201
# Epoch  66/99 train Loss: 1.6681 Acc: 0.4201 val Loss: 1.7446 Acc: 0.4300
# Epoch  67/99 train Loss: 1.6854 Acc: 0.4115 val Loss: 1.6937 Acc: 0.4177
# Epoch  68/99 train Loss: 1.6582 Acc: 0.4324 val Loss: 1.7168 Acc: 0.4275
# Epoch  69/99 train Loss: 1.6633 Acc: 0.4269 val Loss: 1.6674 Acc: 0.4447
# Epoch  70/99 train Loss: 1.6892 Acc: 0.4165 val Loss: 1.7024 Acc: 0.4275
# Epoch  71/99 train Loss: 1.6684 Acc: 0.4201 val Loss: 1.6727 Acc: 0.4472
# Epoch  72/99 train Loss: 1.6551 Acc: 0.4386 val Loss: 1.6857 Acc: 0.4324
# Epoch  73/99 train Loss: 1.6402 Acc: 0.4361 val Loss: 1.7002 Acc: 0.4275
# Epoch  74/99 train Loss: 1.6391 Acc: 0.4459 val Loss: 1.6920 Acc: 0.4545
# Epoch  75/99 train Loss: 1.6335 Acc: 0.4281 val Loss: 1.7291 Acc: 0.4496
# Epoch  76/99 train Loss: 1.6591 Acc: 0.4244 val Loss: 1.7621 Acc: 0.4349
# Epoch  77/99 train Loss: 1.6404 Acc: 0.4453 val Loss: 1.7002 Acc: 0.4324
# Epoch  78/99 train Loss: 1.6393 Acc: 0.4232 val Loss: 1.7214 Acc: 0.4152
# Epoch  79/99 train Loss: 1.6071 Acc: 0.4367 val Loss: 1.6667 Acc: 0.4349
# Epoch  80/99 train Loss: 1.6309 Acc: 0.4570 val Loss: 1.7063 Acc: 0.4423
# Epoch  81/99 train Loss: 1.6226 Acc: 0.4337 val Loss: 1.6870 Acc: 0.4349
# Epoch  82/99 train Loss: 1.6335 Acc: 0.4423 val Loss: 1.7002 Acc: 0.4447
# Epoch  83/99 train Loss: 1.6481 Acc: 0.4349 val Loss: 1.7622 Acc: 0.4128
# Epoch  84/99 train Loss: 1.6168 Acc: 0.4281 val Loss: 1.6881 Acc: 0.4324
# Epoch  85/99 train Loss: 1.5848 Acc: 0.4558 val Loss: 1.6698 Acc: 0.4275
# Epoch  86/99 train Loss: 1.5803 Acc: 0.4607 val Loss: 1.6779 Acc: 0.4373
# Epoch  87/99 train Loss: 1.6026 Acc: 0.4404 val Loss: 1.6990 Acc: 0.4423
# Epoch  88/99 train Loss: 1.6007 Acc: 0.4410 val Loss: 1.6695 Acc: 0.4398
# Epoch  89/99 train Loss: 1.5902 Acc: 0.4459 val Loss: 1.6694 Acc: 0.4423
# Epoch  90/99 train Loss: 1.5853 Acc: 0.4545 val Loss: 1.6935 Acc: 0.4423
# Epoch  91/99 train Loss: 1.6026 Acc: 0.4539 val Loss: 1.6955 Acc: 0.4496
# Epoch  92/99 train Loss: 1.5388 Acc: 0.4742 val Loss: 1.6637 Acc: 0.4545
# Epoch  93/99 train Loss: 1.5687 Acc: 0.4539 val Loss: 1.6661 Acc: 0.4398
# Epoch  94/99 train Loss: 1.6005 Acc: 0.4595 val Loss: 1.6678 Acc: 0.4447
# Epoch  95/99 train Loss: 1.5778 Acc: 0.4527 val Loss: 1.6595 Acc: 0.4545
# Epoch  96/99 train Loss: 1.5702 Acc: 0.4496 val Loss: 1.6627 Acc: 0.4472
# Epoch  97/99 train Loss: 1.5703 Acc: 0.4613 val Loss: 1.6697 Acc: 0.4521
# Epoch  98/99 train Loss: 1.5650 Acc: 0.4564 val Loss: 1.6615 Acc: 0.4570
# Epoch  99/99 train Loss: 1.5528 Acc: 0.4699 val Loss: 1.6627 Acc: 0.4545
# Training complete in 143m 52s
# Best val Acc: 0.457002
# Fold  4 test Loss: 1.7558 Acc: 0.4193
# --------------------------------------------------
# cnn_layers.0.weight True
# cnn_layers.0.bias True
# cnn_layers.1.weight True
# cnn_layers.1.bias True
# cnn_layers.3.weight True
# cnn_layers.3.bias True
# cnn_layers.4.weight True
# cnn_layers.4.bias True
# cnn_layers.7.weight True
# cnn_layers.7.bias True
# cnn_layers.8.weight True
# cnn_layers.8.bias True
# cnn_layers.11.weight True
# cnn_layers.11.bias True
# cnn_layers.12.weight True
# cnn_layers.12.bias True
# self_attn.in_proj_weight False
# self_attn.in_proj_bias False
# self_attn.out_proj.weight False
# self_attn.out_proj.bias False
# fc_layers.0.weight True
# fc_layers.0.bias True
# fc_layers.2.weight True
# fc_layers.2.bias True
# fc_layers.4.weight True
# fc_layers.4.bias True
# Epoch   0/99 train Loss: 2.3503 Acc: 0.1671 val Loss: 2.2690 Acc: 0.1916
# Epoch   1/99 train Loss: 2.2635 Acc: 0.2113 val Loss: 2.1805 Acc: 0.2432
# Epoch   2/99 train Loss: 2.2092 Acc: 0.2316 val Loss: 2.1449 Acc: 0.2629
# Epoch   3/99 train Loss: 2.1703 Acc: 0.2457 val Loss: 2.1695 Acc: 0.2482
# Epoch   4/99 train Loss: 2.1833 Acc: 0.2469 val Loss: 2.1266 Acc: 0.2776
# Epoch   5/99 train Loss: 2.1781 Acc: 0.2525 val Loss: 2.1032 Acc: 0.2555
# Epoch   6/99 train Loss: 2.1234 Acc: 0.2451 val Loss: 2.1113 Acc: 0.2506
# Epoch   7/99 train Loss: 2.0991 Acc: 0.2586 val Loss: 2.1125 Acc: 0.2703
# Epoch   8/99 train Loss: 2.1090 Acc: 0.2647 val Loss: 2.0661 Acc: 0.2727
# Epoch   9/99 train Loss: 2.1078 Acc: 0.2623 val Loss: 2.0571 Acc: 0.2924
# Epoch  10/99 train Loss: 2.0960 Acc: 0.2611 val Loss: 2.0415 Acc: 0.2924
# Epoch  11/99 train Loss: 2.0556 Acc: 0.2807 val Loss: 2.1165 Acc: 0.2604
# Epoch  12/99 train Loss: 2.0730 Acc: 0.2770 val Loss: 2.0142 Acc: 0.3096
# Epoch  13/99 train Loss: 2.0694 Acc: 0.2844 val Loss: 2.1289 Acc: 0.2703
# Epoch  14/99 train Loss: 2.0549 Acc: 0.2875 val Loss: 2.0295 Acc: 0.2801
# Epoch  15/99 train Loss: 2.0522 Acc: 0.2801 val Loss: 2.0092 Acc: 0.3071
# Epoch  16/99 train Loss: 2.0356 Acc: 0.2918 val Loss: 1.9837 Acc: 0.2948
# Epoch  17/99 train Loss: 2.0209 Acc: 0.2875 val Loss: 2.0195 Acc: 0.2948
# Epoch  18/99 train Loss: 2.0150 Acc: 0.2991 val Loss: 2.0059 Acc: 0.2948
# Epoch  19/99 train Loss: 2.0409 Acc: 0.2887 val Loss: 2.0065 Acc: 0.2875
# Epoch  20/99 train Loss: 2.0218 Acc: 0.2869 val Loss: 1.9606 Acc: 0.2826
# Epoch  21/99 train Loss: 2.0091 Acc: 0.2985 val Loss: 1.9298 Acc: 0.3194
# Epoch  22/99 train Loss: 1.9825 Acc: 0.3102 val Loss: 1.9545 Acc: 0.3145
# Epoch  23/99 train Loss: 1.9600 Acc: 0.3249 val Loss: 1.9699 Acc: 0.3120
# Epoch  24/99 train Loss: 1.9969 Acc: 0.3077 val Loss: 1.9747 Acc: 0.3022
# Epoch  25/99 train Loss: 1.9773 Acc: 0.3151 val Loss: 1.9735 Acc: 0.2727
# Epoch  26/99 train Loss: 1.9447 Acc: 0.3139 val Loss: 1.9315 Acc: 0.3292
# Epoch  27/99 train Loss: 1.9617 Acc: 0.3286 val Loss: 1.9276 Acc: 0.3366
# Epoch  28/99 train Loss: 1.9435 Acc: 0.3206 val Loss: 1.9364 Acc: 0.2924
# Epoch  29/99 train Loss: 1.9627 Acc: 0.3127 val Loss: 2.0266 Acc: 0.2899
# Epoch  30/99 train Loss: 1.9616 Acc: 0.3286 val Loss: 1.8944 Acc: 0.3268
# Epoch  31/99 train Loss: 1.9593 Acc: 0.3237 val Loss: 1.8917 Acc: 0.3464
# Epoch  32/99 train Loss: 1.9471 Acc: 0.3256 val Loss: 1.9210 Acc: 0.3120
# Epoch  33/99 train Loss: 1.9191 Acc: 0.3415 val Loss: 1.9075 Acc: 0.3415
# Epoch  34/99 train Loss: 1.9004 Acc: 0.3305 val Loss: 1.8623 Acc: 0.3735
# Epoch  35/99 train Loss: 1.8667 Acc: 0.3538 val Loss: 1.8449 Acc: 0.3587
# Epoch  36/99 train Loss: 1.8706 Acc: 0.3428 val Loss: 1.8216 Acc: 0.3784
# Epoch  37/99 train Loss: 1.8869 Acc: 0.3335 val Loss: 1.8555 Acc: 0.3661
# Epoch  38/99 train Loss: 1.8824 Acc: 0.3575 val Loss: 1.8183 Acc: 0.3759
# Epoch  39/99 train Loss: 1.8772 Acc: 0.3489 val Loss: 1.8385 Acc: 0.3661
# Epoch  40/99 train Loss: 1.8361 Acc: 0.3735 val Loss: 1.8293 Acc: 0.3489
# Epoch  41/99 train Loss: 1.8541 Acc: 0.3550 val Loss: 1.7948 Acc: 0.4152
# Epoch  42/99 train Loss: 1.8414 Acc: 0.3600 val Loss: 1.7900 Acc: 0.4029
# Epoch  43/99 train Loss: 1.8302 Acc: 0.3569 val Loss: 1.7724 Acc: 0.4177
# Epoch  44/99 train Loss: 1.8192 Acc: 0.3636 val Loss: 1.7916 Acc: 0.4029
# Epoch  45/99 train Loss: 1.8309 Acc: 0.3630 val Loss: 1.8016 Acc: 0.3857
# Epoch  46/99 train Loss: 1.8470 Acc: 0.3655 val Loss: 1.7811 Acc: 0.4128
# Epoch  47/99 train Loss: 1.8178 Acc: 0.3839 val Loss: 1.8022 Acc: 0.3710
# Epoch  48/99 train Loss: 1.7939 Acc: 0.3796 val Loss: 1.8020 Acc: 0.3857
# Epoch  49/99 train Loss: 1.8190 Acc: 0.3698 val Loss: 1.7883 Acc: 0.4005
# Epoch  50/99 train Loss: 1.8200 Acc: 0.3857 val Loss: 1.7569 Acc: 0.4152
# Epoch  51/99 train Loss: 1.7848 Acc: 0.3673 val Loss: 1.8042 Acc: 0.4005
# Epoch  52/99 train Loss: 1.7984 Acc: 0.3741 val Loss: 1.7400 Acc: 0.4201
# Epoch  53/99 train Loss: 1.8049 Acc: 0.3753 val Loss: 1.7500 Acc: 0.3956
# Epoch  54/99 train Loss: 1.8099 Acc: 0.3716 val Loss: 1.7547 Acc: 0.4251
# Epoch  55/99 train Loss: 1.7911 Acc: 0.3900 val Loss: 1.7410 Acc: 0.4251
# Epoch  56/99 train Loss: 1.7879 Acc: 0.3759 val Loss: 1.7459 Acc: 0.4152
# Epoch  57/99 train Loss: 1.7643 Acc: 0.3845 val Loss: 1.7290 Acc: 0.4349
# Epoch  58/99 train Loss: 1.7840 Acc: 0.3888 val Loss: 1.7315 Acc: 0.4251
# Epoch  59/99 train Loss: 1.7549 Acc: 0.3974 val Loss: 1.7420 Acc: 0.4472
# Epoch  60/99 train Loss: 1.7754 Acc: 0.3729 val Loss: 1.7329 Acc: 0.4275
# Epoch  61/99 train Loss: 1.7724 Acc: 0.3827 val Loss: 1.7443 Acc: 0.3980
# Epoch  62/99 train Loss: 1.7506 Acc: 0.3864 val Loss: 1.7533 Acc: 0.4226
# Epoch  63/99 train Loss: 1.7526 Acc: 0.4042 val Loss: 1.7151 Acc: 0.4447
# Epoch  64/99 train Loss: 1.7637 Acc: 0.4017 val Loss: 1.6901 Acc: 0.4521
# Epoch  65/99 train Loss: 1.7782 Acc: 0.3876 val Loss: 1.7050 Acc: 0.4324
# Epoch  66/99 train Loss: 1.7435 Acc: 0.3845 val Loss: 1.7096 Acc: 0.4472
# Epoch  67/99 train Loss: 1.7530 Acc: 0.3894 val Loss: 1.6891 Acc: 0.4521
# Epoch  68/99 train Loss: 1.7201 Acc: 0.4048 val Loss: 1.7049 Acc: 0.4349
# Epoch  69/99 train Loss: 1.7428 Acc: 0.3937 val Loss: 1.6896 Acc: 0.4398
# Epoch  70/99 train Loss: 1.7226 Acc: 0.4072 val Loss: 1.6914 Acc: 0.4300
# Epoch  71/99 train Loss: 1.7363 Acc: 0.3999 val Loss: 1.7162 Acc: 0.4201
# Epoch  72/99 train Loss: 1.7658 Acc: 0.4054 val Loss: 1.6966 Acc: 0.4324
# Epoch  73/99 train Loss: 1.7417 Acc: 0.3968 val Loss: 1.6837 Acc: 0.4595
# Epoch  74/99 train Loss: 1.7150 Acc: 0.4134 val Loss: 1.6856 Acc: 0.4496
# Epoch  75/99 train Loss: 1.7139 Acc: 0.4263 val Loss: 1.6830 Acc: 0.4423
# Epoch  76/99 train Loss: 1.7189 Acc: 0.3925 val Loss: 1.6820 Acc: 0.4595
# Epoch  77/99 train Loss: 1.7034 Acc: 0.4128 val Loss: 1.6887 Acc: 0.4595
# Epoch  78/99 train Loss: 1.6851 Acc: 0.4171 val Loss: 1.6805 Acc: 0.4619
# Epoch  79/99 train Loss: 1.7038 Acc: 0.4177 val Loss: 1.6775 Acc: 0.4373
# Epoch  80/99 train Loss: 1.6980 Acc: 0.4177 val Loss: 1.6743 Acc: 0.4545
# Epoch  81/99 train Loss: 1.6808 Acc: 0.4158 val Loss: 1.6865 Acc: 0.4472
# Epoch  82/99 train Loss: 1.6969 Acc: 0.4232 val Loss: 1.6892 Acc: 0.4373
# Epoch  83/99 train Loss: 1.6967 Acc: 0.4324 val Loss: 1.6799 Acc: 0.4496
# Epoch  84/99 train Loss: 1.7030 Acc: 0.4097 val Loss: 1.7030 Acc: 0.4398
# Epoch  85/99 train Loss: 1.7007 Acc: 0.4177 val Loss: 1.6759 Acc: 0.4717
# Epoch  86/99 train Loss: 1.6732 Acc: 0.4238 val Loss: 1.6703 Acc: 0.4496
# Epoch  87/99 train Loss: 1.7060 Acc: 0.4103 val Loss: 1.6652 Acc: 0.4693
# Epoch  88/99 train Loss: 1.7000 Acc: 0.4122 val Loss: 1.6716 Acc: 0.4619
# Epoch  89/99 train Loss: 1.6782 Acc: 0.4355 val Loss: 1.6813 Acc: 0.4570
# Epoch  90/99 train Loss: 1.6973 Acc: 0.4269 val Loss: 1.6712 Acc: 0.4570
# Epoch  91/99 train Loss: 1.7105 Acc: 0.4103 val Loss: 1.6691 Acc: 0.4668
# Epoch  92/99 train Loss: 1.7026 Acc: 0.4066 val Loss: 1.6702 Acc: 0.4644
# Epoch  93/99 train Loss: 1.7031 Acc: 0.4091 val Loss: 1.6728 Acc: 0.4496
# Epoch  94/99 train Loss: 1.7003 Acc: 0.4275 val Loss: 1.6696 Acc: 0.4545
# Epoch  95/99 train Loss: 1.6954 Acc: 0.4214 val Loss: 1.6663 Acc: 0.4570
# Epoch  96/99 train Loss: 1.6778 Acc: 0.4306 val Loss: 1.6694 Acc: 0.4668
# Epoch  97/99 train Loss: 1.6795 Acc: 0.4115 val Loss: 1.6670 Acc: 0.4521
# Epoch  98/99 train Loss: 1.6807 Acc: 0.4244 val Loss: 1.6655 Acc: 0.4668
# Epoch  99/99 train Loss: 1.6787 Acc: 0.4294 val Loss: 1.6646 Acc: 0.4644
# Training complete in 143m 55s
# Best val Acc: 0.471744
# Fold  5 test Loss: 1.7289 Acc: 0.3937

# %%
print(classifier)
# Out:
# Classifier(
#   (cnn_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (self_attn): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=11, bias=True)
#   )
# )

# %% [markdown]
# ### 顯示結果

# %%
plt.figure(figsize=(8,3*len(histories)))

max_loss = 0
max_acc  = 0
for i,history in enumerate(histories):
    max_loss = max(max_loss,np.max(history['loss']),np.max(history['val_loss']))

max_loss *= 1.05
for i,history in enumerate(histories):
    plt.subplot(len(histories),2,i*2+1)
    plt.title(f'fold:{i+1}')
    plt.plot(history['loss'],label='train')
    plt.plot(history['val_loss'],label='valid')
    plt.xlabel('epoch')
    step = int(np.ceil(len(history['loss'])/5))
    plt.xticks(np.arange(0,len(history['loss']),step),[str(u+1) for u in np.arange(0,len(history['loss']),step)])
    plt.ylabel('loss')
    plt.ylim([0,max_loss])
    plt.grid(True)
    plt.legend()

    plt.subplot(len(histories),2,i*2+2)
    plt.title(f'fold:{i+1}')
    plt.plot(history['accuracy'],label='train')
    plt.plot(history['val_accuracy'],label='valid')
    plt.xticks(np.arange(0,len(history['accuracy']),step),[str(u+1) for u in np.arange(0,len(history['accuracy']),step)])
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.ylim([0,1.0])
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()

plt.figure()
plt.bar(x=np.arange(len(test_accuracy)),height=np.array(test_accuracy))
plt.xlabel('fold')
plt.xticks(np.arange(len(test_accuracy)),[str(i+1) for i in np.arange(len(test_accuracy))])
plt.ylabel('accuracy')
plt.title(f'average accuracy rate:{np.mean(np.array(test_accuracy)):.3f}+/-{np.std(np.array(test_accuracy)):.3f}')
plt.grid(True)
plt.ylim([0,1.0])
plt.show()
print(f'average accuracy rate:{np.mean(np.array(test_accuracy)):.3f}+/-{np.std(np.array(test_accuracy)):.3f}')
# Out:
# average accuracy rate:0.398+/-0.017
